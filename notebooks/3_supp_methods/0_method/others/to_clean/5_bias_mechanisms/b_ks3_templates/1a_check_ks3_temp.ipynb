# %% [markdown]
# # Kilosort3 six universal templates
#
# author: steeve.laquitaine@epfl.ch
#
# purpose: extract and plot Kilosort3's six universal templates

# %% [markdown]
# ## Setup
#
# Virtual env is `env_kilosort_silico`
#
# You should have extracted the templates from a KS3 run by running `python3.9 -m src.pipes.postpro.univ_temp` in the terminal before. See usage in `univ_temp` module.

# %%
# SETUP PACKAGES
# %load_ext autoreload
# %autoreload 2
import os
import pandas as pd
pd.set_option('display.max_colwidth', None)
from matplotlib import pyplot as plt

# set project path
PROJ_PATH = "/gpfs/bbp.cscs.ch/project/proj68/home/laquitai/spike-sorting"

os.chdir(PROJ_PATH)
from src.nodes.utils import get_config
from src.pipes.postpro import univ_temp

# SETUP PARAMETERS
EXPERIMENT = "silico_neuropixels"   # specifies the experiment 
SIMULATION_DATE = "2023_02_19"      # specifies the run (date)


# SETUP CONFIG
data_conf, param_conf = get_config(EXPERIMENT, SIMULATION_DATE).values()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2023-05-03 11:36:03,500 - root - utils.py - get_config - INFO - Reading experiment config.
# 2023-05-03 11:36:03,584 - root - utils.py - get_config - INFO - Reading experiment config. - done

# %%
# get and plot Kilosort3's six universal templates
univ_templates = univ_temp.load(data_conf)
plt.plot(univ_templates);
