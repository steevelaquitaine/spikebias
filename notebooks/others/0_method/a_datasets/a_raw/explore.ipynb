# %% [markdown]
# # Disconnected circuit neuropixels simulation

# %%
# %load_ext autoreload
# %autoreload 2
import os
import yaml
import spikeinterface as si
from matplotlib import pyplot as plt

# move to project path
with open("./proj_cfg.yml", "r", encoding="utf-8") as proj_cfg:
    PROJ_PATH = yaml.load(proj_cfg, Loader=yaml.FullLoader)["proj_path"]
os.chdir(PROJ_PATH)

from src.nodes.utils import get_config
data_conf, param_conf = get_config("silico_neuropixels", "npx_spont_discon").values()

REC = data_conf["probe_wiring"]["full"]["output"]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2024-11-27 13:43:12,207 - root - utils.py - get_config - INFO - Reading experiment config.
# 2024-11-27 13:43:12,224 - root - utils.py - get_config - INFO - Reading experiment config. - done

# %%
Recording = si.load_extractor(REC)
traces = Recording.get_traces()
plt.plot(traces[160000, 50])
