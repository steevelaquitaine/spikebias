# %% [markdown]
# # Ground truth neurons biological features
#
# * author: steeve.laquitaine@epfl.ch

# %% [markdown]
# Setup spikeinterf_ env ..

# %%
import os
from tqdm import tqdm
import numpy as np
import pandas as pd
import neurom as nm  # ground truth circuit details
import bluepy as bp  # ground truth circuit details
import spikeinterface as si
from neurom.view import plotly_impl
import neurom as nm


# move to PROJECT PATH
PROJ_PATH = "/gpfs/bbp.cscs.ch/project/proj85/home/laquitai/spikebias/"
os.chdir(PROJ_PATH)
from src.nodes.utils import get_config
from src.nodes.load import load_campaign_params

cfg, param_conf = get_config("dense_spont", "probe_2").values()
SORTING_TRUE_PATH = cfg["ground_truth"]["full"]["output"]
BLUECFG = cfg["dataeng"]["blueconfig"]

# PARAMETERS

# SOMA
SOMA = {
    "soma": nm.core.types.NeuriteType.soma,
}
SOMA_FEATURES = [
    "radius",
    "volume",
]

# OTHER NEURITES
NEURITES_FEATURES = [
    "total_length",
    "total_height",
    "total_area",
    "number_of_sections",
    "section_lengths",
]
NEURITES = {
    "apical": nm.core.types.NeuriteType.apical_dendrite,
    "basal": nm.core.types.NeuriteType.basal_dendrite,
    "axon": nm.core.types.NeuriteType.axon,
}

DS1_MORPH = cfg["metadata"]["cell_morphs"]
# Out:
# 2024-12-12 17:31:52,972 - root - utils.py - get_config - INFO - Reading experiment config.
# 2024-12-12 17:31:53,004 - root - utils.py - get_config - INFO - Reading experiment config. - done

# %% [markdown]
# ### Custom functions

# %%
def get_features(morph_paths, feature_set, neurite_set):
    """Get morphometric features for all morphologies passed"""
    features = {"mtype": [], "feature_name": [], "feature_val": [], "loc": []}
    for mtype, paths in tqdm(morph_paths.items(), desc="mtypes"):
        for path in tqdm(
            paths, desc="morphologies", miniters=len(paths) / 100, leave=False
        ):
            morph = nm.load_morphology(path)
            for neurite_name, neurite_id in neurite_set.items():
                for feature in feature_set:
                    features["mtype"].append(mtype)
                    feature_name = (
                        "avg_section_length"
                        if feature == "section_lengths"
                        else feature
                    )
                    features["feature_name"].append(feature_name)
                    feature_val = nm.get(feature, morph, neurite_type=neurite_id)
                    feature_val = (
                        np.mean(feature_val)
                        if feature == "section_lengths"
                        else feature_val
                    )
                    features["feature_val"].append(feature_val)
                    features["loc"].append(neurite_name)
    df = pd.DataFrame.from_dict(features)
    df.drop(
        df.loc[(df["mtype"] == "L4_SSC") & (df["loc"] == "apical")].index, inplace=True
    )  # clear L4_SSC apicals...
    return df


def get_morph_paths(circuit, unit_ids: list):

    # get the units' mtypes and morphologies
    df = circuit.cells.get(unit_ids, properties=["mtype", "morphology"])

    # this creates the morphology path
    # for each unit by prefixing with the
    # common path of all morphologies
    # circuit.config["morphologies"]
    # to the morphology of the
    # units retrieved above
    # e.g., ../fixed_ais_L23PC_20201210/ascii/dend-C220797A-P3_axon-sm110131a1-3_IN.. for unit 12165
    # e.g., ../fixed_ais_L23PC_20201210/ascii/dend-rat_20160908_E3_LH2_cell2_axon-mt for unit 16652
    df["morph_path"] = (
        df["morphology"]
        .apply(lambda row: os.path.join(circuit.config["morphologies"], "%s.asc" % row))
        .astype(str)
    )
    df = df.drop(columns=["mtype", "morphology"])
    return df


def get_radius(circuit, unit_ids):

    # get the file paths of the morphology
    morph_paths = get_morph_paths(circuit, unit_ids)
    morph_paths = morph_paths.values.flatten()

    # get unit soma radius
    soma_radius = []
    for m_i in morph_paths:
        soma_radius.append(nm.load_morphology(m_i).soma.radius)
    return soma_radius

# %% [markdown]
# ### Soma radius

# %%
# load once
circuit = bp.Simulation(BLUECFG).circuit

# get ground truth unit ids
SortingTrue = si.load_extractor(SORTING_TRUE_PATH)

# %%
# (1m)
# get volume
radius = get_radius(circuit, SortingTrue.unit_ids)

# unit-test
assert len(radius) == len(SortingTrue.unit_ids)
print(radius)
# Out:
# [7.174989, 8.422994, 7.610226, 12.163964, 6.5572352, 7.9881673, 8.082553, 6.5572352, 8.801092, 10.477856, 6.594521, 8.361107, 9.324264, 8.801092, 8.361107, 6.5572352, 7.275731, 6.5572352, 8.082553, 7.275731, 7.174989, 8.422994, 7.9881673, 7.9881673, 7.9881673, 7.174989, 7.275731, 6.5572352, 7.9881673, 8.422994, 6.594521, 8.422994, 6.5572352, 7.610226, 9.324264, 8.361107, 8.361107, 7.174989, 10.56996, 10.663641, 6.5572352, 10.663641, 6.5572352, 7.047762, 6.5572352, 10.663641, 8.361107, 6.5572352, 7.610226, 8.73887, 8.361107, 6.5572352, 6.472128, 6.9807596, 7.4698386, 7.2470517, 6.896214, 7.368907, 7.368907, 9.613261, 9.613261, 7.2470517, 7.2470517, 7.4698386, 7.4698386, 7.368907, 6.896214, 7.4698386, 7.2470517, 7.2470517, 9.613261, 7.4698386, 7.885879, 12.3498955, 6.434877, 6.434877, 6.434877, 7.2498465, 6.751119, 10.428623, 8.590001, 7.0883703, 7.147172, 8.187446, 6.0981436, 8.358167, 8.266456, 6.182903, 8.731668, 8.187446, 7.0785036, 6.182903, 7.0785036, 7.0785036, 7.1187463, 6.0981436, 7.924968, 8.731668, 7.924968, 7.0110345, 8.187446, 9.07306, 8.417779, 7.0883703, 8.417779, 9.07306, 8.417779, 7.924968, 7.924968, 6.0981436, 8.358167, 7.0785036, 10.424591, 8.187446, 7.250568, 8.491132, 8.368504, 9.938738, 7.0785036, 7.0110345, 7.0110345, 6.0981436, 6.0981436, 6.0981436, 8.417779, 8.038113, 7.147172, 7.147172, 7.41455, 8.417779, 7.924968, 7.0110345, 7.997779, 7.835656, 8.112806, 7.9487634, 9.111261, 9.431796, 7.835656, 8.116544, 7.9487634, 7.8339386, 7.8339386, 9.086442, 7.9487634, 11.8826685, 7.6697464, 7.6697464, 8.112806, 9.850744, 7.9487634, 8.577086, 7.273272, 7.9487634, 7.273272, 8.577086, 6.8802133, 6.8802133, 11.8826685, 9.111261, 9.431796, 9.198034, 9.187992, 7.9487634, 7.9487634, 8.577086, 7.9487634, 8.577086, 8.758142, 8.577086, 7.9487634, 9.086442, 10.127033, 9.8098345, 6.8802133, 7.7420506, 9.111261, 9.8098345, 7.229008, 9.198034, 8.577086, 7.9487634, 7.273272, 9.579767, 7.192106, 9.111261, 7.273272, 7.019357, 9.431796, 6.8802133, 7.6697464, 8.577086, 7.273272, 7.715425, 6.8802133, 6.8802133, 8.112806, 9.086442, 9.431796, 11.328219, 7.9487634, 7.997779, 9.086442, 11.8826685, 10.924668, 9.3779, 7.273272, 8.758142, 9.850744, 7.9487634, 9.8098345, 8.758142, 7.6697464, 7.273272, 9.086442, 9.8098345, 8.758142, 10.127033, 8.30935, 9.579767, 8.758142, 10.760917, 9.8098345, 9.086442, 7.8339386, 7.997779, 7.273272, 8.577086, 6.8802133, 7.8339386, 7.273272, 9.431796, 7.6697464, 7.7420506, 7.7420506, 9.086442, 8.112806, 9.3779, 10.127033, 7.835656, 9.8098345, 8.112806, 9.111261, 9.111261, 11.328219, 7.273272, 10.127033, 8.758142, 9.431796, 7.9487634, 9.431796, 6.8802133, 7.229008, 6.8802133, 9.086442, 7.9200935, 7.6772137, 8.715869, 8.958467, 8.434622, 7.120629, 8.958467, 8.434622, 7.877569, 6.9628882, 8.715869, 8.715869, 7.877569, 8.958467, 8.692469, 7.877569, 7.7273917, 7.120629, 8.434622, 8.692469, 7.7273917, 8.692469, 6.9628882, 8.434622, 6.9628882, 8.469845, 7.682073, 10.119182, 6.7326045, 10.119182, 6.7326045, 9.252702, 11.944104, 9.639923, 8.040884, 9.639923, 8.802532, 10.500498, 9.054646, 10.500498, 8.040884, 9.639923, 7.5336657, 9.709649, 10.500498, 8.559948, 11.639513, 9.327482, 8.040884, 10.104563, 8.559948, 8.040884, 13.712643, 10.104563, 10.104563, 10.532178, 9.327482, 11.260711, 9.709649, 7.5336657, 9.639923, 9.639923, 8.559948, 8.040884, 10.104563, 10.104563, 10.119043, 8.552271, 10.177184, 10.502575, 9.673345, 6.6123986, 8.552271, 11.883015, 7.4405737, 8.661746, 13.809426, 10.917589, 9.088625, 6.6123986, 10.917589, 9.2525625, 13.809426, 9.439835, 7.325059, 7.7088666, 10.627711, 7.325059, 10.045507, 9.203061, 7.609973, 9.449554, 9.449554, 11.12446, 6.6463957, 8.322571, 10.06541, 10.514027, 9.203061, 9.203061, 7.325059, 9.002311, 10.240965, 7.7088666, 9.449554, 10.514027, 11.12446, 7.609973, 6.6463957, 6.6463957, 10.013313, 7.2549663, 7.325059, 9.203061, 9.002311, 7.7088666, 11.940535, 7.8038754, 9.467318, 9.715207, 9.194793, 8.718365, 7.2978206, 8.497395, 9.194793, 8.718365, 7.839849, 9.120796, 7.1861887, 9.12 ...

# %% [markdown]
# ### Neurites features

# %%
# 11 min

# get neurite features for each unit
df_all = pd.DataFrame()
for u_i, unit_id in enumerate(SortingTrue.unit_ids):

    # get neurite features
    morph_paths = get_morph_paths(circuit, [unit_id])
    df = get_features(morph_paths, feature_set=NEURITES_FEATURES, neurite_set=NEURITES)
    df = df.apply(lambda x: x.replace("apical", "apical_dendrite"))
    df = df.apply(lambda x: x.replace("basal", "basal_dendrite"))
    df = df.rename({"loc": "neurite_feature"}, axis="columns")
    df["neurite_feature"] += "_" + df["feature_name"]
    df.index = df.neurite_feature.tolist()
    df = df.drop(columns=["feature_name", "mtype", "neurite_feature"])
    df = df.T
    df["morph_path"] = morph_paths.iloc[0][0]
    
    # record
    df_all = pd.concat([df_all, df])

# drop index    
df_all = df_all.reset_index().drop(columns=["index"])

# concatenate with soma radius info
morph_df = pd.DataFrame()
morph_df["unit_id"] = SortingTrue.unit_ids
morph_df["soma_radius"] = radius
df = pd.concat([morph_df, df_all], axis=1)
df.to_parquet(DS1_MORPH)
# Out:
# mtypes: 1it [00:00,  9.09it/s]
# mtypes: 1it [00:00,  5.62it/s]
# mtypes: 1it [00:00,  7.09it/s]
# mtypes: 1it [00:00,  3.43it/s]
# mtypes: 1it [00:00,  4.38it/s]
# mtypes: 1it [00:00,  2.24it/s]
# mtypes: 1it [00:00,  3.54it/s]
# mtypes: 1it [00:00,  5.98it/s]
# mtypes: 1it [00:00,  2.93it/s]
# mtypes: 1it [00:00,  5.49it/s]
# mtypes: 1it [00:00,  4.01it/s]
# mtypes: 1it [00:00,  3.84it/s]
# mtypes: 1it [00:00,  5.80it/s]
# mtypes: 1it [00:00,  2.79it/s]
# mtypes: 1it [00:00,  4.78it/s]
# mtypes: 1it [00:00,  4.90it/s]
# mtypes: 1it [00:00,  6.56it/s]
# mtypes: 1it [00:00,  6.47it/s]
# mtypes: 1it [00:00,  8.33it/s]
# mtypes: 1it [00:00,  3.66it/s]
# mtypes: 1it [00:00,  7.24it/s]
# mtypes: 1it [00:00,  6.84it/s]
# mtypes: 1it [00:00,  4.87it/s]
# mtypes: 1it [00:00,  7.50it/s]
# mtypes: 1it [00:00,  4.84it/s]
# mtypes: 1it [00:00,  3.41it/s]
# mtypes: 1it [00:00,  7.50it/s]
# mtypes: 1it [00:00,  5.11it/s]
# mtypes: 1it [00:00,  2.87it/s]
# mtypes: 1it [00:00,  4.07it/s]
# mtypes: 1it [00:00,  7.01it/s]
# mtypes: 1it [00:00, 10.86it/s]
# mtypes: 1it [00:00,  5.09it/s]
# mtypes: 1it [00:00,  4.81it/s]
# mtypes: 1it [00:00,  3.55it/s]
# mtypes: 1it [00:00,  5.28it/s]
# mtypes: 1it [00:00,  2.96it/s]
# mtypes: 1it [00:00, 10.76it/s]
# mtypes: 1it [00:00,  4.42it/s]
# mtypes: 1it [00:00,  4.52it/s]
# mtypes: 1it [00:00,  6.94it/s]
# mtypes: 1it [00:00,  2.12it/s]
# mtypes: 1it [00:00,  6.96it/s]
# mtypes: 1it [00:00,  2.68it/s]
# mtypes: 1it [00:00,  8.09it/s]
# mtypes: 1it [00:00,  3.99it/s]
# mtypes: 1it [00:00,  4.80it/s]
# mtypes: 1it [00:00,  2.28it/s]
# mtypes: 1it [00:00,  7.77it/s]
# mtypes: 1it [00:00,  4.05it/s]
# mtypes: 1it [00:00,  9.15it/s]
# mtypes: 1it [00:00,  5.78it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00, 27.67it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  2.25it/s]
# mtypes: 1it [00:00,  2.42it/s]
# mtypes: 1it [00:00,  2.61it/s]
# mtypes: 1it [00:00,  6.30it/s]
# mtypes: 1it [00:00,  9.67it/s]
# mtypes: 1it [00:00,  9.42it/s]
# mtypes: 1it [00:00,  5.46it/s]
# mtypes: 1it [00:00,  5.29it/s]
# mtypes: 1it [00:00,  5.97it/s]
# mtypes: 1it [00:00,  5.92it/s]
# mtypes: 1it [00:00,  6.18it/s]
# mtypes: 1it [00:00,  6.15it/s]
# mtypes: 1it [00:00, 10.00it/s]
# mtypes: 1it [00:00,  3.47it/s]
# mtypes: 1it [00:00,  6.10it/s]
# mtypes: 1it [00:00,  2.59it/s]
# mtypes: 1it [00:00,  8.13it/s]
# mtypes: 1it [00:00,  6.87it/s]
# mtypes: 1it [00:00,  6.06it/s]
# mtypes: 1it [00:00,  8.25it/s]
# mtypes: 1it [00:00, 11.61it/s]
# mtypes: 1it [00:00,  3.66it/s]
# mtypes: 1it [00:00,  3.88it/s]
# mtypes: 1it [00:00,  6.77it/s]
# mtypes: 1it [00:00,  6.67it/s]
# mtypes: 1it [00:00,  7.93it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00, 10.85it/s]
# mtypes: 1it [00:00,  6.93it/s]
# mtypes: 1it [00:00, 12.75it/s]
# mtypes: 1it [00:00, 10.86it/s]
# mtypes: 1it [00:00,  5.62it/s]
# mtypes: 1it [00:00,  4.54it/s]
# mtypes: 1it [00:00,  8.66it/s]
# mtypes: 1it [00:00,  5.93it/s]
# mtypes: 1it [00:00,  7.35it/s]
# mtypes: 1it [00:00,  5.14it/s]
# mtypes: 1it [00:00,  5.63it/s]
# mtypes: 1it [00:00,  4.50it/s]
# mtypes: 1it [00:00, 14.31it/s]
# mtypes: 1it [00:00,  5.97it/s]
# mtypes: 1it [00:00,  6.92it/s]
# mtypes: 1it [00:00,  7.20it/s]
# mtypes: 1it [00:00,  7.45it/s]
# mtypes: 1it [00:00,  9.01it/s]
# mtypes: 1it [00:00, 11.45it/s]
# mtypes: 1it [00:00,  3.14it/s]
# mtypes: 1it [00:00,  2.58it/s]
# mtypes: 1it [00:00,  7.17it/s]
# mtypes: 1it [00:00,  7.07it/s]
# mtypes: 1it [00:00,  5.39it/s]
# mtypes: 1it [00:00,  7.20it/s]
# mtypes: 1it [00:00,  5.30it/s]
# mtypes: 1it [00:00,  7.32it/s]
# mtypes: 1it [00:00,  7.87it/s]
# mtypes: 1it [00:00, 10.14it/s]
# mtypes: 1it [00:00,  2.67it/s]
# mtypes: 1it [00:00,  3.01it/s]
# mtypes: 1it [00:00,  9.81it/s]
# mtypes: 1it [00:00, 15.00it/s]
# mtypes: 1it [00:00,  2.55it/s]
# mtypes: 1it [00:00,  6.83it/s]
# mtypes: 1it [00:00,  2.39it/s]
# mtypes: 1it [00:00,  7.74it/s]
# mtypes: 1it [00:00,  1.95it/s]
# mtypes: 1it [00:00,  4.37it/s]
# mtypes: 1it [00:00,  6.70it/s]
# mtypes: 1it [00:00, 11.79it/s]
# mtypes: 1it [00:00,  6.19it/s]
# mtypes: 1it [00:00,  9.26it/s]
# mtypes: 1it [00:00, 11.62it/s]
# mtypes: 1it [00:00,  1.97it/s]
# mtypes: 1it [00:00,  2.48it/s]
# mtypes: 1it [00:00,  6.26it/s]
# mtypes: 1it [00:00,  8.07it/s]
# mtypes: 1it [00:00,  3.62it/s]
# mtypes: 1it [00:00, 13.08it/s]
# mtypes: 1it [00:00, 10.40it/s]
# mtypes: 1it [00:00,  4.72it/s]
# mtypes: 1it [00:00,  6.87it/s]
# mtypes: 1it [00:00, 13.47it/s]
# mtypes: 1it [00:00,  3.93it/s]
# mtypes: 1it [00:00, 15.93it/s]
# mtypes: 1it [00:00,  6.70it/s]
# mtypes: 1it [00:00,  9.49it/s]
# mtypes: 1it [00:00,  4.35it/s]
# mtypes: 1it [00:00,  5.14it/s]
# mtypes: 1it [00:00,  7.98it/s]
# mtypes: 1it [00:00,  5.59it/s]
# mtypes: 1it [00:00,  5.93it/s]
# mtypes: 1it [00:00,  7.27it/s]
# mtypes: 1it [00:00,  5.97it/s]
# mtypes: 1it [00:00, 10.44it/s]
# mtypes: 1it [00:00,  3.67it/s]
# mtypes: 1it [00:00, 11.76it/s]
# mtypes: 1it [00:00,  5.03it/s]
# mtypes: 1it [00:00,  7.57it/s]
# mtypes: 1it [00:00,  3.90it/s]
# mtypes: 1it [00:00,  6.77it/s]
# mtypes: 1it [00:00,  5.65it/s]
# mtypes: 1it [00:00, 10.33it/s]
# mtypes: 1it [00:00, 12.20it/s]
# mtypes: 1it [00:00,  5.64it/s]
# mtypes: 1it [00:00,  5.54it/s]
# mtypes: 1it [00:00,  5.32it/s]
# mtypes: 1it [00:00, 11.58it/s]
# mtypes: 1it [00:00,  3.75it/s]
# mtypes: 1it [00:00,  8.96it/s]
# mtypes: 1it [00:00,  6.29it/s]
# mtypes: 1it [00:00,  4.08it/s]
# mtypes: 1it [00:00,  5.35it/s]
# mtypes: 1it [00:00,  6.68it/s]
# mtypes: 1it [00:00,  6.64it/s]
# mtypes: 1it [00:00,  5.00it/s]
# mtypes: 1it [00:00,  9.06it/s]
# mtypes: 1it [00:00,  4.68it/s]
# mtypes: 1it [00:00,  4.76it/s]
# mtypes: 1it [00:00,  9.28it/s]
# mtypes: 1it [00:00,  6.74it/s]
# mtypes: 1it [00:00,  5.36it/s]
# mtypes: 1it [00:00,  4.72it/s]
# mtypes: 1it [00:00,  7.37it/s]
# mtypes: 1it [00:00,  6.64it/s]
# mtypes: 1it [00:00,  5.97it/s]
# mtypes: 1it [00:00,  8.15it/s]
# mtypes: 1it [00:00,  5.31it/s]
# mtypes: 1it [00:00,  6.86it/s]
# mtypes: 1it [00:00,  6.13it/s]
# mtypes: 1it [00:00,  5.65it/s]
# mtypes: 1it [00:00,  8.47it/s]
# mtypes: 1it [00:00,  6.63it/s]
# mtypes: 1it [00:00,  5.60it/s]
# mtypes: 1it [00:00,  7.13it/s]
# mtypes: 1it [00:00,  7.51it/s]
# mtypes: 1it [00:00, 11.35it/s]
# mtypes: 1it [00:00, 11.92it/s]
# mtypes: 1it [00:00,  3.65it/s]
# mtypes: 1it [00:00,  7.17it/s]
# mtypes: 1it [00:00, 10.98it/s]
# mtypes: 1it [00:00,  5.20it/s]
# mtypes: 1it [00:00, 16.43it/s]
# mtypes: 1it [00:00, 14.14it/s]
# mtypes: 1it [00:00,  7.07it/s]
# mtypes: 1it [00:00,  6.11it/s]
# mtypes: 1it [00:00, 15.88it/s]
# mtypes: 1it [00:00,  5.63it/s]
# mtypes: 1it [00:00,  6.86it/s]
# mtypes: 1it [00:00,  4.88it/s]
# mtypes: 1it [00:00,  5.07it/s]
# mtypes: 1it [00:00,  5.22it/s]
# mtypes: 1it [00:00,  4.39it/s]
# mtypes: 1it [00:00,  4.07it/s]
# mtypes: 1it [00:00,  8.51it/s]
# mtypes: 1it [00:00,  5.34it/s]
# mtypes: 1it [00:00,  8.71it/s]
# mtypes: 1it [00:00,  4.75it/s]
# mtypes: 1it [00:00,  6.19it/s]
# mtypes: 1it [00:00,  7.29it/s]
# mtypes: 1it [00:00,  4.40it/s]
# mtypes: 1it [00:00,  5.39it/s]
# mtypes: 1it [00:00,  9.62it/s]
# mtypes: 1it [00:00,  7.57it/s]
# mtypes: 1it [00:00,  7.37it/s]
# mtypes: 1it [00:00,  5.58it/s]
# mtypes: 1it [00:00,  5.38it/s]
# mtypes: 1it [00:00,  4.01it/s]
# mtypes: 1it [00:00,  8.36it/s]
# mtypes: 1it [00:00,  6.82it/s]
# mtypes: 1it [00:00,  5.32it/s]
# mtypes: 1it [00:00,  8.56it/s]
# mtypes: 1it [00:00,  3.73it/s]
# mtypes: 1it [00:00,  5.49it/s]
# mtypes: 1it [00:00,  7.45it/s]
# mtypes: 1it [00:00,  5.35it/s]
# mtypes: 1it [00:00, 10.41it/s]
# mtypes: 1it [00:00,  5.86it/s]
# mtypes: 1it [00:00, 10.84it/s]
# mtypes: 1it [00:00,  6.23it/s]
# mtypes: 1it [00:00,  6.60it/s]
# mtypes: 1it [00:00,  5.10it/s]
# mtypes: 1it [00:00, 11.99it/s]
# mtypes: 1it [00:00,  7.86it/s]
# mtypes: 1it [00:00,  4.28it/s]
# mtypes: 1it [00:00,  5.62it/s]
# mtypes: 1it [00:00,  6.61it/s]
# mtypes: 1it [00:00,  5.00it/s]
# mtypes: 1it [00:00,  6.34it/s]
# mtypes: 1it [00:00,  5.54it/s]
# mtypes: 1it [00:00,  5.51it/s]
# mtypes: 1it [00:00,  6.40it/s]
# mtypes: 1it [00:00,  8.34it/s]
# mtypes: 1it [00:00, 10.32it/s]
# mtypes: 1it [00:00,  6.02it/s]
# mtypes: 1it [00:00,  5.48it/s]
# mtypes: 1it [00:00,  4.91it/s]
# mtypes: 1it [00:00,  7.11it/s]
# mtypes: 1it [00:00,  6.30it/s]
# mtypes: 1it [00:00,  5.23it/s]
# mtypes: 1it [00:00,  5.07it/s]
# mtypes: 1it [00:00,  5.31it/s]
# mtypes: 1it [00:00,  7.20it/s]
# mtypes: 1it [00:00,  6.96it/s]
# mtypes: 1it [00:00,  4.54it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  4.03it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  4.07it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  6.59it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  8.03it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  3.23it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  5.41it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  6.17it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  4.02it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  5.36it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  8.20it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  3.91it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  4.13it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  7.12it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  4.10it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  4.25it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  4.73it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  5.40it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  3.63it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00, 11.09it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  6.73it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  5.98it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  5.84it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  3.90it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  3.98it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  7.14it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  4.50it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  1.16it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  1.91it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  2.04it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  2.52it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  1.80it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  2.79it/s]
# mtypes: 1it [00:00,  7.35it/s]
# mtypes: 1it [00:00,  7.01it/s]
# mtypes: 1it [00:00,  4.35it/s]
# mtypes: 1it [00:00,  4.45it/s]
# mtypes: 1it [00:00,  5.49it/s]
# mtypes: 1it [00:00,  6.25it/s]
# mtypes: 1it [00:00,  5.03it/s]
# mtypes: 1it [00:00,  3.44it/s]
# mtypes: 1it [00:00,  2.59it/s]
# mtypes: 1it [00:00,  6.37it/s]
# mtypes: 1it [00:00,  4.23it/s]
# mtypes: 1it [00:00,  3.96it/s]
# mtypes: 1it [00:00,  6.71it/s]
# mtypes: 1it [00:00,  6.36it/s]
# mtypes: 1it [00:00,  5.28it/s]
# mtypes: 1it [00:00,  4.17it/s]
# mtypes: 1it [00:00,  4.15it/s]
# mtypes: 1it [00:00,  2.32it/s]
# mtypes: 1it [00:00,  4.02it/s]
# mtypes: 1it [00:00,  2.50it/s]
# mtypes: 1it [00:00,  3.41it/s]
# mtypes: 1it [00:00,  2.36it/s]
# mtypes: 1it [00:00,  1.57it/s]
# mtypes: 1it [00:00,  2.20it/s]
# mtypes: 1it [00:00,  2.74it/s]
# mtypes: 1it [00:00,  2.28it/s]
# mtypes: 1it [00:00,  5.15it/s]
# mtypes: 1it [00:00,  3.65it/s]
# mtypes: 1it [00:00,  3.88it/s]
# mtypes: 1it [00:00,  4.00it/s]
# mtypes: 1it [00:00,  4.09it/s]
# mtypes: 1it [00:00,  2.25it/s]
# mtypes: 1it [00:00,  2.09it/s]
# mtypes: 1it [00:00,  2.01it/s]
# mtypes: 1it [00:00,  2.91it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  4.64it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  1.56it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  2.50it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  1.75it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  1.99it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  4.72it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:01,  1.07s/it]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  2.35it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  4.12it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  1.23it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  2.03it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:01,  1.03s/it]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  2.17it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  2.11it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  1.03it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  1.22it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  1.33it/s]
# mtypes: 1it [00:00,  3.15it/s]
# mtypes: 1it [00:00,  2.00it/s]
# mtypes: 1it [00:00,  2.03it/s]
# mtypes: 1it [00:00,  2.36it/s]
# mtypes: 1it [00:00,  3.17it/s]
# mtypes: 1it [00:00,  1.77it/s]
# mtypes: 1it [00:00,  2.97it/s]
# mtypes: 1it [00:00,  2.26it/s]
# mtypes: 1it [00:00,  2.96it/s]
# mtypes: 1it [00:00,  2.73it/s]
# mtypes: 1it [00:00,  3.97it/s]
# mtypes: 1it [00:00,  2.45it/s]
# mtypes: 1it [00:00,  4.21it/s]
# mtypes: 1it [00:00,  4.66it/s]
# mtypes: 1it [00:00,  2.47it/s]
# mtypes: 1it [00:00,  2.06it/s]
# mtypes: 1it [00:00,  2.33it/s]
# mtypes: 1it [00:00,  2.88it/s]
# mtypes: 1it [00:00,  1.99it/s]
# mtypes: 1it [00:00,  2.40it/s]
# mtypes: 1it [00:00,  3.08it/s]
# mtypes: 1it [00:00,  3.90it/s]
# mtypes: 1it [00:00,  2.84it/s]
# mtypes: 1it [00:00,  2.68it/s]
# mtypes: 1it [00:00,  3.20it/s]
# mtypes: 1it [00:00,  3.95it/s]
# mtypes: 1it [00:00,  3.79it/s]
# mtypes: 1it [00:00,  4.24it/s]
# mtypes: 1it [00:00,  2.14it/s]
# mtypes: 1it [00:00,  3.66it/s]
# mtypes: 1it [00:00,  3.73it/s]
# mtypes: 1it [00:00,  3.19it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  2.33it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  4.42it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  2.51it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  1.70it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  2.10it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  1.67it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  2.38it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  1.59it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  1.95it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  1.48it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  3.44it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  1.46it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  3.64it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  1.45it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  2.34it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  4.02it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  1.53it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00, 11.37it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  6.09it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  3.76it/s]
# mtypes: 1it [00:00,  2.40it/s]
# mtypes: 1it [00:00,  2.74it/s]
# mtypes: 1it [00:00,  2.51it/s]
# mtypes: 1it [00:00,  2.45it/s]
# mtypes: 1it [00:00,  2.63it/s]
# mtypes: 1it [00:00,  1.60it/s]
# mtypes: 1it [00:00,  2.26it/s]
# mtypes: 1it [00:00,  2.03it/s]
# mtypes: 1it [00:00,  1.71it/s]
# mtypes: 1it [00:00,  2.49it/s]
# mtypes: 1it [00:00,  1.95it/s]
# mtypes: 1it [00:00,  2.08it/s]
# mtypes: 1it [00:00,  2.60it/s]
# mtypes: 1it [00:00,  3.20it/s]
# mtypes: 1it [00:00,  2.92it/s]
# mtypes: 1it [00:00,  2.17it/s]
# mtypes: 1it [00:00,  2.60it/s]
# mtypes: 1it [00:00,  2.35it/s]
# mtypes: 1it [00:00,  2.32it/s]
# mtypes: 1it [00:00,  2.11it/s]
# mtypes: 1it [00:00,  3.16it/s]
# mtypes: 1it [00:00,  2.04it/s]
# mtypes: 1it [00:00,  1.80it/s]
# mtypes: 1it [00:00,  1.58it/s]
# mtypes: 1it [00:00,  1.26it/s]
# mtypes: 1it [00:00,  2.23it/s]
# mtypes: 1it [00:00,  1.91it/s]
# mtypes: 1it [00:00,  1.79it/s]
# mtypes: 1it [00:00,  2.37it/s]
# mtypes: 1it [00:00,  1.58it/s]
# mtypes: 1it [00:00,  1.44it/s]
# mtypes: 1it [00:00,  1.88it/s]
# mtypes: 1it [00:00,  1.84it/s]
# mtypes: 1it [00:01,  1.13s/it]
# mtypes: 1it [00:00,  1.41it/s]
# mtypes: 1it [00:00,  2.30it/s]
# mtypes: 1it [00:00,  1.48it/s]
# mtypes: 1it [00:00,  1.24it/s]
# mtypes: 1it [00:00,  1.97it/s]
# mtypes: 1it [00:00,  1.31it/s]
# mtypes: 1it [00:00,  2.48it/s]
# mtypes: 1it [00:00,  2.05it/s]
# mtypes: 1it [00:00,  1.10it/s]
# mtypes: 1it [00:00,  1.42it/s]
# mtypes: 1it [00:00,  1.89it/s]
# mtypes: 1it [00:00,  1.99it/s]
# mtypes: 1it [00:00,  2.26it/s]
# mtypes: 1it [00:00,  1.54it/s]
# mtypes: 1it [00:00,  2.23it/s]
# mtypes: 1it [00:00,  2.80it/s]
# mtypes: 1it [00:00,  1.68it/s]
# mtypes: 1it [00:00,  2.52it/s]
# mtypes: 1it [00:00,  2.08it/s]
# mtypes: 1it [00:00,  2.24it/s]
# mtypes: 1it [00:00,  1.77it/s]
# mtypes: 1it [00:00,  2.08it/s]
# mtypes: 1it [00:00,  2.83it/s]
# mtypes: 1it [00:00,  1.75it/s]
# mtypes: 1it [00:00,  1.34it/s]
# mtypes: 1it [00:00,  1.70it/s]
# mtypes: 1it [00:00,  2.23it/s]
# mtypes: 1it [00:00,  2.04it/s]
# mtypes: 1it [00:00,  2.90it/s]
# mtypes: 1it [00:00,  1.88it/s]
# mtypes: 1it [00:00,  1.96it/s]
# mtypes: 1it [00:00,  1.87it/s]
# mtypes: 1it [00:00,  2.19it/s]
# mtypes: 1it [00:00,  2.10it/s]
# mtypes: 1it [00:00,  2.22it/s]
# mtypes: 1it [00:00,  1.82it/s]
# mtypes: 1it [00:00,  1.51it/s]
# mtypes: 1it [00:00,  2.51it/s]
# mtypes: 1it [00:00,  2.48it/s]
# mtypes: 1it [00:00,  1.78it/s]
# mtypes: 1it [00:00,  1.65it/s]
# mtypes: 1it [00:00,  2.14it/s]
# mtypes: 1it [00:00,  1.97it/s]
# mtypes: 1it [00:00,  2.42it/s]
# mtypes: 1it [00:00,  2.68it/s]
# mtypes: 1it [00:00,  2.53it/s]
# mtypes: 1it [00:00,  1.81it/s]
# mtypes: 1it [00:00,  2.31it/s]
# mtypes: 1it [00:00,  2.14it/s]
# mtypes: 1it [00:00,  2.44it/s]
# mtypes: 1it [00:00,  2.06it/s]
# mtypes: 1it [00:00,  1.63it/s]
# mtypes: 1it [00:00,  1.85it/s]
# mtypes: 1it [00:00,  1.86it/s]
# mtypes: 1it [00:00,  1.93it/s]
# mtypes: 1it [00:00,  1.74it/s]
# mtypes: 1it [00:00,  2.23it/s]
# mtypes: 1it [00:00,  1.93it/s]
# mtypes: 1it [00:00,  1.95it/s]
# mtypes: 1it [00:00,  2.40it/s]
# mtypes: 1it [00:00,  2.28it/s]
# mtypes: 1it [00:00,  1.52it/s]
# mtypes: 1it [00:00,  2.20it/s]
# mtypes: 1it [00:00,  1.36it/s]
# mtypes: 1it [00:00,  3.13it/s]
# mtypes: 1it [00:00,  1.41it/s]
# mtypes: 1it [00:00,  1.42it/s]
# mtypes: 1it [00:00,  2.73it/s]
# mtypes: 1it [00:00,  1.97it/s]
# mtypes: 1it [00:00,  1.72it/s]
# mtypes: 1it [00:00,  2.36it/s]
# mtypes: 1it [00:00,  2.55it/s]
# mtypes: 1it [00:00,  2.12it/s]
# mtypes: 1it [00:00,  1.85it/s]
# mtypes: 1it [00:00,  2.09it/s]
# mtypes: 1it [00:00,  2.05it/s]
# mtypes: 1it [00:00,  1.47it/s]
# mtypes: 1it [00:00,  1.46it/s]
# mtypes: 1it [00:00,  2.33it/s]
# mtypes: 1it [00:00,  2.52it/s]
# mtypes: 1it [00:00,  2.00it/s]
# mtypes: 1it [00:00,  2.52it/s]
# mtypes: 1it [00:00,  1.36it/s]
# mtypes: 1it [00:00,  2.01it/s]
# mtypes: 1it [00:00,  2.29it/s]
# mtypes: 1it [00:00,  1.41it/s]
# mtypes: 1it [00:00,  2.56it/s]
# mtypes: 1it [00:00,  2.11it/s]
# mtypes: 1it [00:00,  1.92it/s]
# mtypes: 1it [00:00,  3.34it/s]
# mtypes: 1it [00:00,  1.76it/s]
# mtypes: 1it [00:00,  1.90it/s]
# mtypes: 1it [00:00,  1.39it/s]
# mtypes: 1it [00:00,  1.21it/s]
# mtypes: 1it [00:00,  2.48it/s]
# mtypes: 1it [00:00,  1.99it/s]
# mtypes: 1it [00:00,  2.24it/s]
# mtypes: 1it [00:00,  1.80it/s]
# mtypes: 1it [00:00,  2.46it/s]
# mtypes: 1it [00:00,  1.39it/s]
# mtypes: 1it [00:00,  1.79it/s]
# mtypes: 1it [00:00,  2.05it/s]
# mtypes: 1it [00:00,  2.68it/s]
# mtypes: 1it [00:00,  1.17it/s]
# mtypes: 1it [00:00,  2.00it/s]
# mtypes: 1it [00:00,  1.70it/s]
# mtypes: 1it [00:00,  1.76it/s]
# mtypes: 1it [00:00,  2.63it/s]
# mtypes: 1it [00:00,  2.47it/s]
# mtypes: 1it [00:00,  2.01it/s]
# mtypes: 1it [00:00,  2.18it/s]
# mtypes: 1it [00:00,  1.83it/s]
# mtypes: 1it [00:00,  2.87it/s]
# mtypes: 1it [00:00,  2.31it/s]
# mtypes: 1it [00:00,  2.05it/s]
# mtypes: 1it [00:00,  2.17it/s]
# mtypes: 1it [00:00,  2.17it/s]
# mtypes: 1it [00:00,  2.58it/s]
# mtypes: 1it [00:00,  2.11it/s]
# mtypes: 1it [00:00,  2.15it/s]
# mtypes: 1it [00:00,  1.84it/s]
# mtypes: 1it [00:00,  2.51it/s]
# mtypes: 1it [00:00,  2.21it/s]
# mtypes: 1it [00:00,  2.35it/s]
# mtypes: 1it [00:00,  2.54it/s]
# mtypes: 1it [00:00,  1.79it/s]
# mtypes: 1it [00:00,  2.12it/s]
# mtypes: 1it [00:00,  2.68it/s]
# mtypes: 1it [00:00,  2.10it/s]
# mtypes: 1it [00:00,  2.06it/s]
# mtypes: 1it [00:00,  1.33it/s]
# mtypes: 1it [00:00,  1.86it/s]
# mtypes: 1it [00:00,  1.99it/s]
# mtypes: 1it [00:00,  1.71it/s]
# mtypes: 1it [00:00,  1.74it/s]
# mtypes: 1it [00:00,  1.89it/s]
# mtypes: 1it [00:00,  1.48it/s]
# mtypes: 1it [00:00,  2.43it/s]
# mtypes: 1it [00:00,  1.76it/s]
# mtypes: 1it [00:00,  2.21it/s]
# mtypes: 1it [00:00,  2.52it/s]
# mtypes: 1it [00:00,  1.78it/s]
# mtypes: 1it [00:00,  2.13it/s]
# mtypes: 1it [00:00,  1.22it/s]
# mtypes: 1it [00:00,  2.11it/s]
# mtypes: 1it [00:00,  1.46it/s]
# mtypes: 1it [00:00,  1.36it/s]
# mtypes: 1it [00:00,  1.82it/s]
# mtypes: 1it [00:00,  2.55it/s]
# mtypes: 1it [00:00,  1.74it/s]
# mtypes: 1it [00:00,  1.80it/s]
# mtypes: 1it [00:00,  2.02it/s]
# mtypes: 1it [00:00,  2.29it/s]
# mtypes: 1it [00:00,  2.15it/s]
# mtypes: 1it [00:00,  2.22it/s]
# mtypes: 1it [00:00,  2.53it/s]
# mtypes: 1it [00:00,  1.68it/s]
# mtypes: 1it [00:00,  2.10it/s]
# mtypes: 1it [00:00,  3.14it/s]
# mtypes: 1it [00:00,  1.19it/s]
# mtypes: 1it [00:00,  2.28it/s]
# mtypes: 1it [00:00,  1.70it/s]
# mtypes: 1it [00:00,  2.04it/s]
# mtypes: 1it [00:00,  3.03it/s]
# mtypes: 1it [00:00,  1.28it/s]
# mtypes: 1it [00:00,  1.54it/s]
# mtypes: 1it [00:00,  2.63it/s]
# mtypes: 1it [00:00,  1.18it/s]
# mtypes: 1it [00:00,  2.32it/s]
# mtypes: 1it [00:00,  2.25it/s]
# mtypes: 1it [00:00,  1.31it/s]
# mtypes: 1it [00:00,  2.18it/s]
# mtypes: 1it [00:00,  1.88it/s]
# mtypes: 1it [00:01,  1.03s/it]
# mtypes: 1it [00:00,  2.29it/s]
# mtypes: 1it [00:00,  2.52it/s]
# mtypes: 1it [00:00,  2.37it/s]
# mtypes: 1it [00:00,  1.62it/s]
# mtypes: 1it [00:00,  2.23it/s]
# mtypes: 1it [00:00,  1.27it/s]
# mtypes: 1it [00:00,  1.83it/s]
# mtypes: 1it [00:00,  1.78it/s]
# mtypes: 1it [00:00,  2.40it/s]
# mtypes: 1it [00:00,  1.86it/s]
# mtypes: 1it [00:00,  1.73it/s]
# mtypes: 1it [00:00,  3.70it/s]
# mtypes: 1it [00:00,  2.05it/s]
# mtypes: 1it [00:00,  2.50it/s]
# mtypes: 1it [00:00,  2.09it/s]
# mtypes: 1it [00:00,  1.53it/s]
# mtypes: 1it [00:00,  1.44it/s]
# mtypes: 1it [00:00,  2.37it/s]
# mtypes: 1it [00:00,  2.30it/s]
# mtypes: 1it [00:00,  1.24it/s]
# mtypes: 1it [00:00,  1.48it/s]
# mtypes: 1it [00:00,  2.57it/s]
# mtypes: 1it [00:00,  1.42it/s]
# mtypes: 1it [00:00,  3.38it/s]
# mtypes: 1it [00:00,  2.54it/s]
# mtypes: 1it [00:00,  2.10it/s]
# mtypes: 1it [00:00,  1.49it/s]
# mtypes: 1it [00:00,  1.56it/s]
# mtypes: 1it [00:00,  2.48it/s]
# mtypes: 1it [00:00,  2.25it/s]
# mtypes: 1it [00:00,  2.16it/s]
# mtypes: 1it [00:00,  2.17it/s]
# mtypes: 1it [00:00,  2.00it/s]
# mtypes: 1it [00:00,  2.72it/s]
# mtypes: 1it [00:00,  2.09it/s]
# mtypes: 1it [00:00,  1.36it/s]
# mtypes: 1it [00:00,  1.79it/s]
# mtypes: 1it [00:00,  2.04it/s]
# mtypes: 1it [00:00,  1.26it/s]
# mtypes: 1it [00:00,  1.86it/s]
# mtypes: 1it [00:00,  1.37it/s]
# mtypes: 1it [00:00,  1.02it/s]
# mtypes: 1it [00:00,  1.90it/s]
# mtypes: 1it [00:00,  2.27it/s]
# mtypes: 1it [00:01,  1.01s/it]
# mtypes: 1it [00:00,  2.18it/s]
# mtypes: 1it [00:00,  1.90it/s]
# mtypes: 1it [00:00,  1.55it/s]
# mtypes: 1it [00:00,  2.98it/s]
# mtypes: 1it [00:00,  1.78it/s]
# mtypes: 1it [00:00,  2.67it/s]
# mtypes: 1it [00:00,  1.37it/s]
# mtypes: 1it [00:00,  1.43it/s]
# mtypes: 1it [00:00,  1.57it/s]
# mtypes: 1it [00:00,  1.69it/s]
# mtypes: 1it [00:00,  2.98it/s]
# mtypes: 1it [00:00,  1.52it/s]
# mtypes: 1it [00:00,  1.76it/s]
# mtypes: 1it [00:00,  1.67it/s]
# mtypes: 1it [00:00,  2.03it/s]
# mtypes: 1it [00:00,  2.08it/s]
# mtypes: 1it [00:00,  1.43it/s]
# mtypes: 1it [00:00,  2.02it/s]
# mtypes: 1it [00:00,  1.45it/s]
# mtypes: 1it [00:00,  1.58it/s]
# mtypes: 1it [00:00,  2.65it/s]
# mtypes: 1it [00:00,  2.30it/s]
# mtypes: 1it [00:00,  2.03it/s]
# mtypes: 1it [00:00,  1.17it/s]
# mtypes: 1it [00:00,  1.27it/s]
# mtypes: 1it [00:00,  1.40it/s]
# mtypes: 1it [00:00,  2.22it/s]
# mtypes: 1it [00:00,  2.30it/s]
# mtypes: 1it [00:00,  1.85it/s]
# mtypes: 1it [00:00,  2.73it/s]
# mtypes: 1it [00:00,  2.16it/s]
# mtypes: 1it [00:00,  2.79it/s]
# mtypes: 1it [00:00,  1.24it/s]
# mtypes: 1it [00:00,  1.99it/s]
# mtypes: 1it [00:00,  1.88it/s]
# mtypes: 1it [00:00,  3.12it/s]
# mtypes: 1it [00:00,  1.32it/s]
# mtypes: 1it [00:00,  1.52it/s]
# mtypes: 1it [00:00,  1.59it/s]
# mtypes: 1it [00:00,  1.10it/s]
# mtypes: 1it [00:00,  2.15it/s]
# mtypes: 1it [00:00,  2.18it/s]
# mtypes: 1it [00:00,  1.51it/s]
# mtypes: 1it [00:00,  2.66it/s]
# mtypes: 1it [00:00,  2.55it/s]
# mtypes: 1it [00:00,  2.44it/s]
# mtypes: 1it [00:00,  1.81it/s]
# mtypes: 1it [00:00,  1.71it/s]
# mtypes: 1it [00:00,  1.48it/s]
# mtypes: 1it [00:00,  1.47it/s]
# mtypes: 1it [00:00,  1.76it/s]
# mtypes: 1it [00:00,  1.40it/s]
# mtypes: 1it [00:00,  1.13it/s]
# mtypes: 1it [00:00,  1.32it/s]
# mtypes: 1it [00:00,  1.46it/s]
# mtypes: 1it [00:00,  2.26it/s]
# mtypes: 1it [00:00,  1.68it/s]
# mtypes: 1it [00:00,  1.89it/s]
# mtypes: 1it [00:00,  1.98it/s]
# mtypes: 1it [00:00,  1.20it/s]
# mtypes: 1it [00:00,  1.77it/s]
# mtypes: 1it [00:00,  1.41it/s]
# mtypes: 1it [00:00,  1.91it/s]
# mtypes: 1it [00:00,  2.71it/s]
# mtypes: 1it [00:00,  1.28it/s]
# mtypes: 1it [00:00,  2.61it/s]
# mtypes: 1it [00:00,  1.98it/s]
# mtypes: 1it [00:00,  1.54it/s]
# mtypes: 1it [00:00,  2.63it/s]
# mtypes: 1it [00:00,  2.15it/s]
# mtypes: 1it [00:00,  2.24it/s]
# mtypes: 1it [00:00,  1.76it/s]
# mtypes: 1it [00:00,  1.09it/s]
# mtypes: 1it [00:00,  1.02it/s]
# mtypes: 1it [00:00,  2.89it/s]
# mtypes: 1it [00:00,  2.41it/s]
# mtypes: 1it [00:00,  1.36it/s]
# mtypes: 1it [00:00,  2.17it/s]
# mtypes: 1it [00:00,  1.54it/s]
# mtypes: 1it [00:00,  1.64it/s]
# mtypes: 1it [00:00,  2.06it/s]
# mtypes: 1it [00:00,  1.84it/s]
# mtypes: 1it [00:00,  2.05it/s]
# mtypes: 1it [00:00,  2.46it/s]
# mtypes: 1it [00:00,  1.95it/s]
# mtypes: 1it [00:00,  2.38it/s]
# mtypes: 1it [00:00,  1.70it/s]
# mtypes: 1it [00:00,  2.47it/s]
# mtypes: 1it [00:00,  2.50it/s]
# mtypes: 1it [00:01,  1.04s/it]
# mtypes: 1it [00:00,  2.00it/s]
# mtypes: 1it [00:00,  1.05it/s]
# mtypes: 1it [00:00,  1.68it/s]
# mtypes: 1it [00:00,  1.39it/s]
# mtypes: 1it [00:00,  1.81it/s]
# mtypes: 1it [00:00,  1.78it/s]
# mtypes: 1it [00:00,  1.65it/s]
# mtypes: 1it [00:00,  1.34it/s]
# mtypes: 1it [00:00,  1.70it/s]
# mtypes: 1it [00:00,  1.95it/s]
# mtypes: 1it [00:00,  1.92it/s]
# mtypes: 1it [00:00,  2.01it/s]
# mtypes: 1it [00:00,  1.38it/s]
# mtypes: 1it [00:00,  1.38it/s]
# mtypes: 1it [00:00,  2.09it/s]
# mtypes: 1it [00:00,  1.61it/s]
# mtypes: 1it [00:00,  3.79it/s]
# mtypes: 1it [00:00,  1.53it/s]
# mtypes: 1it [00:00,  1.61it/s]
# mtypes: 1it [00:01,  1.01s/it]
# mtypes: 1it [00:00,  1.72it/s]
# mtypes: 1it [00:00,  1.73it/s]
# mtypes: 1it [00:00,  1.40it/s]
# mtypes: 1it [00:00,  1.43it/s]
# mtypes: 1it [00:00,  1.83it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  2.80it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  2.87it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:01,  1.25s/it]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  3.77it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  8.59it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  1.15it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  1.24it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  1.05it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  1.38it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  4.26it/s]
# mtypes: 0it [00:00, ?it/s]/gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /gpfs/bbp.cscs.ch/project/proj85/laquitai/spikebias_paper/envs/spikinterf0_100_5/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# mtypes: 1it [00:00,  1.75it/s]

# %% [markdown]
# # References
#
# https://neurom.readthedocs.io/en/latest/features.html#
