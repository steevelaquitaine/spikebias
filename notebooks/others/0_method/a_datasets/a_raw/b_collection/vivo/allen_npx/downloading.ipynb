# %% [markdown]
# # Downloading

# %% [markdown]
# #### Setup
#
# create and activate env from `allensdk.txt`

# %%
# %load_ext autoreload
# %autoreload 2

import os
from allensdk.brain_observatory.ecephys.ecephys_project_cache import EcephysProjectCache

# move to project path
PROJ_PATH = "/gpfs/bbp.cscs.ch/project/proj68/home/laquitai/bernstein_2023/"
os.chdir(PROJ_PATH)

from src.nodes.utils import get_config
from src.nodes.dataeng.allen import allen

# SETUP PARAMETERS
EXPERIMENT = "supp/allen_neuropixels"  # the experiment 
SIMULATION_DATE = "2023_08_30"    # the run (date)
data_conf, param_conf = get_config(EXPERIMENT, SIMULATION_DATE).values()
RAW_DATA = data_conf["raw_data"]["input"]
DOWNLOAD_COMPLETE_DATASET = True
manifest_path = os.path.join(RAW_DATA, "manifest.json")

# session data with optotagged parvalbmin interneurons (reliable laser)
# 1.82 GB
PARV_SESSION_ID = 829720705

# session data with optotagged somatostatin interneurons (reliable laser)
# 2.82 GB
SST_SESSION_ID = 839068429   

# session data with optotagged vip interneurons (reliable laser)
# 2 GB
VIP_SESSION_ID = 835479236
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2023-09-01 13:29:38,861 - root - utils.py - get_config - INFO - Reading experiment config.
# 2023-09-01 13:29:38,865 - root - utils.py - get_config - INFO - Reading experiment config. - done

# %% [markdown]
# ### Download Parvalbumin optotagged dataset

# %%
sessions = allen.find_sessions(manifest_path, interneuron="Pvalb")
sessions.iloc[PARV_SESSION_ID]
# Out:
# 2023-09-01 12:44:16,027 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 12:44:16,035 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 12:44:16,686 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 12:44:16,787 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 12:44:16,793 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 12:44:16,919 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 12:44:16,993 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 12:44:16,998 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# ...

# %%
# download data from a session
session = allen.download_data_from_a_session(PARV_SESSION_ID, manifest_path)

# unit-test
assert session.ecephys_session_id == PARV_SESSION_ID, "wrong session"
# Out:
# 2023-09-01 11:48:57,668 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 11:48:57,669 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 11:48:57,675 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 11:48:57,682 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 11:48:58,290 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 11:48:58,371 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 11:48:58,376 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 11:48:58,502 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# ...

# %% [markdown]
# ### Download Somatostatin optotagged dataset

# %%
# find Somatostatin optotagged sessions
sessions = allen.find_sessions(manifest_path, interneuron="Sst")
sessions.iloc[SST_SESSION_ID]
# Out:
# 2023-09-01 12:44:52,947 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 12:44:52,954 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 12:44:53,655 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 12:44:53,740 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 12:44:53,745 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 12:44:53,870 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 12:44:53,942 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 12:44:53,947 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# ...

# %%
# takes 8 min

# download data from a session
session = allen.download_data_from_a_session(SST_SESSION_ID, manifest_path)

# unit-test
assert session.ecephys_session_id == SST_SESSION_ID, "wrong session"
# Out:
# 2023-09-01 12:47:18,099 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 12:47:18,112 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 12:47:18,128 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 12:47:18,147 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 12:47:18,824 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 12:47:18,909 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 12:47:18,913 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 12:47:19,039 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# ...

# %% [markdown]
# ### Download VIP optotagged dataset

# %%
# find Somatostatin optotagged sessions
sessions = allen.find_sessions(manifest_path, interneuron="Vip")
sessions.iloc[VIP_SESSION_ID]
# Out:
# 2023-09-01 13:28:58,619 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 13:28:58,624 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 13:28:59,319 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 13:28:59,402 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 13:28:59,407 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 13:28:59,538 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 13:28:59,611 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 13:28:59,615 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# ...

# %%
# takes 6 min

# download data from a session
session = allen.download_data_from_a_session(VIP_SESSION_ID, manifest_path)

# unit-test
assert session.ecephys_session_id == VIP_SESSION_ID, "wrong session"
# Out:
# 2023-09-01 13:30:15,484 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 13:30:15,485 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 13:30:15,490 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 13:30:15,499 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 13:30:16,091 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 13:30:16,174 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 13:30:16,190 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# 2023-09-01 13:30:16,324 - call_caching - caching_utilities.py - call_caching - INFO - Reading data from cache
# ...
