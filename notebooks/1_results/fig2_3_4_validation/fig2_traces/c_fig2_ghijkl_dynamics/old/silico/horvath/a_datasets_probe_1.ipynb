# %% [markdown]
# # Datasets
#
#
# author: steeve.laquitaine@epfl.ch
# date: 2023.10.30
# last modified: 2023.10.30
# status:  OK
# display-status: up-to-date
# regression: None

# %% [markdown]
# ## Setup
#
# create and activate env from `npx_10m_384ch_unit_classes.txt`

# %%
# listen to changes
# %load_ext autoreload
# %autoreload 2

import os
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np 

# set project path
PROJ_PATH = "/gpfs/bbp.cscs.ch/project/proj68/home/laquitai/sfn_2023/"

os.chdir(PROJ_PATH)

from src.nodes.utils import get_config
from src.nodes.load import load_campaign_params
from src.nodes.dataeng.silico import recording, probe_wiring
from src.nodes.prepro import preprocess
from src.nodes.truth.silico import ground_truth
from src.nodes.dataeng.lfp_only import stacking

# SETUP PARAMETERS
EXPERIMENT = "silico_horvath"
SIMULATION_DATE = "probe_1"
GAIN = 1e5
data_conf, param_conf = get_config(EXPERIMENT, SIMULATION_DATE).values()
RAW_DATASET = data_conf["dataeng"]["campaign"]["output"]["trace_file_path"]
N_CONTACTS = 128
# Out:
# 2023-10-30 18:09:16,535 - root - utils.py - get_config - INFO - Reading experiment config.
# 2023-10-30 18:09:16,550 - root - utils.py - get_config - INFO - Reading experiment config. - done

# %% [markdown]
# ### Raw traces
#
# TODO:
#
# * delete 129th contact. It is a test one.

# %%
DURATION = 20 # in ms
Y_STEP = 600

# get traces
raw_traces = pd.read_pickle(RAW_DATASET)

# plot
fig, ax = plt.subplots(1,1)
pos_up = 0
for contact_i in np.arange(0, N_CONTACTS, 1):
    pos_up += Y_STEP
    ax.plot(raw_traces.loc[raw_traces.index<DURATION, contact_i] + pos_up, color="pink");

# %% [markdown]
# ### Rescaled traces (gain and offset)

# %%
Y_STEP = 600
WIND = 8

# get rescaled traces
Recording = recording.load(data_conf);
resc_traces = Recording.get_traces()[:,:128];

# get 20 ms (like Trautmann et al 2023)
sampfreq = 20000    # hz
duration = 20       # in ms
n_timepoints = int(duration*sampfreq/1000)

# plot
fig, ax = plt.subplots(1,1)
pos_up = 0
for contact_i in np.arange(0, N_CONTACTS,1):
    pos_up += Y_STEP
    #ax.plot(resc_traces[:n_timepoints, contact_i] + pos_up, color="pink", linewidth=1);
    ax.plot(resc_traces[WIND*n_timepoints:(WIND+1)*n_timepoints, contact_i] + pos_up, color="pink", linewidth=1);

# check rescaling correct
rescaled = raw_traces.loc[:, 0]*GAIN
resc_offsetted = rescaled - np.mean(rescaled)

# plot
fig, ax = plt.subplots(1,1);
plt.plot(resc_offsetted.values[:n_timepoints], color="pink", label="raw * GAIN - offset contact 0");
plt.plot(resc_traces[:n_timepoints, 0], "--", label="Recording dataset - contact 0");

plt.legend();

# %% [markdown]
# ### Preprocessed traces

# %%
Y_STEP = 600
#WIND = 7
WIND = 8

# get preprocessed
Recording = preprocess.load(data_conf)
traces = Recording.get_traces()[:,:128]

# plot
fig, ax = plt.subplots(1,1)
pos_up = 0
for contact_i in np.arange(0, N_CONTACTS, 1):
    pos_up += Y_STEP
    ax.plot(traces[WIND*n_timepoints:(WIND+1)*n_timepoints, contact_i] + pos_up, color="pink");
