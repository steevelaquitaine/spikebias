# %% [markdown]
# ### Qmetrics

# %%
import os
import pandas as pd

PROJ_PATH = "/gpfs/bbp.cscs.ch/project/proj85/home/laquitai/preprint_2023/"
os.chdir(PROJ_PATH)

from src.nodes.utils import get_config

data_cfg, _ = get_config("silico_neuropixels", "concatenated").values()

QMETRICS_PATH = data_cfg["postprocessing"]["qmetrics"]["truth"]
# Out:
# 2024-05-09 20:57:31,812 - root - utils.py - get_config - INFO - Reading experiment config.
# 2024-05-09 20:57:31,879 - root - utils.py - get_config - INFO - Reading experiment config. - done

# %%
qmetrics = pd.read_csv(QMETRICS_PATH)
# Out:
#       Unnamed: 0  amplitude_cutoff  amplitude_cv  amplitude_median  \
# 0          12165               NaN           NaN          2.748219
# 1          16652               NaN           NaN          2.713188
# 2          18371               NaN           NaN          4.207945
# 3          19690               NaN           NaN          1.231333
# 4          21040               NaN           NaN          3.990454
# ...          ...               ...           ...               ...
# 1383     4223302               NaN           NaN          2.341356
# 1384     4225319               NaN           NaN          2.861920
# 1385     4228700          0.015797           NaN          3.143923
# 1386     4229218               NaN           NaN          2.629769
# 1387     4229506          0.004088           NaN          8.978893
#
#       firing_range  firing_rate  isi_violations_ratio  isi_violations_count  \
# 0              0.2     0.024781                   0.0                     0
# 1              0.2     0.015063                   0.0                     0
# 2              0.2     0.062196                   0.0                     0
# 3              0.0     0.009232                   0.0                     0
# 4              0.2     0.043732                   0.0                     0
# ...            ...          ...                   ...                   ...
# 1383           0.2     0.012148                   0.0                     0
# 1384           0.0     0.002915                   0.0                     0
# 1385           0.8     2.026726                   0.0                     0
# 1386           0.4     0.088921                   0.0                     0
# 1387           0.8     0.625365                   0.0                     0
#
#       num_spikes  presence_ratio  rp_contamination  rp_violations  sd_ratio  \
# 0             51        0.705882               0.0              0       NaN
# 1             31        0.558824               0.0              0       NaN
# 2            128        1.000000               0.0              0       NaN
# 3             19        0.352941               0.0              0       NaN
# 4             90        0.941176               0.0              0       NaN
# ...          ...             ...               ...            ...       ...
# 1383          25        0.500000               0.0              0       NaN
# 1384           6        0.117647               0.0              0       NaN
# 1385        4171        1.000000               0.0              0       NaN
# 1386         183        0.970588               0.0              0       NaN
# 1387        1287        1.000000               0.0              0       NaN
#
#       sliding_rp_violation       snr  sync_spike_2  sync_spike_4  sync_spike_8
# 0                      NaN  1.037487      0.000000           0.0           0.0
# 1                      NaN  0.984630      0.000000           0.0           0.0
# 2                      NaN  0.938671      0.007812           0.0           0.0
# 3                      NaN  1.736147      0.052632           0.0           0.0
# 4                      NaN  0.921596      0.044444           0.0           0.0
# ...                    ...       ...           ...           ...           ...
# 1383                   NaN  4.068130      0.040000           0.0           0.0
# 1384                   NaN  3.579617      0.000000           0.0           0.0
# 1385                 0.015  0.549198      0.012707           0.0           0.0
# 1386                   NaN  0.386467      0.010929           0.0           0.0
# 1387                 0.145  1.724258      0.012432           0.0           0.0
#
# [1388 rows x 18 columns]

# %%
qmetrics["snr"].hist(bins=100)
# Out:
# <Axes: >
