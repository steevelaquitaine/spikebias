# %% [markdown]
# # Feature importance

# %%
from matplotlib import pyplot as plt
import os

PROJ_PATH = "/gpfs/bbp.cscs.ch/project/proj85/home/laquitai/preprint_2023"
os.chdir(PROJ_PATH)


FIG_SIZE = (2, 1)
plt.rcParams["figure.figsize"] = (4, 1)
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = 6
plt.rcParams["lines.linewidth"] = 0.2
plt.rcParams["axes.linewidth"] = 0.5
plt.rcParams["axes.spines.top"] = False
plt.rcParams["axes.spines.right"] = False
plt.rcParams["xtick.major.width"] = 0.3
plt.rcParams["xtick.minor.size"] = 0.1
plt.rcParams["xtick.major.size"] = 1.5
plt.rcParams["ytick.major.size"] = 1.5
plt.rcParams["ytick.major.width"] = 0.3
legend_cfg = {"frameon": False, "handletextpad": 0.1}
savefig_cfg = {"transparent": True, "dpi": 300}
# print(plt.rcParams.keys())

# %%
fig, axis = plt.subplots(1, figsize=(2 * 0.5, 1))
axis.bar(
    ["cADpyr", "Firing rate", "L2", "L3", "L4", "Distance", "SNR"],
    [0.7, 0.58, 0.51, 0.48, -0.12, -0.27, -0.28],
    color="k",
)

axis.set_xticklabels(
    ["cADpyr", "Firing rate", "L2", "L3", "L4", "Distance", "SNR"],
    rotation=45,
    ha="right",
)
axis.set_ylabel("Accuracy change per\n unit of feature (ratio)")
plt.savefig(
    "figures/3_bias/svg/prediction_spont_accuracy_change_per_feature.svg", **savefig_cfg
)
# Out:
# /tmp/ipykernel_281229/3078571304.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axis.set_xticklabels(
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...

# %%
fig, axis = plt.subplots(1, figsize=(2 * 0.5, 1))

axis.bar(
    [
        "Exc. unit",
        "Firing rate",
        "Spatial extent",
        "L4",
        "L5",
        "L6",
        "Distance",
    ],
    [0.73, 0.51, 0.37, 0.03, -0.08, -0.17, -0.34],
    color="k",
)
axis.set_xticklabels(
    [
        "Exc. unit",
        "Firing rate",
        "Spatial extent",
        "L4",
        "L5",
        "L6",
        "Distance",
    ],
    rotation=45,
    ha="right",
)
axis.set_ylabel("Accuracy change per\n unit of feature (ratio)")
plt.savefig(
    "figures/3_bias/svg/prediction_evoked_accuracy_change_per_feature.svg",
    **savefig_cfg
)
# Out:
# /tmp/ipykernel_281229/2388578098.py:16: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axis.set_xticklabels(
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...
