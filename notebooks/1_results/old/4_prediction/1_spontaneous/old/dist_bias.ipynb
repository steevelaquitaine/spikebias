# %% [markdown]
# # Population biases
#
# author: steeve.laquitaine@epfl.ch
#
# purpose: plot firing rate density biases for Reyes and neuropixels probes

# %% [markdown]
# ## Setup
#
# Setup virtual env
#
# ```bash
# pip3.9 install -r requirements_kilosort_silico.txt
# ```

# %%
# SETUP PACKAGES 
# %load_ext autoreload
# %autoreload 2
import os 

# SET PROJECT PATH
PROJ_PATH = "/gpfs/bbp.cscs.ch/project/proj68/home/laquitai/spike-sorting"
os.chdir(PROJ_PATH)

EXPERIMENT = "silico_neuropixels"
SIMULATION_DATE = "2023_02_19"

from src.nodes.utils import get_config
from src.pipes.figures import run_population_bias_silico_reyes_2023_01_13, run_population_bias_silico_neuropix_2023_02_19

# SET RUN CONFIG
data_conf, _ = get_config(EXPERIMENT, SIMULATION_DATE).values()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2023-04-25 11:57:24,279 - root - utils.py - get_config - INFO - Reading experiment config.
# 2023-04-25 11:57:24,355 - root - utils.py - get_config - INFO - Reading experiment config. - done
# 2023-04-25 11:57:24,362 - root - utils.py - get_config - INFO - Reading experiment config.
# 2023-04-25 11:57:24,443 - root - utils.py - get_config - INFO - Reading experiment config. - done

# %%
fig = run_population_bias_silico_reyes_2023_01_13.run()
# Out:
# 2023-04-25 11:56:59,875 - root - bias.py - get_recording - INFO - loading SpikeInterface Recording Extractor ...
# 2023-04-25 11:56:59,969 - root - bias.py - get_recording - INFO - loading SpikeInterface Recording Extractor - done in 0.1
# 2023-04-25 11:56:59,975 - root - bias.py - get_recording - INFO - loading SpikeInterface Recording object ...
# 2023-04-25 11:57:00,051 - root - bias.py - get_recording - INFO - loading SpikeInterface recording - done in 0.1
# 2023-04-25 11:57:00,059 - root - bias.py - get_ground_truth - INFO - loading already processed true sorting ...
# 2023-04-25 11:57:00,090 - root - bias.py - get_ground_truth - INFO - loading already processed true sorting - done in 0.0
# Setting KILOSORT3_PATH environment variable for subprocess calls to: /gpfs/bbp.cscs.ch/project/proj68/home/laquitai/spike-sorting/sorters_packages/Kilosort3
# 2023-04-25 11:57:00,148 - root - bias.py - sort_with_KS3 - INFO - loading kilosort3 sorting ...
# ...

# %%
fig = run_population_bias_silico_neuropix_2023_02_19.run()
# Out:
# 2023-04-25 11:57:38,251 - root - bias.py - get_recording - INFO - loading SpikeInterface Recording Extractor ...
# 2023-04-25 11:57:38,306 - root - bias.py - get_recording - INFO - loading SpikeInterface Recording Extractor - done in 0.1
# 2023-04-25 11:57:38,309 - root - bias.py - get_recording - INFO - loading SpikeInterface Recording object ...
# 2023-04-25 11:57:38,388 - root - bias.py - get_recording - INFO - loading SpikeInterface recording - done in 0.1
# 2023-04-25 11:57:38,394 - root - bias.py - get_ground_truth - INFO - loading already processed true sorting ...
# 2023-04-25 11:57:38,441 - root - bias.py - get_ground_truth - INFO - loading already processed true sorting - done in 0.0
# Setting KILOSORT3_PATH environment variable for subprocess calls to: /gpfs/bbp.cscs.ch/project/proj68/home/laquitai/spike-sorting/sorters_packages/Kilosort3
# 2023-04-25 11:57:38,519 - root - bias.py - sort_with_KS3 - INFO - loading kilosort3 sorting ...
# ...
