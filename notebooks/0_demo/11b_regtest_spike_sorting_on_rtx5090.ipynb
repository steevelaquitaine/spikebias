# %% [markdown]
# # Spike sorting on RTX 5090
#
# 10 min recording |
#
# author: laquitainesteeve@gmail.com
#
# Tested on an Ubuntu 24 with a 32GB VRAM Nvidia RTX 5090
#
# Execution time: 16 min

# %% [markdown]
# ## Setup
#
# Prerequisites:
#
# 1. Activate `demo` environment
#
# 2. Enable forward compatibility if your GPU and CUDA libraries are more recent and not supported by editing your matlab `startup.m` file to contain "parallel.gpu.enableCUDAForwardCompatibility(true)" and:
#
#     ```bash
#     # manually compile Kilosort3 with CUDA support for forward compatibility
#     sudo apt install gcc-11 g++-11 # install gcc 11 compiler
#     sudo update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-11 100 # enable temporary
#     cd /home/steeve/steeve/epfl/code/spikebias/dataset/01_intermediate/sorters/Kilosort3_buttw_forwcomp/CUDA/
#     matlab -batch mexGPUall  # compile matlab mex files
#     ```
#
# 3. Run notebook ss.run_sorter should work.
#
#
# You also also run spike sorting manually by replacing SpikeInterface's "run_kilosort.sh" script (created by ss.run_sorter) with and run:
#
#   ```bash
#   #/bin/bash -->
#   #manually compile Kilosort3 with CUDA support for forward compatibility
#   sudo apt install gcc-11 g++-11 # install gcc 11 compiler
#   sudo update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-11 100 # enable temporary
#
#   cd /home/steeve/steeve/epfl/code/spikebias/dataset/01_intermediate/sorters/Kilosort3_buttw_forwcomp/CUDA/
#   matlab -batch mexGPUall  # compile matlab mex files
#
#   run Kilosort3 with forward compatibility activated for that session
#   cd "/home/steeve/steeve/epfl/code/spikebias/SortingKS3/sorter_output"
#
#   matlab -nosplash -nodisplay -r "parallel.gpu.enableCUDAForwardCompatibility(true); kilosort3_master('/home/steeve/steeve/epfl/code/spikebias/SortingKS3/sorter_output', '/home/steeve/steeve/epfl/code/spikebias/dataset/01_intermediate/sorters/Kilosort3_buttw_forwcomp')"
#   ```

# %%
# %%time 
# %load_ext autoreload
# %autoreload 2

# import python packages
import os
from dandi.dandiapi import DandiAPIClient
import spikeinterface.extractors as se
import spikeinterface.sorters as ss
import spikeinterface as si
print("spikeinterface", si.__version__)

# project path
PROJ_PATH = "/home/steeve/steeve/epfl/code/spikebias/"
os.chdir(PROJ_PATH)

# import spikebias package
from src.nodes.sorting import sort_and_postprocess_10m

# recording parameters
REC_SECS = 600 
RECORDING_PATH = "./dataset/00_raw/recording_npx_spont/"

# sorting parameters
SORTER = "kilosort3"
SORTER_PATH = "/home/steeve/steeve/epfl/code/spikebias/dataset/01_intermediate/sorters/Kilosort3_buttw_forwcomp"
SORTING_OUTPUT = "./temp/SortingKS3/" 
SORTER_PARAMS = {
    "detect_threshold": 6,
    "projection_threshold": [9, 9],
    "preclust_threshold": 8,
    "car": True,
    "minFR": 0, # modified
    "minfr_goodchannels": 0, # modified
    "nblocks": 5,
    "sig": 20,
    "freq_min": 300,
    "sigmaMask": 30,
    "lam": 20.0,
    "nPCs": 3,
    "ntbuff": 64,
    "nfilt_factor": 4,
    "do_correction": True,
    "NT": 65792, # modified
    "AUCsplit": 0.8,
    "wave_length": 61,
    "keep_good_only": False,
    "skip_kilosort_preprocessing": False,
    "scaleproc": None,
    "save_rez_to_mat": False,
    "delete_tmp_files": ("matlab_files",),
    "delete_recording_dat": False,
}

# SET KS3 software environment variable
ss.Kilosort3Sorter.set_kilosort3_path(SORTER_PATH)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# spikeinterface 0.101.2
# Setting KILOSORT3_PATH environment variable for subprocess calls to: /home/steeve/steeve/epfl/code/spikebias/dataset/01_intermediate/sorters/Kilosort3_buttw_forwcomp
# CPU times: user 0 ns, sys: 341 μs, total: 341 μs
# Wall time: 300 μs

# %% [markdown]
# ## Spike sorting

# %%
# %%time

# load recording
Recording = si.load_extractor(RECORDING_PATH)
Recording = Recording.frame_slice(start_frame=0, end_frame=Recording.sampling_frequency*REC_SECS)
print('\n', Recording)

# spike sort
Sorting = ss.run_sorter(sorter_name = SORTER,
                        recording = Recording,
                        folder="./temp/SortingKS3",
                        remove_existing_folder = True,
                        verbose = True,
                        **SORTER_PARAMS)

print(Sorting.unit_ids)

# %%
# load old (reference) sorting and compare with sorting on RTX5090
SortingRef = si.load_extractor("/home/steeve/steeve/epfl/code/spikebias/dataset/01_intermediate/sorting/npx_evoked/SortingKS3")
print(len(SortingRef.unit_ids))
print(len(Sorting.unit_ids))
# Out:
# /home/steeve/steeve/epfl/code/spikebias/envs/demo/lib/python3.10/site-packages/spikeinterface/core/base.py:1129: UserWarning: Versions are not the same. This might lead to compatibility errors. Using spikeinterface==0.100.6 is recommended
#   warnings.warn(
# 1660

# %% [markdown]
# ## Full pipeline

# %%
# setup config
CFG = {
    'probe_wiring': {
        'full': {
            'output': 'dataset/00_raw/recording_npx_spont'
        }
    },
    'preprocessing': {
        'full': {
            'output': {
                'trace_file_path': 'dataset/01_intermediate/preprocessing/recording_npx_spont'
            }
        }
    },
    'sorting': {
        'sorters': {
            f"{SORTER}": {
                '10m': {
                    'output': './temp/SortingKS3_10m_RTX5090', #'path/to/sorting/output',
                    'sort_output':'./temp/KS3_output/KS3_output_10m_RTX5090' #'path/to/sorting/sort_output'
                }
            }
        }
    },
    'postprocessing': {
        'waveform': {
            'sorted': {
                'study': {
                    f"{SORTER}": {  # sorter name
                        '10m': './temp/study_ks3_10m_RTX5090' #'path/to/postprocessing/study'
                    }
                }
            }
        }
    }
}

# %%
# sort and postprocess
sort_and_postprocess_10m(CFG,
                         SORTER,
                         SORTER_PARAMS,
                         duration_sec=REC_SECS,
                         is_sort=True,
                         is_postpro=True,
                         copy_binary_recording=True,
                         remove_bad_channels=True)
# Out:
# 2025-07-09 18:45:50,705 - root - sorting.py - sort_and_postprocess_10m - INFO - Started sorting 10 minutes recording.
# 2025-07-09 18:45:50,710 - root - sorting.py - sort - INFO - Removing bad channels...
# 2025-07-09 18:45:50,714 - root - sorting.py - sort - INFO - Done removing bad channels in: 0.0
# 2025-07-09 18:45:50,715 - root - sorting.py - sort - INFO - Selected first 10.0 minutes in: 0.0
# 2025-07-09 18:45:50,716 - root - sorting.py - sort - INFO - Done converting recording as int16 in: 0.0
# 2025-07-09 18:45:50,716 - root - sorting.py - sort - INFO - Saving int16 binary recording...
# write_binary_recording
# n_jobs=32 - samples_per_chunk=400,000 - chunk_memory=154.11 MiB - total_memory=4.82 GiB - chunk_duration=10.00s
# write_binary_recording: 100%|██████████| 60/60 [00:09<00:00,  6.13it/s]
# 2025-07-09 18:46:00,923 - root - sorting.py - sort - INFO - Done copying int16 binary recording in: 10.2
# 2025-07-09 18:46:00,926 - root - sorting.py - sort - INFO - Start sorting...
# /home/steeve/steeve/epfl/code/spikebias/envs/demo/lib/python3.10/site-packages/spikeinterface/core/baserecording.py:815: UserWarning: `file_paths_lenght` is deprecated and will be removed in 0.103.0 please use `file_paths_length`
#   warnings.warn(
# RUNNING SHELL SCRIPT: /home/steeve/steeve/epfl/code/spikebias/temp/KS3_output/KS3_output_10m_RTX5090/sorter_output/run_kilosort3.sh
#
#
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2024 The MathWorks, Inc.
#
#                   R2025a (25.1.0.2943329) 64-bit (glnxa64)
#
#                                April 16, 2025
#
#
#
#
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
#
#
# Steeve - forward compatibility enabled for more recent GPUs - edit startup.m file to disable
#
# Time   0s. Computing whitening matrix..
#
# Getting channel whitening matrix...
#
# Warning: Recompiling GPU libraries because your device is more recent than the
#
# libraries. Compilation can take several minutes.
#
# > In get_whitening_matrix (line 25)
#
# In preprocessDataSub (line 62)
#
# In kilosort3_master (line 71)
#
# Channel-whitening matrix computed.
#
# Time   2s. Loading raw data and applying filters...
#
# Time  36s. Finished preprocessing 365 batches.
#
# Drift correction ENABLED
#
# running datashift2...
#
# running extractTemplatesfromSnippets...
#
# running isolated_peaks_new...
#
# running isolated_peaks_new...
#
# running isolated_peaks_new...
#
# running isolated_peaks_new...
#
# running isolated_peaks_new...
#
# running isolated_peaks_new...
#
# running isolated_peaks_new...
#
# running isolated_peaks_new...
#
# running isolated_peaks_new...
#
# running isolated_peaks_new...
#
# running isolated_peaks_new...
#
# running isolated_peaks_new...
#
# running isolated_peaks_new...
#
# running isolated_peaks_new...
#
# running isolated_peaks_new...
#
# extractTemplatesfromSnippets done
#
# vertical pitch size is 2.457609e+00
#
# horizontal pitch size is 5
#
#    1.0e+03 *
#
#
#
#   Columns 1 through 7
#
#
#
#     3.3191    3.3216    3.3241    3.3266    3.3291    3.3316    3.3341
#
#
#
#   Columns 8 through 14
#
#
#
#     3.3366    3.3391    3.3416    3.3441    3.3466    3.3491    3.3516
#
#
#
#   Columns 15 through 21
#
#
#
#     3.3541    3.3566    3.3591    3.3616    3.3641    3.3666    3.3691
#
#
#
#   Columns 22 through 28
#
#
#
#     3.3716    3.3741    3.3766    3.3791    3.3816    3.3841    3.3866
#
#
#
#   Columns 29 through 35
#
#
#
#     3.3891    3.3916    3.3941    3.3966    3.3991    3.4016    3.4041
#
#
#
#   Columns 36 through 42
#
#
#
#     3.4066    3.4091    3.4116    3.4141    3.4166    3.4191    3.4216
#
#
#
#   Columns 43 through 49
#
#
#
#     3.4241    3.4266    3.4291    3.4316    3.4341    3.4366    3.4391
#
#
#
#   Columns 50 through 56
#
#
#
#     3.4416    3.4441    3.4466    3.4491    3.4516    3.4541    3.4566
#
#
#
#   Columns 57 through 63
#
#
#
#     3.4591    3.4616    3.4641    3.4666    3.4691    3.4716    3.4741
#
#
#
#   Columns 64 through 70
#
#
#
#     3.4766    3.4791    3.4816    3.4841    3.4866    3.4891    3.4916
#
#
#
#   Columns 71 through 77
#
#
#
#     3.4941    3.4966    3.4991    3.5016    3.5041    3.5066    3.5091
#
#
#
#   Columns 78 through 84
#
#
#
#     3.5116    3.5141    3.5166    3.5191    3.5216    3.5241    3.5266
#
#
#
#   Columns 85 through 91
#
#
#
#     3.5291    3.5316    3.5341    3.5366    3.5391    3.5416    3.5441
#
#
#
#   Columns 92 through 98
#
#
#
#     3.5466    3.5491    3.5516    3.5541    3.5566    3.5591    3.5616
#
#
#
#   Columns 99 through 105
#
#
#
#     3.5641    3.5666    3.5691    3.5716    3.5741    3.5766    3.5791
#
#
#
#   Columns 106 through 112
#
#
#
#     3.5816    3.5841    3.5866    3.5891    3.5916    3.5941    3.5966
#
#
#
#   Columns 113 through 119
#
#
#
#     3.5991    3.6016    3.6041    3.6066    3.6091    3.6116    3.6141
#
#
#
#   Columns 120 through 126
#
#
#
#     3.6166    3.6191    3.6216    3.6241    3.6266    3.6291    3.6316
#
#
#
#   Columns 127 through 133
#
#
#
#     3.6341    3.6366    3.6391    3.6416    3.6441    3.6466    3.6491
#
#
#
#   Columns 134 through 140
#
#
#
#     3.6516    3.6541    3.6566    3.6591    3.6616    3.6641    3.6666
#
#
#
#   Columns 141 through 147
#
#
#
#     3.6691    3.6716    3.6741    3.6766    3.6791    3.6816    3.6841
#
#
#
#   Columns 148 through 154
#
#
#
#     3.6866    3.6891    3.6916    3.6941    3.6966    3.6991    3.7016
#
#
#
#   Columns 155 through 161
#
#
#
#     3.7041    3.7066    3.7091    3.7116    3.7141    3.7166    3.7191
#
#
#
#   Columns 162 through 168
#
#
#
#     3.7216    3.7241    3.7266    3.7291    3.7316    3.7341    3.7366
#
#
#
#   Columns 169 through 175
#
#
#
#     3.7391    3.7416    3.7441    3.7466    3.7491    3.7516    3.7541
#
#
#
#   Columns 176 through 182
#
#
#
#     3.7566    3.7591    3.7616    3.7641    3.7666    3.7691    3.7716
#
#
#
#   Columns 183 through 189
#
#
#
#     3.7741    3.7766    3.7791    3.7816    3.7841    3.7866    3.7891
#
#
#
#   Columns 190 through 196
#
#
#
#     3.7916    3.7941    3.7966    3.7991    3.8016    3.8041    3.8066
#
#
#
#   Columns 197 through 203
#
#
#
#     3.8091    3.8116    3.8141    3.8166    3.8191    3.8216    3.8241
#
#
#
#   Columns 204 through 210
#
#
#
#     3.8266    3.8291    3.8316    3.8341    3.8366    3.8391    3.8416
#
#
#
#   Columns 211 through 217
#
#
#
#     3.8441    3.8466    3.8491    3.8516    3.8541    3.8566    3.8591
#
#
#
#   Columns 218 through 224
#
#
#
#     3.8616    3.8641    3.8666    3.8691    3.8716    3.8741    3.8766
#
#
#
#   Columns 225 through 231
#
#
#
#     3.8791    3.8816    3.8841    3.8866    3.8891    3.8916    3.8941
#
#
#
#   Columns 232 through 238
#
#
#
#     3.8966    3.8991    3.9016    3.9041    3.9066    3.9091    3.9116
#
#
#
#   Columns 239 through 245
#
#
#
#     3.9141    3.9166    3.9191    3.9216    3.9241    3.9266    3.9291
#
#
#
#   Columns 246 through 252
#
#
#
#     3.9316    3.9341    3.9366    3.9391    3.9416    3.9441    3.9466
#
#
#
#   Columns 253 through 259
#
#
#
#     3.9491    3.9516    3.9541    3.9566    3.9591    3.9616    3.9641
#
#
#
#   Columns 260 through 266
#
#
#
#     3.9666    3.9691    3.9716    3.9741    3.9766    3.9791    3.9816
#
#
#
#   Columns 267 through 273
#
#
#
#     3.9841    3.9866    3.9891    3.9916    3.9941    3.9966    3.9991
#
#
#
#   Columns 274 through 280
#
#
#
#     4.0016    4.0041    4.0066    4.0091    4.0116    4.0141    4.0166
#
#
#
#   Columns 281 through 287
#
#
#
#     4.0191    4.0216    4.0241    4.0266    4.0291    4.0316    4.0341
#
#
#
#   Columns 288 through 294
#
#
#
#     4.0366    4.0391    4.0416    4.0441    4.0466    4.0491    4.0516
#
#
#
#   Columns 295 through 301
#
#
#
#     4.0541    4.0566    4.0591    4.0615    4.0640    4.0665    4.0690
#
#
#
#   Columns 302 through 308
#
#
#
#     4.0715    4.0740    4.0765    4.0790    4.0815    4.0840    4.0865
#
#
#
#   Columns 309 through 315
#
#
#
#     4.0890    4.0915    4.0940    4.0965    4.0990    4.1015    4.1040
#
#
#
#   Columns 316 through 322
#
#
#
#     4.1065    4.1090    4.1115    4.1140    4.1165    4.1190    4.1215
#
#
#
#   Columns 323 through 329
#
#
#
#     4.1240    4.1265    4.1290    4.1315    4.1340    4.1365    4.1390
#
#
#
#   Columns 330 through 336
#
#
#
#     4.1415    4.1440    4.1465    4.1490    4.1515    4.1540    4.1565
#
#
#
#   Columns 337 through 343
#
#
#
#     4.1590    4.1615    4.1640    4.1665    4.1690    4.1715    4.1740
#
#
#
#   Columns 344 through 350
#
#
#
#     4.1765    4.1790    4.1815    4.1840    4.1865    4.1890    4.1915
#
#
#
#   Columns 351 through 357
#
#
#
#     4.1940    4.1965    4.1990    4.2015    4.2040    4.2065    4.2090
#
#
#
#   Columns 358 through 364
#
#
#
#     4.2115    4.2140    4.2165    4.2190    4.2215    4.2240    4.2265
#
#
#
#   Columns 365 through 371
#
#
#
#     4.2290    4.2315    4.2340    4.2365    4.2390    4.2415    4.2440
#
#
#
#   Columns 372 through 378
#
#
#
#     4.2465    4.2490    4.2515    4.2540    4.2565    4.2590    4.2615
#
#
#
#   Columns 379 through 385
#
#
#
#     4.2640    4.2665    4.2690    4.2715    4.2740    4.2765    4.2790
#
#
#
#   Columns 386 through 392
#
#
#
#     4.2815    4.2840    4.2865    4.2890    4.2915    4.2940    4.2965
#
#
#
#   Columns 393 through 399
#
#
#
#     4.2990    4.3015    4.3040    4.3065    4.3090    4.3115    4.3140
#
#
#
#   Columns 400 through 406
#
#
#
#     4.3165    4.3190    4.3215    4.3240    4.3265    4.3290    4.3315
#
#
#
#   Columns 407 through 413
#
#
#
#     4.3340    4.3365    4.3390    4.3415    4.3440    4.3465    4.3490
#
#
#
#   Columns 414 through 420
#
#
#
#     4.3515    4.3540    4.3565    4.3590    4.3615    4.3640    4.3665
#
#
#
#   Columns 421 through 427
#
#
#
#     4.3690    4.3715    4.3740    4.3765    4.3790    4.3815    4.3840
#
#
#
#   Columns 428 through 434
#
#
#
#     4.3865    4.3890    4.3915    4.3940    4.3965    4.3990    4.4015
#
#
#
#   Columns 435 through 441
#
#
#
#     4.4040    4.4065    4.4090    4.4115    4.4140    4.4165    4.4190
#
#
#
#   Columns 442 through 448
#
#
#
#     4.4215    4.4240    4.4265    4.4290    4.4315    4.4340    4.4365
#
#
#
#   Columns 449 through 455
#
#
#
#     4.4390    4.4415    4.4440    4.4465    4.4490    4.4515    4.4540
#
#
#
#   Columns 456 through 462
#
#
#
#     4.4565    4.4590    4.4615    4.4640    4.4665    4.4690    4.4715
#
#
#
#   Columns 463 through 469
#
#
#
#     4.4740    4.4765    4.4790    4.4815    4.4840    4.4865    4.4890
#
#
#
#   Columns 470 through 476
#
#
#
#     4.4915    4.4940    4.4965    4.4990    4.5015    4.5040    4.5065
#
#
#
#   Columns 477 through 483
#
#
#
#     4.5090    4.5115    4.5140    4.5165    4.5190    4.5215    4.5240
#
#
#
#   Columns 484 through 490
#
#
#
#     4.5265    4.5290    4.5315    4.5340    4.5365    4.5390    4.5415
#
#
#
#   Columns 491 through 497
#
#
#
#     4.5440    4.5465    4.5490    4.5515    4.5540    4.5565    4.5590
#
#
#
#   Columns 498 through 504
#
#
#
#     4.5615    4.5640    4.5665    4.5690    4.5715    4.5740    4.5765
#
#
#
#   Columns 505 through 511
#
#
#
#     4.5790    4.5815    4.5840    4.5865    4.5890    4.5915    4.5940
#
#
#
#     92
#
#
#
# 0.05 sec, 1 batches, 485 spikes
#
# 3.87 sec, 101 batches, 46468 spikes
#
# 7.69 sec, 201 batches, 92365 spikes
#
# 11.50 sec, 301 batches, 138215 spikes
#
# 13.95 sec, 365 batches, 167537 spikes
#
# time 29.02, Shifted up/down 365 batches.
#
# datashift2 done
#
# running extractTemplatesfromSnippets...
#
# running isolated_peaks_new...
#
# running isolated_peaks_new...
#
# running isolated_peaks_new...
#
# running isolated_peaks_new...
#
# running isolated_peaks_new...
#
# running isolated_peaks_new...
#
# running isolated_peaks_new...
#
# running isolated_peaks_new...
#
# running isolated_peaks_new...
#
# running isolated_peaks_new...
#
# running isolated_peaks_new...
#
# running isolated_peaks_new...
#
# running isolated_peaks_new...
#
# running isolated_peaks_new...
#
# running isolated_peaks_new...
#
# extractTemplatesfromSnippets done
#
# 0.05 sec, 1 batches, 536 spikes
#
# 4.12 sec, 101 batches, 51855 spikes
#
# 8.20 sec, 201 batches, 103053 spikes
#
# 12.32 sec, 301 batches, 154280 spikes
#
# 14.96 sec, 365 batches, 187095 spikes
#
# time 0.00, GROUP 1/11904, units 0
#
# time 0.00, GROUP 6/11904, units 0
#
# time 0.00, GROUP 11/11904, units 0
#
# time 0.00, GROUP 16/11904, units 0
#
# time 0.00, GROUP 21/11904, units 0
#
# time 0.00, GROUP 26/11904, units 0
#
# time 0.00, GROUP 31/11904, units 0
#
# time 0.00, GROUP 36/11904, units 0
#
# time 0.00, GROUP 41/11904, units 0
#
# time 0.00, GROUP 46/11904, units 0
#
# time 0.00, GROUP 51/11904, units 0
#
# time 0.00, GROUP 56/11904, units 0
#
# time 0.00, GROUP 61/11904, units 0
#
# time 0.00, GROUP 66/11904, units 0
#
# time 0.00, GROUP 71/11904, units 0
#
# time 0.00, GROUP 76/11904, units 0
#
# time 0.00, GROUP 81/11904, units 0
#
# time 0.07, GROUP 86/11904, units 2
#
# time 0.07, GROUP 91/11904, units 4
#
# time 0.08, GROUP 96/11904, units 4
#
# time 0.08, GROUP 101/11904, units 4
#
# time 0.08, GROUP 106/11904, units 4
#
# time 0.08, GROUP 111/11904, units 4
#
# time 0.08, GROUP 116/11904, units 4
#
# time 0.08, GROUP 121/11904, units 4
#
# time 0.08, GROUP 126/11904, units 4
#
# time 0.08, GROUP 131/11904, units 4
#
# time 0.08, GROUP 136/11904, units 4
#
# time 0.08, GROUP 141/11904, units 4
#
# time 0.08, GROUP 146/11904, units 4
#
# time 0.08, GROUP 151/11904, units 4
#
# time 0.08, GROUP 156/11904, units 4
#
# time 0.08, GROUP 161/11904, units 4
#
# time 0.08, GROUP 166/11904, units 4
#
# time 0.08, GROUP 171/11904, units 4
#
# time 0.08, GROUP 176/11904, units 4
#
# time 0.08, GROUP 181/11904, units 4
#
# time 0.09, GROUP 186/11904, units 7
#
# time 0.09, GROUP 191/11904, units 8
#
# time 0.09, GROUP 196/11904, units 8
#
# time 0.09, GROUP 201/11904, units 8
#
# time 0.09, GROUP 206/11904, units 8
#
# time 0.09, GROUP 211/11904, units 8
#
# time 0.09, GROUP 216/11904, units 8
#
# time 0.09, GROUP 221/11904, units 8
#
# time 0.09, GROUP 226/11904, units 8
#
# time 0.09, GROUP 231/11904, units 8
#
# time 0.09, GROUP 236/11904, units 8
#
# time 0.09, GROUP 241/11904, units 8
#
# time 0.09, GROUP 246/11904, units 8
#
# time 0.09, GROUP 251/11904, units 8
#
# time 0.09, GROUP 256/11904, units 8
#
# time 0.09, GROUP 261/11904, units 8
#
# time 0.09, GROUP 266/11904, units 8
#
# time 0.09, GROUP 271/11904, units 9
#
# time 0.09, GROUP 276/11904, units 11
#
# time 0.09, GROUP 281/11904, units 11
#
# time 0.09, GROUP 286/11904, units 11
#
# time 0.09, GROUP 291/11904, units 11
#
# time 0.09, GROUP 296/11904, units 11
#
# time 0.09, GROUP 301/11904, units 11
#
# time 0.09, GROUP 306/11904, units 11
#
# time 0.09, GROUP 311/11904, units 11
#
# time 0.09, GROUP 316/11904, units 11
#
# time 0.09, GROUP 321/11904, units 11
#
# time 0.09, GROUP 326/11904, units 11
#
# time 0.09, GROUP 331/11904, units 11
#
# time 0.09, GROUP 336/11904, units 11
#
# time 0.09, GROUP 341/11904, units 11
#
# time 0.09, GROUP 346/11904, units 11
#
# time 0.09, GROUP 351/11904, units 11
#
# time 0.09, GROUP 356/11904, units 11
#
# time 0.10, GROUP 361/11904, units 12
#
# time 0.10, GROUP 366/11904, units 12
#
# time 0.10, GROUP 371/11904, units 13
#
# time 0.10, GROUP 376/11904, units 13
#
# time 0.10, GROUP 381/11904, units 13
#
# time 0.10, GROUP 386/11904, units 13
#
# time 0.10, GROUP 391/11904, units 13
#
# time 0.10, GROUP 396/11904, units 13
#
# time 0.10, GROUP 401/11904, units 13
#
# time 0.10, GROUP 406/11904, units 13
#
# time 0.10, GROUP 411/11904, units 13
#
# time 0.10, GROUP 416/11904, units 13
#
# time 0.10, GROUP 421/11904, units 13
#
# time 0.10, GROUP 426/11904, units 13
#
# time 0.10, GROUP 431/11904, units 13
#
# time 0.10, GROUP 436/11904, units 13
#
# time 0.10, GROUP 441/11904, units 13
#
# time 0.10, GROUP 446/11904, units 13
#
# time 0.10, GROUP 451/11904, units 13
#
# time 0.10, GROUP 456/11904, units 13
#
# time 0.10, GROUP 461/11904, units 14
#
# time 0.10, GROUP 466/11904, units 14
#
# time 0.10, GROUP 471/11904, units 14
#
# time 0.10, GROUP 476/11904, units 14
#
# time 0.10, GROUP 481/11904, units 14
#
# time 0.10, GROUP 486/11904, units 14
#
# time 0.10, GROUP 491/11904, units 14
#
# time 0.10, GROUP 496/11904, units 14
#
# time 0.10, GROUP 501/11904, units 14
#
# time 0.10, GROUP 506/11904, units 14
#
# time 0.10, GROUP 511/11904, units 14
#
# time 0.10, GROUP 516/11904, units 14
#
# time 0.10, GROUP 521/11904, units 14
#
# time 0.10, GROUP 526/11904, units 14
#
# time 0.10, GROUP 531/11904, units 14
#
# time 0.10, GROUP 536/11904, units 14
#
# time 0.10, GROUP 541/11904, units 14
#
# time 0.10, GROUP 546/11904, units 16
#
# time 0.11, GROUP 551/11904, units 17
#
# time 0.11, GROUP 556/11904, units 17
#
# time 0.11, GROUP 561/11904, units 17
#
# time 0.11, GROUP 566/11904, units 17
#
# time 0.11, GROUP 571/11904, units 17
#
# time 0.11, GROUP 576/11904, units 17
#
# time 0.11, GROUP 581/11904, units 17
#
# time 0.11, GROUP 586/11904, units 17
#
# time 0.11, GROUP 591/11904, units 17
#
# time 0.11, GROUP 596/11904, units 17
#
# time 0.11, GROUP 601/11904, units 17
#
# time 0.11, GROUP 606/11904, units 17
#
# time 0.11, GROUP 611/11904, units 17
#
# time 0.11, GROUP 616/11904, units 17
#
# time 0.11, GROUP 621/11904, units 17
#
# time 0.11, GROUP 626/11904, units 17
#
# time 0.11, GROUP 631/11904, units 17
#
# time 0.11, GROUP 636/11904, units 17
#
# time 0.11, GROUP 641/11904, units 18
#
# time 0.11, GROUP 646/11904, units 19
#
# time 0.11, GROUP 651/11904, units 21
#
# time 0.11, GROUP 656/11904, units 21
#
# time 0.11, GROUP 661/11904, units 21
#
# time 0.11, GROUP 666/11904, units 21
#
# time 0.11, GROUP 671/11904, units 21
#
# time 0.11, GROUP 676/11904, units 21
#
# time 0.11, GROUP 681/11904, units 21
#
# time 0.11, GROUP 686/11904, units 21
#
# time 0.11, GROUP 691/11904, units 21
#
# time 0.11, GROUP 696/11904, units 21
#
# time 0.11, GROUP 701/11904, units 21
#
# time 0.11, GROUP 706/11904, units 21
#
# time 0.11, GROUP 711/11904, units 21
#
# time 0.11, GROUP 716/11904, units 21
#
# time 0.11, GROUP 721/11904, units 21
#
# time 0.11, GROUP 726/11904, units 21
#
# time 0.11, GROUP 731/11904, units 21
#
# time 0.12, GROUP 736/11904, units 23
#
# time 0.12, GROUP 741/11904, units 25
#
# time 0.12, GROUP 746/11904, units 25
#
# time 0.12, GROUP 751/11904, units 25
#
# time 0.12, GROUP 756/11904, units 25
#
# time 0.12, GROUP 761/11904, units 25
#
# time 0.12, GROUP 766/11904, units 25
#
# time 0.12, GROUP 771/11904, units 25
#
# time 0.12, GROUP 776/11904, units 25
#
# time 0.12, GROUP 781/11904, units 25
#
# time 0.12, GROUP 786/11904, units 25
#
# time 0.12, GROUP 791/11904, units 25
#
# time 0.12, GROUP 796/11904, units 25
#
# time 0.12, GROUP 801/11904, units 25
#
# time 0.12, GROUP 806/11904, units 25
#
# time 0.12, GROUP 811/11904, units 25
#
# time 0.12, GROUP 816/11904, units 25
#
# time 0.12, GROUP 821/11904, units 25
#
# time 0.34, GROUP 826/11904, units 27
#
# time 0.34, GROUP 831/11904, units 27
#
# time 0.34, GROUP 836/11904, units 29
#
# time 0.34, GROUP 841/11904, units 29
#
# time 0.34, GROUP 846/11904, units 29
#
# time 0.34, GROUP 851/11904, units 29
#
# time 0.34, GROUP 856/11904, units 29
#
# time 0.34, GROUP 861/11904, units 29
#
# time 0.34, GROUP 866/11904, units 29
#
# time 0.34, GROUP 871/11904, units 29
#
# time 0.34, GROUP 876/11904, units 29
#
# time 0.34, GROUP 881/11904, units 29
#
# time 0.34, GROUP 886/11904, units 29
#
# time 0.34, GROUP 891/11904, units 29
#
# time 0.34, GROUP 896/11904, units 29
#
# time 0.34, GROUP 901/11904, units 29
#
# time 0.34, GROUP 906/11904, units 29
#
# time 0.34, GROUP 911/11904, units 29
#
# time 0.34, GROUP 916/11904, units 29
#
# time 0.35, GROUP 921/11904, units 30
#
# time 0.40, GROUP 926/11904, units 31
#
# time 0.40, GROUP 931/11904, units 31
#
# time 0.40, GROUP 936/11904, units 31
#
# time 0.40, GROUP 941/11904, units 31
#
# time 0.40, GROUP 946/11904, units 31
#
# time 0.40, GROUP 951/11904, units 31
#
# time 0.40, GROUP 956/11904, units 31
#
# time 0.40, GROUP 961/11904, units 31
#
# time 0.40, GROUP 966/11904, units 31
#
# time 0.40, GROUP 971/11904, units 31
#
# time 0.40, GROUP 976/11904, units 31
#
# time 0.41, GROUP 981/11904, units 31
#
# time 0.41, GROUP 986/11904, units 31
#
# time 0.41, GROUP 991/11904, units 31
#
# time 0.41, GROUP 996/11904, units 31
#
# time 0.41, GROUP 1001/11904, units 31
#
# time 0.41, GROUP 1006/11904, units 31
#
# time 0.41, GROUP 1011/11904, units 33
#
# time 0.41, GROUP 1016/11904, units 33
#
# time 0.41, GROUP 1021/11904, units 33
#
# time 0.41, GROUP 1026/11904, units 33
#
# time 0.41, GROUP 1031/11904, units 33
#
# time 0.41, GROUP 1036/11904, units 33
#
# time 0.41, GROUP 1041/11904, units 33
#
# time 0.41, GROUP 1046/11904, units 33
#
# time 0.41, GROUP 1051/11904, units 33
#
# time 0.41, GROUP 1056/11904, units 33
#
# time 0.41, GROUP 1061/11904, units 33
#
# time 0.41, GROUP 1066/11904, units 33
#
# time 0.41, GROUP 1071/11904, units 33
#
# time 0.41, GROUP 1076/11904, units 33
#
# time 0.41, GROUP 1081/11904, units 33
#
# time 0.41, GROUP 1086/11904, units 33
#
# time 0.41, GROUP 1091/11904, units 33
#
# time 0.41, GROUP 1096/11904, units 33
#
# time 0.46, GROUP 1101/11904, units 34
#
# time 0.46, GROUP 1106/11904, units 35
#
# time 0.59, GROUP 1111/11904, units 37
#
# time 0.59, GROUP 1116/11904, units 37
#
# time 0.59, GROUP 1121/11904, units 37
#
# time 0.59, GROUP 1126/11904, units 37
#
# time 0.59, GROUP 1131/11904, units 37
#
# time 0.59, GROUP 1136/11904, units 37
#
# time 0.59, GROUP 1141/11904, units 37
#
# time 0.59, GROUP 1146/11904, units 37
#
# time 0.59, GROUP 1151/11904, units 37
#
# time 0.59, GROUP 1156/11904, units 37
#
# time 0.59, GROUP 1161/11904, units 37
#
# time 0.59, GROUP 1166/11904, units 37
#
# time 0.59, GROUP 1171/11904, units 37
#
# time 0.59, GROUP 1176/11904, units 37
#
# time 0.59, GROUP 1181/11904, units 37
#
# time 0.59, GROUP 1186/11904, units 37
#
# time 0.59, GROUP 1191/11904, units 37
#
# time 0.65, GROUP 1196/11904, units 38
#
# time 0.65, GROUP 1201/11904, units 39
#
# time 0.65, GROUP 1206/11904, units 39
#
# time 0.65, GROUP 1211/11904, units 39
#
# time 0.65, GROUP 1216/11904, units 39
#
# time 0.65, GROUP 1221/11904, units 39
#
# time 0.65, GROUP 1226/11904, units 39
#
# time 0.65, GROUP 1231/11904, units 39
#
# time 0.65, GROUP 1236/11904, units 39
#
# time 0.65, GROUP 1241/11904, units 39
#
# time 0.65, GROUP 1246/11904, units 39
#
# time 0.65, GROUP 1251/11904, units 39
#
# time 0.65, GROUP 1256/11904, units 39
#
# time 0.65, GROUP 1261/11904, units 39
#
# time 0.65, GROUP 1266/11904, units 39
#
# time 0.65, GROUP 1271/11904, units 39
#
# time 0.65, GROUP 1276/11904, units 39
#
# time 0.65, GROUP 1281/11904, units 39
#
# time 0.65, GROUP 1286/11904, units 41
#
# time 0.65, GROUP 1291/11904, units 41
#
# time 0.82, GROUP 1296/11904, units 44
#
# time 0.82, GROUP 1301/11904, units 44
#
# time 0.82, GROUP 1306/11904, units 44
#
# time 0.82, GROUP 1311/11904, units 44
#
# time 0.82, GROUP 1316/11904, units 44
#
# time 0.82, GROUP 1321/11904, units 44
#
# time 0.82, GROUP 1326/11904, units 44
#
# time 0.82, GROUP 1331/11904, units 44
#
# time 0.82, GROUP 1336/11904, units 44
#
# time 0.82, GROUP 1341/11904, units 44
#
# time 0.82, GROUP 1346/11904, units 44
#
# time 0.82, GROUP 1351/11904, units 44
#
# time 0.82, GROUP 1356/11904, units 44
#
# time 0.82, GROUP 1361/11904, units 44
#
# time 0.82, GROUP 1366/11904, units 44
#
# time 0.82, GROUP 1371/11904, units 44
#
# time 0.82, GROUP 1376/11904, units 44
#
# time 0.82, GROUP 1381/11904, units 44
#
# time 0.85, GROUP 1386/11904, units 47
#
# time 0.85, GROUP 1391/11904, units 47
#
# time 0.85, GROUP 1396/11904, units 47
#
# time 0.85, GROUP 1401/11904, units 47
#
# time 0.85, GROUP 1406/11904, units 47
#
# time 0.85, GROUP 1411/11904, units 47
#
# time 0.85, GROUP 1416/11904, units 47
#
# time 0.85, GROUP 1421/11904, units 47
#
# time 0.85, GROUP 1426/11904, units 47
#
# time 0.85, GROUP 1431/11904, units 47
#
# time 0.85, GROUP 1436/11904, units 47
#
# time 0.85, GROUP 1441/11904, units 47
#
# time 0.85, GROUP 1446/11904, units 47
#
# time 0.85, GROUP 1451/11904, units 47
#
# time 0.85, GROUP 1456/11904, units 47
#
# time 0.85, GROUP 1461/11904, units 47
#
# time 0.85, GROUP 1466/11904, units 47
#
# time 0.90, GROUP 1471/11904, units 49
#
# time 0.98, GROUP 1476/11904, units 52
#
# time 0.98, GROUP 1481/11904, units 52
#
# time 0.98, GROUP 1486/11904, units 52
#
# time 0.98, GROUP 1491/11904, units 52
#
# time 0.98, GROUP 1496/11904, units 52
#
# time 0.98, GROUP 1501/11904, units 52
#
# time 0.98, GROUP 1506/11904, units 52
#
# time 0.98, GROUP 1511/11904, units 52
#
# time 0.98, GROUP 1516/11904, units 52
#
# time 0.98, GROUP 1521/11904, units 52
#
# time 0.98, GROUP 1526/11904, units 52
#
# time 0.98, GROUP 1531/11904, units 52
#
# time 0.98, GROUP 1536/11904, units 52
#
# time 0.98, GROUP 1541/11904, units 52
#
# time 0.98, GROUP 1546/11904, units 52
#
# time 0.98, GROUP 1551/11904, units 52
#
# time 0.98, GROUP 1556/11904, units 52
#
# time 0.98, GROUP 1561/11904, units 53
#
# time 0.98, GROUP 1566/11904, units 54
#
# time 1.00, GROUP 1571/11904, units 57
#
# time 1.32, GROUP 1576/11904, units 61
#
# time 1.32, GROUP 1581/11904, units 61
#
# time 1.32, GROUP 1586/11904, units 61
#
# time 1.32, GROUP 1591/11904, units 61
#
# time 1.32, GROUP 1596/11904, units 61
#
# time 1.32, GROUP 1601/11904, units 61
#
# time 1.32, GROUP 1606/11904, units 61
#
# time 1.32, GROUP 1611/11904, units 61
#
# time 1.32, GROUP 1616/11904, units 61
#
# time 1.32, GROUP 1621/11904, units 61
#
# time 1.32, GROUP 1626/11904, units 61
#
# time 1.32, GROUP 1631/11904, units 61
#
# time 1.32, GROUP 1636/11904, units 61
#
# time 1.32, GROUP 1641/11904, units 61
#
# time 1.32, GROUP 1646/11904, units 61
#
# time 1.32, GROUP 1651/11904, units 61
#
# time 1.32, GROUP 1656/11904, units 62
#
# time 1.32, GROUP 1661/11904, units 65
#
# time 1.32, GROUP 1666/11904, units 65
#
# time 1.32, GROUP 1671/11904, units 65
#
# time 1.32, GROUP 1676/11904, units 65
#
# time 1.32, GROUP 1681/11904, units 65
#
# time 1.32, GROUP 1686/11904, units 65
#
# time 1.32, GROUP 1691/11904, units 65
#
# time 1.32, GROUP 1696/11904, units 65
#
# time 1.32, GROUP 1701/11904, units 65
#
# time 1.32, GROUP 1706/11904, units 65
#
# time 1.32, GROUP 1711/11904, units 65
#
# time 1.32, GROUP 1716/11904, units 65
#
# time 1.32, GROUP 1721/11904, units 65
#
# time 1.32, GROUP 1726/11904, units 65
#
# time 1.32, GROUP 1731/11904, units 65
#
# time 1.32, GROUP 1736/11904, units 65
#
# time 1.32, GROUP 1741/11904, units 65
#
# time 1.37, GROUP 1746/11904, units 66
#
# time 1.37, GROUP 1751/11904, units 66
#
# time 1.42, GROUP 1756/11904, units 67
#
# time 1.42, GROUP 1761/11904, units 67
#
# time 1.42, GROUP 1766/11904, units 67
#
# time 1.42, GROUP 1771/11904, units 67
#
# time 1.42, GROUP 1776/11904, units 67
#
# time 1.42, GROUP 1781/11904, units 67
#
# time 1.42, GROUP 1786/11904, units 67
#
# time 1.42, GROUP 1791/11904, units 67
#
# time 1.42, GROUP 1796/11904, units 67
#
# time 1.42, GROUP 1801/11904, units 67
#
# time 1.42, GROUP 1806/11904, units 67
#
# time 1.42, GROUP 1811/11904, units 67
#
# time 1.42, GROUP 1816/11904, units 67
#
# time 1.42, GROUP 1821/11904, units 67
#
# time 1.42, GROUP 1826/11904, units 67
#
# time 1.42, GROUP 1831/11904, units 67
#
# time 1.42, GROUP 1836/11904, units 67
#
# time 1.42, GROUP 1841/11904, units 67
#
# time 1.50, GROUP 1846/11904, units 69
#
# time 1.50, GROUP 1851/11904, units 69
#
# time 1.50, GROUP 1856/11904, units 69
#
# time 1.50, GROUP 1861/11904, units 69
#
# time 1.50, GROUP 1866/11904, units 69
#
# time 1.50, GROUP 1871/11904, units 69
#
# time 1.50, GROUP 1876/11904, units 69
#
# time 1.50, GROUP 1881/11904, units 69
#
# time 1.50, GROUP 1886/11904, units 69
#
# time 1.50, GROUP 1891/11904, units 69
#
# time 1.50, GROUP 1896/11904, units 69
#
# time 1.50, GROUP 1901/11904, units 69
#
# time 1.50, GROUP 1906/11904, units 69
#
# time 1.50, GROUP 1911/11904, units 69
#
# time 1.50, GROUP 1916/11904, units 69
#
# time 1.50, GROUP 1921/11904, units 69
#
# time 1.50, GROUP 1926/11904, units 69
#
# time 1.50, GROUP 1931/11904, units 69
#
# time 1.68, GROUP 1936/11904, units 72
#
# time 1.68, GROUP 1941/11904, units 72
#
# time 1.68, GROUP 1946/11904, units 72
#
# time 1.68, GROUP 1951/11904, units 72
#
# time 1.68, GROUP 1956/11904, units 72
#
# time 1.68, GROUP 1961/11904, units 72
#
# time 1.68, GROUP 1966/11904, units 72
#
# time 1.68, GROUP 1971/11904, units 72
#
# time 1.68, GROUP 1976/11904, units 72
#
# time 1.68, GROUP 1981/11904, units 72
#
# time 1.68, GROUP 1986/11904, units 72
#
# time 1.68, GROUP 1991/11904, units 72
#
# time 1.68, GROUP 1996/11904, units 72
#
# time 1.68, GROUP 2001/11904, units 72
#
# time 1.68, GROUP 2006/11904, units 72
#
# time 1.68, GROUP 2011/11904, units 72
#
# time 1.68, GROUP 2016/11904, units 72
#
# time 1.68, GROUP 2021/11904, units 72
#
# time 1.99, GROUP 2026/11904, units 77
#
# time 1.99, GROUP 2031/11904, units 77
#
# time 2.16, GROUP 2036/11904, units 81
#
# time 2.16, GROUP 2041/11904, units 81
#
# time 2.16, GROUP 2046/11904, units 81
#
# time 2.16, GROUP 2051/11904, units 81
#
# time 2.16, GROUP 2056/11904, units 81
#
# time 2.16, GROUP 2061/11904, units 81
#
# time 2.16, GROUP 2066/11904, units 81
#
# time 2.16, GROUP 2071/11904, units 81
#
# time 2.16, GROUP 2076/11904, units 81
#
# time 2.16, GROUP 2081/11904, units 81
#
# time 2.16, GROUP 2086/11904, units 81
#
# time 2.16, GROUP 2091/11904, units 81
#
# time 2.16, GROUP 2096/11904, units 81
#
# time 2.16, GROUP 2101/11904, units 81
#
# time 2.16, GROUP 2106/11904, units 81
#
# time 2.16, GROUP 2111/11904, units 81
#
# time 2.16, GROUP 2116/11904, units 81
#
# time 2.21, GROUP 2121/11904, units 83
#
# time 2.32, GROUP 2126/11904, units 87
#
# time 2.32, GROUP 2131/11904, units 87
#
# time 2.32, GROUP 2136/11904, units 87
#
# time 2.32, GROUP 2141/11904, units 87
#
# time 2.32, GROUP 2146/11904, units 87
#
# time 2.32, GROUP 2151/11904, units 87
#
# time 2.32, GROUP 2156/11904, units 87
#
# time 2.32, GROUP 2161/11904, units 87
#
# time 2.32, GROUP 2166/11904, units 87
#
# time 2.32, GROUP 2171/11904, units 87
#
# time 2.32, GROUP 2176/11904, units 87
#
# time 2.32, GROUP 2181/11904, units 87
#
# time 2.32, GROUP 2186/11904, units 87
#
# time 2.32, GROUP 2191/11904, units 87
#
# time 2.32, GROUP 2196/11904, units 87
#
# time 2.32, GROUP 2201/11904, units 87
#
# time 2.32, GROUP 2206/11904, units 87
#
# time 2.44, GROUP 2211/11904, units 91
#
# time 2.45, GROUP 2216/11904, units 92
#
# time 2.45, GROUP 2221/11904, units 94
#
# time 2.45, GROUP 2226/11904, units 94
#
# time 2.45, GROUP 2231/11904, units 94
#
# time 2.45, GROUP 2236/11904, units 94
#
# time 2.45, GROUP 2241/11904, units 94
#
# time 2.45, GROUP 2246/11904, units 94
#
# time 2.45, GROUP 2251/11904, units 94
#
# time 2.45, GROUP 2256/11904, units 94
#
# time 2.45, GROUP 2261/11904, units 94
#
# time 2.45, GROUP 2266/11904, units 94
#
# time 2.45, GROUP 2271/11904, units 94
#
# time 2.45, GROUP 2276/11904, units 94
#
# time 2.45, GROUP 2281/11904, units 94
#
# time 2.45, GROUP 2286/11904, units 94
#
# time 2.45, GROUP 2291/11904, units 94
#
# time 2.45, GROUP 2296/11904, units 94
#
# time 2.45, GROUP 2301/11904, units 94
#
# time 2.45, GROUP 2306/11904, units 95
#
# time 2.45, GROUP 2311/11904, units 97
#
# time 2.45, GROUP 2316/11904, units 97
#
# time 2.45, GROUP 2321/11904, units 97
#
# time 2.45, GROUP 2326/11904, units 97
#
# time 2.45, GROUP 2331/11904, units 97
#
# time 2.45, GROUP 2336/11904, units 97
#
# time 2.45, GROUP 2341/11904, units 97
#
# time 2.45, GROUP 2346/11904, units 97
#
# time 2.45, GROUP 2351/11904, units 97
#
# time 2.45, GROUP 2356/11904, units 97
#
# time 2.45, GROUP 2361/11904, units 97
#
# time 2.45, GROUP 2366/11904, units 97
#
# time 2.45, GROUP 2371/11904, units 97
#
# time 2.45, GROUP 2376/11904, units 97
#
# time 2.45, GROUP 2381/11904, units 97
#
# time 2.45, GROUP 2386/11904, units 97
#
# time 2.45, GROUP 2391/11904, units 97
#
# time 2.45, GROUP 2396/11904, units 99
#
# time 2.45, GROUP 2401/11904, units 99
#
# time 2.45, GROUP 2406/11904, units 99
#
# time 2.45, GROUP 2411/11904, units 99
#
# time 2.45, GROUP 2416/11904, units 99
#
# time 2.45, GROUP 2421/11904, units 99
#
# time 2.45, GROUP 2426/11904, units 99
#
# time 2.45, GROUP 2431/11904, units 99
#
# time 2.45, GROUP 2436/11904, units 99
#
# time 2.45, GROUP 2441/11904, units 99
#
# time 2.45, GROUP 2446/11904, units 99
#
# time 2.45, GROUP 2451/11904, units 99
#
# time 2.45, GROUP 2456/11904, units 99
#
# time 2.45, GROUP 2461/11904, units 99
#
# time 2.45, GROUP 2466/11904, units 99
#
# time 2.45, GROUP 2471/11904, units 99
#
# time 2.45, GROUP 2476/11904, units 99
#
# time 2.45, GROUP 2481/11904, units 99
#
# time 2.50, GROUP 2486/11904, units 100
#
# time 2.50, GROUP 2491/11904, units 100
#
# time 2.55, GROUP 2496/11904, units 101
#
# time 2.55, GROUP 2501/11904, units 101
#
# time 2.55, GROUP 2506/11904, units 101
#
# time 2.55, GROUP 2511/11904, units 101
#
# time 2.55, GROUP 2516/11904, units 101
#
# time 2.55, GROUP 2521/11904, units 101
#
# time 2.55, GROUP 2526/11904, units 101
#
# time 2.55, GROUP 2531/11904, units 101
#
# time 2.55, GROUP 2536/11904, units 101
#
# time 2.55, GROUP 2541/11904, units 101
#
# time 2.55, GROUP 2546/11904, units 101
#
# time 2.55, GROUP 2551/11904, units 101
#
# time 2.55, GROUP 2556/11904, units 101
#
# time 2.55, GROUP 2561/11904, units 101
#
# time 2.55, GROUP 2566/11904, units 101
#
# time 2.55, GROUP 2571/11904, units 101
#
# time 2.55, GROUP 2576/11904, units 101
#
# time 2.55, GROUP 2581/11904, units 102
#
# time 2.70, GROUP 2586/11904, units 105
#
# time 2.70, GROUP 2591/11904, units 105
#
# time 2.70, GROUP 2596/11904, units 105
#
# time 2.70, GROUP 2601/11904, units 105
#
# time 2.70, GROUP 2606/11904, units 105
#
# time 2.70, GROUP 2611/11904, units 105
#
# time 2.70, GROUP 2616/11904, units 105
#
# time 2.70, GROUP 2621/11904, units 105
#
# time 2.70, GROUP 2626/11904, units 105
#
# time 2.70, GROUP 2631/11904, units 105
#
# time 2.70, GROUP 2636/11904, units 105
#
# time 2.70, GROUP 2641/11904, units 105
#
# time 2.70, GROUP 2646/11904, units 105
#
# time 2.70, GROUP 2651/11904, units 105
#
# time 2.70, GROUP 2656/11904, units 105
#
# time 2.70, GROUP 2661/11904, units 105
#
# time 2.70, GROUP 2666/11904, units 105
#
# time 2.70, GROUP 2671/11904, units 107
#
# time 2.70, GROUP 2676/11904, units 108
#
# time 2.73, GROUP 2681/11904, units 111
#
# time 2.73, GROUP 2686/11904, units 111
#
# time 2.73, GROUP 2691/11904, units 111
#
# time 2.73, GROUP 2696/11904, units 111
#
# time 2.73, GROUP 2701/11904, units 111
#
# time 2.73, GROUP 2706/11904, units 111
#
# time 2.73, GROUP 2711/11904, units 111
#
# time 2.73, GROUP 2716/11904, units 111
#
# time 2.73, GROUP 2721/11904, units 111
#
# time 2.73, GROUP 2726/11904, units 111
#
# time 2.73, GROUP 2731/11904, units 111
#
# time 2.73, GROUP 2736/11904, units 111
#
# time 2.73, GROUP 2741/11904, units 111
#
# time 2.73, GROUP 2746/11904, units 111
#
# time 2.73, GROUP 2751/11904, units 111
#
# time 2.73, GROUP 2756/11904, units 111
#
# time 2.73, GROUP 2761/11904, units 111
#
# time 2.73, GROUP 2766/11904, units 111
#
# time 2.73, GROUP 2771/11904, units 113
#
# time 2.73, GROUP 2776/11904, units 115
#
# time 2.73, GROUP 2781/11904, units 115
#
# time 2.73, GROUP 2786/11904, units 115
#
# time 2.73, GROUP 2791/11904, units 115
#
# time 2.73, GROUP 2796/11904, units 115
#
# time 2.73, GROUP 2801/11904, units 115
#
# time 2.73, GROUP 2806/11904, units 115
#
# time 2.73, GROUP 2811/11904, units 115
#
# time 2.73, GROUP 2816/11904, units 115
#
# time 2.73, GROUP 2821/11904, units 115
#
# time 2.73, GROUP 2826/11904, units 115
#
# time 2.73, GROUP 2831/11904, units 115
#
# time 2.73, GROUP 2836/11904, units 115
#
# time 2.73, GROUP 2841/11904, units 115
#
# time 2.73, GROUP 2846/11904, units 115
#
# time 2.73, GROUP 2851/11904, units 115
#
# time 2.73, GROUP 2856/11904, units 115
#
# time 2.83, GROUP 2861/11904, units 117
#
# time 2.83, GROUP 2866/11904, units 117
#
# time 2.83, GROUP 2871/11904, units 117
#
# time 2.83, GROUP 2876/11904, units 117
#
# time 2.83, GROUP 2881/11904, units 117
#
# time 2.83, GROUP 2886/11904, units 117
#
# time 2.83, GROUP 2891/11904, units 117
#
# time 2.83, GROUP 2896/11904, units 117
#
# time 2.83, GROUP 2901/11904, units 117
#
# time 2.83, GROUP 2906/11904, units 117
#
# time 2.83, GROUP 2911/11904, units 117
#
# time 2.83, GROUP 2916/11904, units 117
#
# time 2.83, GROUP 2921/11904, units 117
#
# time 2.83, GROUP 2926/11904, units 117
#
# time 2.83, GROUP 2931/11904, units 117
#
# time 2.83, GROUP 2936/11904, units 117
#
# time 2.83, GROUP 2941/11904, units 117
#
# time 2.87, GROUP 2946/11904, units 118
#
# time 2.88, GROUP 2951/11904, units 119
#
# time 2.88, GROUP 2956/11904, units 120
#
# time 2.88, GROUP 2961/11904, units 121
#
# time 2.88, GROUP 2966/11904, units 121
#
# time 2.88, GROUP 2971/11904, units 121
#
# time 2.88, GROUP 2976/11904, units 121
#
# time 2.88, GROUP 2981/11904, units 121
#
# time 2.88, GROUP 2986/11904, units 121
#
# time 2.88, GROUP 2991/11904, units 121
#
# time 2.88, GROUP 2996/11904, units 121
#
# time 2.88, GROUP 3001/11904, units 121
#
# time 2.88, GROUP 3006/11904, units 121
#
# time 2.88, GROUP 3011/11904, units 121
#
# time 2.88, GROUP 3016/11904, units 121
#
# time 2.88, GROUP 3021/11904, units 121
#
# time 2.88, GROUP 3026/11904, units 121
#
# time 2.88, GROUP 3031/11904, units 121
#
# time 2.88, GROUP 3036/11904, units 121
#
# time 2.88, GROUP 3041/11904, units 121
#
# time 3.02, GROUP 3046/11904, units 126
#
# time 3.02, GROUP 3051/11904, units 126
#
# time 3.02, GROUP 3056/11904, units 126
#
# time 3.02, GROUP 3061/11904, units 126
#
# time 3.02, GROUP 3066/11904, units 126
#
# time 3.02, GROUP 3071/11904, units 126
#
# time 3.02, GROUP 3076/11904, units 126
#
# time 3.02, GROUP 3081/11904, units 126
#
# time 3.02, GROUP 3086/11904, units 126
#
# time 3.02, GROUP 3091/11904, units 126
#
# time 3.02, GROUP 3096/11904, units 126
#
# time 3.02, GROUP 3101/11904, units 126
#
# time 3.02, GROUP 3106/11904, units 126
#
# time 3.02, GROUP 3111/11904, units 126
#
# time 3.02, GROUP 3116/11904, units 126
#
# time 3.02, GROUP 3121/11904, units 126
#
# time 3.02, GROUP 3126/11904, units 126
#
# time 3.07, GROUP 3131/11904, units 127
#
# time 3.12, GROUP 3136/11904, units 129
#
# time 3.24, GROUP 3141/11904, units 131
#
# time 3.24, GROUP 3146/11904, units 131
#
# time 3.24, GROUP 3151/11904, units 131
#
# time 3.24, GROUP 3156/11904, units 131
#
# time 3.24, GROUP 3161/11904, units 131
#
# time 3.24, GROUP 3166/11904, units 131
#
# time 3.24, GROUP 3171/11904, units 131
#
# time 3.24, GROUP 3176/11904, units 131
#
# time 3.24, GROUP 3181/11904, units 131
#
# time 3.24, GROUP 3186/11904, units 131
#
# time 3.24, GROUP 3191/11904, units 131
#
# time 3.24, GROUP 3196/11904, units 131
#
# time 3.24, GROUP 3201/11904, units 131
#
# time 3.24, GROUP 3206/11904, units 131
#
# time 3.24, GROUP 3211/11904, units 131
#
# time 3.24, GROUP 3216/11904, units 131
#
# time 3.24, GROUP 3221/11904, units 131
#
# time 3.24, GROUP 3226/11904, units 131
#
# time 3.28, GROUP 3231/11904, units 132
#
# time 3.28, GROUP 3236/11904, units 133
#
# time 3.28, GROUP 3241/11904, units 133
#
# time 3.28, GROUP 3246/11904, units 133
#
# time 3.28, GROUP 3251/11904, units 133
#
# time 3.28, GROUP 3256/11904, units 133
#
# time 3.28, GROUP 3261/11904, units 133
#
# time 3.28, GROUP 3266/11904, units 133
#
# time 3.28, GROUP 3271/11904, units 133
#
# time 3.28, GROUP 3276/11904, units 133
#
# time 3.28, GROUP 3281/11904, units 133
#
# time 3.28, GROUP 3286/11904, units 133
#
# time 3.28, GROUP 3291/11904, units 133
#
# time 3.28, GROUP 3296/11904, units 133
#
# time 3.29, GROUP 3301/11904, units 133
#
# time 3.29, GROUP 3306/11904, units 133
#
# time 3.29, GROUP 3311/11904, units 133
#
# time 3.29, GROUP 3316/11904, units 133
#
# time 3.29, GROUP 3321/11904, units 134
#
# time 3.29, GROUP 3326/11904, units 134
#
# time 3.29, GROUP 3331/11904, units 134
#
# time 3.29, GROUP 3336/11904, units 134
#
# time 3.29, GROUP 3341/11904, units 134
#
# time 3.29, GROUP 3346/11904, units 134
#
# time 3.29, GROUP 3351/11904, units 134
#
# time 3.29, GROUP 3356/11904, units 134
#
# time 3.29, GROUP 3361/11904, units 134
#
# time 3.29, GROUP 3366/11904, units 134
#
# time 3.29, GROUP 3371/11904, units 134
#
# time 3.29, GROUP 3376/11904, units 134
#
# time 3.29, GROUP 3381/11904, units 134
#
# time 3.29, GROUP 3386/11904, units 134
#
# time 3.29, GROUP 3391/11904, units 134
#
# time 3.29, GROUP 3396/11904, units 134
#
# time 3.29, GROUP 3401/11904, units 134
#
# time 3.29, GROUP 3406/11904, units 134
#
# time 3.31, GROUP 3411/11904, units 137
#
# time 3.31, GROUP 3416/11904, units 137
#
# time 3.45, GROUP 3421/11904, units 141
#
# time 3.45, GROUP 3426/11904, units 141
#
# time 3.45, GROUP 3431/11904, units 141
#
# time 3.45, GROUP 3436/11904, units 141
#
# time 3.45, GROUP 3441/11904, units 141
#
# time 3.45, GROUP 3446/11904, units 141
#
# time 3.45, GROUP 3451/11904, units 141
#
# time 3.45, GROUP 3456/11904, units 141
#
# time 3.45, GROUP 3461/11904, units 141
#
# time 3.45, GROUP 3466/11904, units 141
#
# time 3.45, GROUP 3471/11904, units 141
#
# time 3.45, GROUP 3476/11904, units 141
#
# time 3.45, GROUP 3481/11904, units 141
#
# time 3.45, GROUP 3486/11904, units 141
#
# time 3.45, GROUP 3491/11904, units 141
#
# time 3.45, GROUP 3496/11904, units 141
#
# time 3.45, GROUP 3501/11904, units 141
#
# time 3.45, GROUP 3506/11904, units 143
#
# time 3.46, GROUP 3511/11904, units 145
#
# time 3.46, GROUP 3516/11904, units 145
#
# time 3.46, GROUP 3521/11904, units 145
#
# time 3.46, GROUP 3526/11904, units 145
#
# time 3.46, GROUP 3531/11904, units 145
#
# time 3.46, GROUP 3536/11904, units 145
#
# time 3.46, GROUP 3541/11904, units 145
#
# time 3.46, GROUP 3546/11904, units 145
#
# time 3.46, GROUP 3551/11904, units 145
#
# time 3.46, GROUP 3556/11904, units 145
#
# time 3.46, GROUP 3561/11904, units 145
#
# time 3.46, GROUP 3566/11904, units 145
#
# time 3.46, GROUP 3571/11904, units 145
#
# time 3.46, GROUP 3576/11904, units 145
#
# time 3.46, GROUP 3581/11904, units 145
#
# time 3.46, GROUP 3586/11904, units 145
#
# time 3.46, GROUP 3591/11904, units 145
#
# time 3.69, GROUP 3596/11904, units 151
#
# time 3.76, GROUP 3601/11904, units 153
#
# time 3.86, GROUP 3606/11904, units 156
#
# time 3.86, GROUP 3611/11904, units 156
#
# time 3.86, GROUP 3616/11904, units 156
#
# time 3.86, GROUP 3621/11904, units 156
#
# time 3.86, GROUP 3626/11904, units 156
#
# time 3.86, GROUP 3631/11904, units 156
#
# time 3.86, GROUP 3636/11904, units 156
#
# time 3.86, GROUP 3641/11904, units 156
#
# time 3.86, GROUP 3646/11904, units 156
#
# time 3.86, GROUP 3651/11904, units 156
#
# time 3.86, GROUP 3656/11904, units 156
#
# time 3.86, GROUP 3661/11904, units 156
#
# time 3.86, GROUP 3666/11904, units 156
#
# time 3.86, GROUP 3671/11904, units 156
#
# time 3.86, GROUP 3676/11904, units 156
#
# time 3.86, GROUP 3681/11904, units 156
#
# time 3.86, GROUP 3686/11904, units 156
#
# time 3.86, GROUP 3691/11904, units 157
#
# time 3.96, GROUP 3696/11904, units 160
#
# time 3.96, GROUP 3701/11904, units 160
#
# time 3.96, GROUP 3706/11904, units 160
#
# time 3.96, GROUP 3711/11904, units 160
#
# time 3.96, GROUP 3716/11904, units 160
#
# time 3.96, GROUP 3721/11904, units 160
#
# time 3.96, GROUP 3726/11904, units 160
#
# time 3.96, GROUP 3731/11904, units 160
#
# time 3.96, GROUP 3736/11904, units 160
#
# time 3.96, GROUP 3741/11904, units 160
#
# time 3.96, GROUP 3746/11904, units 160
#
# time 3.96, GROUP 3751/11904, units 160
#
# time 3.96, GROUP 3756/11904, units 160
#
# time 3.96, GROUP 3761/11904, units 160
#
# time 3.96, GROUP 3766/11904, units 160
#
# time 3.96, GROUP 3771/11904, units 160
#
# time 3.96, GROUP 3776/11904, units 160
#
# time 4.01, GROUP 3781/11904, units 162
#
# time 4.01, GROUP 3786/11904, units 162
#
# time 4.01, GROUP 3791/11904, units 162
#
# time 4.01, GROUP 3796/11904, units 162
#
# time 4.01, GROUP 3801/11904, units 162
#
# time 4.01, GROUP 3806/11904, units 162
#
# time 4.01, GROUP 3811/11904, units 162
#
# time 4.01, GROUP 3816/11904, units 162
#
# time 4.01, GROUP 3821/11904, units 162
#
# time 4.01, GROUP 3826/11904, units 162
#
# time 4.01, GROUP 3831/11904, units 162
#
# time 4.01, GROUP 3836/11904, units 162
#
# time 4.01, GROUP 3841/11904, units 162
#
# time 4.01, GROUP 3846/11904, units 162
#
# time 4.01, GROUP 3851/11904, units 162
#
# time 4.01, GROUP 3856/11904, units 162
#
# time 4.01, GROUP 3861/11904, units 162
#
# time 4.01, GROUP 3866/11904, units 162
#
# time 4.01, GROUP 3871/11904, units 164
#
# time 4.01, GROUP 3876/11904, units 164
#
# time 4.06, GROUP 3881/11904, units 165
#
# time 4.06, GROUP 3886/11904, units 165
#
# time 4.06, GROUP 3891/11904, units 165
#
# time 4.06, GROUP 3896/11904, units 165
#
# time 4.06, GROUP 3901/11904, units 165
#
# time 4.06, GROUP 3906/11904, units 165
#
# time 4.06, GROUP 3911/11904, units 165
#
# time 4.06, GROUP 3916/11904, units 165
#
# time 4.06, GROUP 3921/11904, units 165
#
# time 4.06, GROUP 3926/11904, units 165
#
# time 4.06, GROUP 3931/11904, units 165
#
# time 4.06, GROUP 3936/11904, units 165
#
# time 4.06, GROUP 3941/11904, units 165
#
# time 4.06, GROUP 3946/11904, units 165
#
# time 4.06, GROUP 3951/11904, units 165
#
# time 4.06, GROUP 3956/11904, units 165
#
# time 4.06, GROUP 3961/11904, units 165
#
# time 4.06, GROUP 3966/11904, units 165
#
# time 4.19, GROUP 3971/11904, units 168
#
# time 4.19, GROUP 3976/11904, units 168
#
# time 4.19, GROUP 3981/11904, units 168
#
# time 4.19, GROUP 3986/11904, units 168
#
# time 4.19, GROUP 3991/11904, units 168
#
# time 4.19, GROUP 3996/11904, units 168
#
# time 4.19, GROUP 4001/11904, units 168
#
# time 4.19, GROUP 4006/11904, units 168
#
# time 4.19, GROUP 4011/11904, units 168
#
# time 4.19, GROUP 4016/11904, units 168
#
# time 4.19, GROUP 4021/11904, units 168
#
# time 4.19, GROUP 4026/11904, units 168
#
# time 4.19, GROUP 4031/11904, units 168
#
# time 4.19, GROUP 4036/11904, units 168
#
# time 4.19, GROUP 4041/11904, units 168
#
# time 4.19, GROUP 4046/11904, units 168
#
# time 4.19, GROUP 4051/11904, units 168
#
# time 4.28, GROUP 4056/11904, units 170
#
# time 4.33, GROUP 4061/11904, units 171
#
# time 4.33, GROUP 4066/11904, units 171
#
# time 4.33, GROUP 4071/11904, units 171
#
# time 4.33, GROUP 4076/11904, units 171
#
# time 4.33, GROUP 4081/11904, units 171
#
# time 4.33, GROUP 4086/11904, units 171
#
# time 4.33, GROUP 4091/11904, units 171
#
# time 4.33, GROUP 4096/11904, units 171
#
# time 4.33, GROUP 4101/11904, units 171
#
# time 4.33, GROUP 4106/11904, units 171
#
# time 4.33, GROUP 4111/11904, units 171
#
# time 4.33, GROUP 4116/11904, units 171
#
# time 4.33, GROUP 4121/11904, units 171
#
# time 4.33, GROUP 4126/11904, units 171
#
# time 4.33, GROUP 4131/11904, units 171
#
# time 4.33, GROUP 4136/11904, units 171
#
# time 4.33, GROUP 4141/11904, units 171
#
# time 4.33, GROUP 4146/11904, units 171
#
# time 4.40, GROUP 4151/11904, units 173
#
# time 4.43, GROUP 4156/11904, units 176
#
# time 4.90, GROUP 4161/11904, units 185
#
# time 4.90, GROUP 4166/11904, units 185
#
# time 4.90, GROUP 4171/11904, units 185
#
# time 4.90, GROUP 4176/11904, units 185
#
# time 4.90, GROUP 4181/11904, units 185
#
# time 4.90, GROUP 4186/11904, units 185
#
# time 4.90, GROUP 4191/11904, units 185
#
# time 4.90, GROUP 4196/11904, units 185
#
# time 4.90, GROUP 4201/11904, units 185
#
# time 4.90, GROUP 4206/11904, units 185
#
# time 4.90, GROUP 4211/11904, units 185
#
# time 4.90, GROUP 4216/11904, units 185
#
# time 4.90, GROUP 4221/11904, units 185
#
# time 4.90, GROUP 4226/11904, units 185
#
# time 4.91, GROUP 4231/11904, units 185
#
# time 4.91, GROUP 4236/11904, units 185
#
# time 4.91, GROUP 4241/11904, units 185
#
# time 5.02, GROUP 4246/11904, units 189
#
# time 5.02, GROUP 4251/11904, units 189
#
# time 5.02, GROUP 4256/11904, units 189
#
# time 5.02, GROUP 4261/11904, units 189
#
# time 5.02, GROUP 4266/11904, units 189
#
# time 5.02, GROUP 4271/11904, units 189
#
# time 5.02, GROUP 4276/11904, units 189
#
# time 5.02, GROUP 4281/11904, units 189
#
# time 5.02, GROUP 4286/11904, units 189
#
# time 5.02, GROUP 4291/11904, units 189
#
# time 5.02, GROUP 4296/11904, units 189
#
# time 5.02, GROUP 4301/11904, units 189
#
# time 5.02, GROUP 4306/11904, units 189
#
# time 5.02, GROUP 4311/11904, units 189
#
# time 5.02, GROUP 4316/11904, units 189
#
# time 5.02, GROUP 4321/11904, units 189
#
# time 5.02, GROUP 4326/11904, units 189
#
# time 5.30, GROUP 4331/11904, units 194
#
# time 5.40, GROUP 4336/11904, units 196
#
# time 5.49, GROUP 4341/11904, units 199
#
# time 5.82, GROUP 4346/11904, units 205
#
# time 5.82, GROUP 4351/11904, units 205
#
# time 5.82, GROUP 4356/11904, units 205
#
# time 5.82, GROUP 4361/11904, units 205
#
# time 5.82, GROUP 4366/11904, units 205
#
# time 5.82, GROUP 4371/11904, units 205
#
# time 5.82, GROUP 4376/11904, units 205
#
# time 5.82, GROUP 4381/11904, units 205
#
# time 5.82, GROUP 4386/11904, units 205
#
# time 5.82, GROUP 4391/11904, units 205
#
# time 5.82, GROUP 4396/11904, units 205
#
# time 5.82, GROUP 4401/11904, units 205
#
# time 5.82, GROUP 4406/11904, units 205
#
# time 5.82, GROUP 4411/11904, units 205
#
# time 5.82, GROUP 4416/11904, units 205
#
# time 5.82, GROUP 4421/11904, units 205
#
# time 5.82, GROUP 4426/11904, units 205
#
# time 6.23, GROUP 4431/11904, units 213
#
# time 6.23, GROUP 4436/11904, units 213
#
# time 6.23, GROUP 4441/11904, units 213
#
# time 6.23, GROUP 4446/11904, units 213
#
# time 6.23, GROUP 4451/11904, units 213
#
# time 6.23, GROUP 4456/11904, units 213
#
# time 6.23, GROUP 4461/11904, units 213
#
# time 6.23, GROUP 4466/11904, units 213
#
# time 6.23, GROUP 4471/11904, units 213
#
# time 6.23, GROUP 4476/11904, units 213
#
# time 6.23, GROUP 4481/11904, units 213
#
# time 6.23, GROUP 4486/11904, units 213
#
# time 6.23, GROUP 4491/11904, units 213
#
# time 6.23, GROUP 4496/11904, units 213
#
# time 6.23, GROUP 4501/11904, units 213
#
# time 6.23, GROUP 4506/11904, units 213
#
# time 6.23, GROUP 4511/11904, units 213
#
# time 6.47, GROUP 4516/11904, units 219
#
# time 6.54, GROUP 4521/11904, units 222
#
# time 6.54, GROUP 4526/11904, units 222
#
# time 6.54, GROUP 4531/11904, units 222
#
# time 6.54, GROUP 4536/11904, units 222
#
# time 6.54, GROUP 4541/11904, units 222
#
# time 6.54, GROUP 4546/11904, units 222
#
# time 6.54, GROUP 4551/11904, units 222
#
# time 6.54, GROUP 4556/11904, units 222
#
# time 6.54, GROUP 4561/11904, units 222
#
# time 6.54, GROUP 4566/11904, units 222
#
# time 6.54, GROUP 4571/11904, units 222
#
# time 6.54, GROUP 4576/11904, units 222
#
# time 6.54, GROUP 4581/11904, units 222
#
# time 6.54, GROUP 4586/11904, units 222
#
# time 6.54, GROUP 4591/11904, units 222
#
# time 6.54, GROUP 4596/11904, units 222
#
# time 6.54, GROUP 4601/11904, units 222
#
# time 6.54, GROUP 4606/11904, units 222
#
# time 6.95, GROUP 4611/11904, units 229
#
# time 7.00, GROUP 4616/11904, units 230
#
# time 7.56, GROUP 4621/11904, units 238
#
# time 7.56, GROUP 4626/11904, units 238
#
# time 7.56, GROUP 4631/11904, units 238
#
# time 7.56, GROUP 4636/11904, units 238
#
# time 7.56, GROUP 4641/11904, units 238
#
# time 7.56, GROUP 4646/11904, units 238
#
# time 7.56, GROUP 4651/11904, units 238
#
# time 7.56, GROUP 4656/11904, units 238
#
# time 7.56, GROUP 4661/11904, units 238
#
# time 7.56, GROUP 4666/11904, units 238
#
# time 7.56, GROUP 4671/11904, units 238
#
# time 7.56, GROUP 4676/11904, units 238
#
# time 7.56, GROUP 4681/11904, units 238
#
# time 7.56, GROUP 4686/11904, units 238
#
# time 7.56, GROUP 4691/11904, units 238
#
# time 7.56, GROUP 4696/11904, units 238
#
# time 7.56, GROUP 4701/11904, units 238
#
# time 7.73, GROUP 4706/11904, units 242
#
# time 7.73, GROUP 4711/11904, units 243
#
# time 7.73, GROUP 4716/11904, units 243
#
# time 7.73, GROUP 4721/11904, units 243
#
# time 7.73, GROUP 4726/11904, units 243
#
# time 7.73, GROUP 4731/11904, units 243
#
# time 7.73, GROUP 4736/11904, units 243
#
# time 7.73, GROUP 4741/11904, units 243
#
# time 7.73, GROUP 4746/11904, units 243
#
# time 7.73, GROUP 4751/11904, units 243
#
# time 7.73, GROUP 4756/11904, units 243
#
# time 7.73, GROUP 4761/11904, units 243
#
# time 7.73, GROUP 4766/11904, units 243
#
# time 7.73, GROUP 4771/11904, units 243
#
# time 7.73, GROUP 4776/11904, units 243
#
# time 7.73, GROUP 4781/11904, units 243
#
# time 7.73, GROUP 4786/11904, units 243
#
# time 7.73, GROUP 4791/11904, units 243
#
# time 8.13, GROUP 4796/11904, units 248
#
# time 8.13, GROUP 4801/11904, units 248
#
# time 8.53, GROUP 4806/11904, units 255
#
# time 8.53, GROUP 4811/11904, units 255
#
# time 8.53, GROUP 4816/11904, units 255
#
# time 8.53, GROUP 4821/11904, units 255
#
# time 8.53, GROUP 4826/11904, units 255
#
# time 8.53, GROUP 4831/11904, units 255
#
# time 8.53, GROUP 4836/11904, units 255
#
# time 8.53, GROUP 4841/11904, units 255
#
# time 8.53, GROUP 4846/11904, units 255
#
# time 8.53, GROUP 4851/11904, units 255
#
# time 8.53, GROUP 4856/11904, units 255
#
# time 8.53, GROUP 4861/11904, units 255
#
# time 8.53, GROUP 4866/11904, units 255
#
# time 8.53, GROUP 4871/11904, units 255
#
# time 8.53, GROUP 4876/11904, units 255
#
# time 8.53, GROUP 4881/11904, units 255
#
# time 8.53, GROUP 4886/11904, units 255
#
# time 8.53, GROUP 4891/11904, units 255
#
# time 8.76, GROUP 4896/11904, units 260
#
# time 8.76, GROUP 4901/11904, units 260
#
# time 8.76, GROUP 4906/11904, units 260
#
# time 8.76, GROUP 4911/11904, units 260
#
# time 8.76, GROUP 4916/11904, units 260
#
# time 8.76, GROUP 4921/11904, units 260
#
# time 8.76, GROUP 4926/11904, units 260
#
# time 8.76, GROUP 4931/11904, units 260
#
# time 8.76, GROUP 4936/11904, units 260
#
# time 8.76, GROUP 4941/11904, units 260
#
# time 8.76, GROUP 4946/11904, units 260
#
# time 8.76, GROUP 4951/11904, units 260
#
# time 8.76, GROUP 4956/11904, units 260
#
# time 8.76, GROUP 4961/11904, units 260
#
# time 8.76, GROUP 4966/11904, units 260
#
# time 8.76, GROUP 4971/11904, units 260
#
# time 8.76, GROUP 4976/11904, units 260
#
# time 8.83, GROUP 4981/11904, units 264
#
# time 8.91, GROUP 4986/11904, units 266
#
# time 8.91, GROUP 4991/11904, units 266
#
# time 8.91, GROUP 4996/11904, units 266
#
# time 8.91, GROUP 5001/11904, units 266
#
# time 8.91, GROUP 5006/11904, units 266
#
# time 8.91, GROUP 5011/11904, units 266
#
# time 8.91, GROUP 5016/11904, units 266
#
# time 8.91, GROUP 5021/11904, units 266
#
# time 8.91, GROUP 5026/11904, units 266
#
# time 8.91, GROUP 5031/11904, units 266
#
# time 8.91, GROUP 5036/11904, units 266
#
# time 8.91, GROUP 5041/11904, units 266
#
# time 8.91, GROUP 5046/11904, units 266
#
# time 8.91, GROUP 5051/11904, units 266
#
# time 8.91, GROUP 5056/11904, units 266
#
# time 8.91, GROUP 5061/11904, units 266
#
# time 8.91, GROUP 5066/11904, units 266
#
# time 9.09, GROUP 5071/11904, units 271
#
# time 9.16, GROUP 5076/11904, units 273
#
# time 9.37, GROUP 5081/11904, units 279
#
# time 9.37, GROUP 5086/11904, units 279
#
# time 9.37, GROUP 5091/11904, units 279
#
# time 9.37, GROUP 5096/11904, units 279
#
# time 9.37, GROUP 5101/11904, units 279
#
# time 9.37, GROUP 5106/11904, units 279
#
# time 9.37, GROUP 5111/11904, units 279
#
# time 9.37, GROUP 5116/11904, units 279
#
# time 9.37, GROUP 5121/11904, units 279
#
# time 9.37, GROUP 5126/11904, units 279
#
# time 9.37, GROUP 5131/11904, units 279
#
# time 9.37, GROUP 5136/11904, units 279
#
# time 9.37, GROUP 5141/11904, units 279
#
# time 9.37, GROUP 5146/11904, units 279
#
# time 9.37, GROUP 5151/11904, units 279
#
# time 9.37, GROUP 5156/11904, units 279
#
# time 9.37, GROUP 5161/11904, units 279
#
# time 9.66, GROUP 5166/11904, units 284
#
# time 9.86, GROUP 5171/11904, units 289
#
# time 9.86, GROUP 5176/11904, units 289
#
# time 9.86, GROUP 5181/11904, units 289
#
# time 9.86, GROUP 5186/11904, units 289
#
# time 9.86, GROUP 5191/11904, units 289
#
# time 9.86, GROUP 5196/11904, units 289
#
# time 9.86, GROUP 5201/11904, units 289
#
# time 9.86, GROUP 5206/11904, units 289
#
# time 9.86, GROUP 5211/11904, units 289
#
# time 9.86, GROUP 5216/11904, units 289
#
# time 9.86, GROUP 5221/11904, units 289
#
# time 9.86, GROUP 5226/11904, units 289
#
# time 9.86, GROUP 5231/11904, units 289
#
# time 9.86, GROUP 5236/11904, units 289
#
# time 9.86, GROUP 5241/11904, units 289
#
# time 9.86, GROUP 5246/11904, units 289
#
# time 9.86, GROUP 5251/11904, units 289
#
# time 10.17, GROUP 5256/11904, units 295
#
# time 10.17, GROUP 5261/11904, units 295
#
# time 10.37, GROUP 5266/11904, units 298
#
# time 10.37, GROUP 5271/11904, units 298
#
# time 10.37, GROUP 5276/11904, units 298
#
# time 10.37, GROUP 5281/11904, units 298
#
# time 10.37, GROUP 5286/11904, units 298
#
# time 10.37, GROUP 5291/11904, units 298
#
# time 10.37, GROUP 5296/11904, units 298
#
# time 10.37, GROUP 5301/11904, units 298
#
# time 10.37, GROUP 5306/11904, units 298
#
# time 10.37, GROUP 5311/11904, units 298
#
# time 10.37, GROUP 5316/11904, units 298
#
# time 10.37, GROUP 5321/11904, units 298
#
# time 10.37, GROUP 5326/11904, units 298
#
# time 10.37, GROUP 5331/11904, units 298
#
# time 10.37, GROUP 5336/11904, units 298
#
# time 10.37, GROUP 5341/11904, units 298
#
# time 10.37, GROUP 5346/11904, units 298
#
# time 10.37, GROUP 5351/11904, units 298
#
# time 10.60, GROUP 5356/11904, units 303
#
# time 10.60, GROUP 5361/11904, units 303
#
# time 10.60, GROUP 5366/11904, units 303
#
# time 10.60, GROUP 5371/11904, units 303
#
# time 10.60, GROUP 5376/11904, units 303
#
# time 10.60, GROUP 5381/11904, units 303
#
# time 10.60, GROUP 5386/11904, units 303
#
# time 10.60, GROUP 5391/11904, units 303
#
# time 10.60, GROUP 5396/11904, units 303
#
# time 10.60, GROUP 5401/11904, units 303
#
# time 10.61, GROUP 5406/11904, units 303
#
# time 10.61, GROUP 5411/11904, units 303
#
# time 10.61, GROUP 5416/11904, units 303
#
# time 10.61, GROUP 5421/11904, units 303
#
# time 10.61, GROUP 5426/11904, units 303
#
# time 10.61, GROUP 5431/11904, units 303
#
# time 10.61, GROUP 5436/11904, units 303
#
# time 10.79, GROUP 5441/11904, units 306
#
# time 10.96, GROUP 5446/11904, units 310
#
# time 10.96, GROUP 5451/11904, units 310
#
# time 10.96, GROUP 5456/11904, units 310
#
# time 10.96, GROUP 5461/11904, units 310
#
# time 10.96, GROUP 5466/11904, units 310
#
# time 10.96, GROUP 5471/11904, units 310
#
# time 10.96, GROUP 5476/11904, units 310
#
# time 10.96, GROUP 5481/11904, units 310
#
# time 10.96, GROUP 5486/11904, units 310
#
# time 10.96, GROUP 5491/11904, units 310
#
# time 10.96, GROUP 5496/11904, units 310
#
# time 10.96, GROUP 5501/11904, units 310
#
# time 10.96, GROUP 5506/11904, units 310
#
# time 10.96, GROUP 5511/11904, units 310
#
# time 10.96, GROUP 5516/11904, units 310
#
# time 10.96, GROUP 5521/11904, units 310
#
# time 10.96, GROUP 5526/11904, units 310
#
# time 10.96, GROUP 5531/11904, units 310
#
# time 11.25, GROUP 5536/11904, units 316
#
# time 11.34, GROUP 5541/11904, units 319
#
# time 11.67, GROUP 5546/11904, units 325
#
# time 11.67, GROUP 5551/11904, units 325
#
# time 11.67, GROUP 5556/11904, units 325
#
# time 11.67, GROUP 5561/11904, units 325
#
# time 11.67, GROUP 5566/11904, units 325
#
# time 11.67, GROUP 5571/11904, units 325
#
# time 11.67, GROUP 5576/11904, units 325
#
# time 11.67, GROUP 5581/11904, units 325
#
# time 11.67, GROUP 5586/11904, units 325
#
# time 11.67, GROUP 5591/11904, units 325
#
# time 11.67, GROUP 5596/11904, units 325
#
# time 11.67, GROUP 5601/11904, units 325
#
# time 11.67, GROUP 5606/11904, units 325
#
# time 11.67, GROUP 5611/11904, units 325
#
# time 11.67, GROUP 5616/11904, units 325
#
# time 11.67, GROUP 5621/11904, units 325
#
# time 11.67, GROUP 5626/11904, units 325
#
# time 11.92, GROUP 5631/11904, units 331
#
# time 11.93, GROUP 5636/11904, units 332
#
# time 11.93, GROUP 5641/11904, units 332
#
# time 11.93, GROUP 5646/11904, units 332
#
# time 11.93, GROUP 5651/11904, units 332
#
# time 11.93, GROUP 5656/11904, units 332
#
# time 11.93, GROUP 5661/11904, units 332
#
# time 11.93, GROUP 5666/11904, units 332
#
# time 11.93, GROUP 5671/11904, units 332
#
# time 11.93, GROUP 5676/11904, units 332
#
# time 11.93, GROUP 5681/11904, units 332
#
# time 11.93, GROUP 5686/11904, units 332
#
# time 11.93, GROUP 5691/11904, units 332
#
# time 11.93, GROUP 5696/11904, units 332
#
# time 11.93, GROUP 5701/11904, units 332
#
# time 11.93, GROUP 5706/11904, units 332
#
# time 11.93, GROUP 5711/11904, units 332
#
# time 11.97, GROUP 5716/11904, units 333
#
# time 12.02, GROUP 5721/11904, units 334
#
# time 12.21, GROUP 5726/11904, units 337
#
# time 12.37, GROUP 5731/11904, units 340
#
# time 12.37, GROUP 5736/11904, units 340
#
# time 12.37, GROUP 5741/11904, units 340
#
# time 12.37, GROUP 5746/11904, units 340
#
# time 12.37, GROUP 5751/11904, units 340
#
# time 12.37, GROUP 5756/11904, units 340
#
# time 12.37, GROUP 5761/11904, units 340
#
# time 12.37, GROUP 5766/11904, units 340
#
# time 12.37, GROUP 5771/11904, units 340
#
# time 12.37, GROUP 5776/11904, units 340
#
# time 12.37, GROUP 5781/11904, units 340
#
# time 12.37, GROUP 5786/11904, units 340
#
# time 12.37, GROUP 5791/11904, units 340
#
# time 12.37, GROUP 5796/11904, units 340
#
# time 12.37, GROUP 5801/11904, units 340
#
# time 12.37, GROUP 5806/11904, units 340
#
# time 12.37, GROUP 5811/11904, units 340
#
# time 12.47, GROUP 5816/11904, units 344
#
# time 12.47, GROUP 5821/11904, units 344
#
# time 12.47, GROUP 5826/11904, units 344
#
# time 12.47, GROUP 5831/11904, units 344
#
# time 12.47, GROUP 5836/11904, units 344
#
# time 12.47, GROUP 5841/11904, units 344
#
# time 12.47, GROUP 5846/11904, units 344
#
# time 12.47, GROUP 5851/11904, units 344
#
# time 12.47, GROUP 5856/11904, units 344
#
# time 12.47, GROUP 5861/11904, units 344
#
# time 12.47, GROUP 5866/11904, units 344
#
# time 12.47, GROUP 5871/11904, units 344
#
# time 12.47, GROUP 5876/11904, units 344
#
# time 12.47, GROUP 5881/11904, units 344
#
# time 12.47, GROUP 5886/11904, units 344
#
# time 12.47, GROUP 5891/11904, units 344
#
# time 12.47, GROUP 5896/11904, units 344
#
# time 12.47, GROUP 5901/11904, units 344
#
# time 12.68, GROUP 5906/11904, units 348
#
# time 12.68, GROUP 5911/11904, units 348
#
# time 12.68, GROUP 5916/11904, units 348
#
# time 12.68, GROUP 5921/11904, units 348
#
# time 12.68, GROUP 5926/11904, units 348
#
# time 12.68, GROUP 5931/11904, units 348
#
# time 12.68, GROUP 5936/11904, units 348
#
# time 12.68, GROUP 5941/11904, units 348
#
# time 12.68, GROUP 5946/11904, units 348
#
# time 12.68, GROUP 5951/11904, units 348
#
# time 12.68, GROUP 5956/11904, units 348
#
# time 12.68, GROUP 5961/11904, units 348
#
# time 12.68, GROUP 5966/11904, units 348
#
# time 12.68, GROUP 5971/11904, units 348
#
# time 12.68, GROUP 5976/11904, units 348
#
# time 12.68, GROUP 5981/11904, units 348
#
# time 12.68, GROUP 5986/11904, units 348
#
# time 12.68, GROUP 5991/11904, units 348
#
# time 12.85, GROUP 5996/11904, units 351
#
# time 12.85, GROUP 6001/11904, units 351
