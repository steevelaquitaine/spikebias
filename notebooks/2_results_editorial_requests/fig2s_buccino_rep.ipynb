# %% [markdown]
# # Replicate Buccino model
#
# author: laquitainesteeve@gmail.com
#
# Simulate Buccino's model without filtering
#
# Tested on Ubuntu 24.04.1 LTS (32 cores, 188 GB RAM, Intel(R) Core(TM) i9-14900K ＠3.2 GHz/5.8 GHz) with RTX 5090 GPU with 40GB VRAM (GPU not needed)
#
# Required:
# - Storage: 14 GB for 1,500 templates (13GB) and Recording (~500 MB)
#
# tips to free up storage
#
# 0. check storage with df -h
# 1. restart the notebook kernel will free up 100 GB of storage; some large deleted files remain opened and are deleted when the kernel is restarted.
# 2. import os; import glob; for f in glob.glob('temp/pros_of_details/waveformextractor'): os.remove(f) # 100 GB saved
# 3. free up RAM: clear cache with sudo sh -c 'echo 1 >  /proc/sys/vm/drop_caches'

# %% [markdown]
# ## Setup
#
# 1. Setup "_envs/mearec_si_103_0_.yml" virtual environment
# 2. Setup jupyter kernel _$python -m ipykernel install --user --name mearec_si_0_103_0 --display-name "mearec_si_0_103_0"_

# %%
# %%time
# %load_ext autoreload
# %autoreload 2

# import packages
import os
import MEArec as mr
import numpy as np
import spikeinterface.extractors as se
import spikeinterface.sorters as sorters 
import spikeinterface.comparison as sc  
from matplotlib import pyplot as plt;
from numpy.linalg import norm as lalgnorm
import warnings
from scipy.spatial.distance import cdist
import json 
import spikeinterface as si
from spikeinterface.curation import remove_excess_spikes
from spikeinterface import extract_waveforms
from spikeinterface.core.sparsity import compute_sparsity
import spikeinterface.qualitymetrics as sqm
import spikeinterface.core.template_tools as ttools
print(si.__version__)

warnings.filterwarnings('ignore')

# SET PROJECT PATH

PROJ_PATH = "/home/steeve/steeve/epfl/code/spikebias/"
os.chdir(PROJ_PATH)

# parameters
DURATION_S = 600 # duration of recording period considered in seconds
CREATE_TEMPLATE = True

# setup simulation common template parameters
DATA_PATH = './temp/pros_of_details/'
CELLS_PATH = mr.get_default_cell_models_folder()

# parameter Buccino replicate
TEMPLATE_PARAMS_PATH = './assets/mearec/global_templates.json' # templates used for all simulations
TEMPLATES_PATH = './temp/pros_of_details/templates.h5' # warning initially was not 1500 templates but much less 200 - check if that has an effect
INPUT_PARAMS_REP_PATH =  './assets/mearec/buccino_rep/input_params.json'
OUTPUT_PARAMS_REP_PATH = './assets/mearec/buccino_rep/output_params.json'
RECORDING_REP_H5_PATH = './temp/pros_of_details/recordings.h5'
RECORDING_REP_PATH = 'dataset/00_raw/recording_buccino_rep/'

# parallel processing parameters
save_recording_params = {'n_jobs': 20, 'verbose':True, 'progress_bar':True, 'overwrite':True, 'chunk_size': 50000}

# parallel processing parameters 
job_kwargs = dict(n_jobs=-1, chunk_duration="1s", progress_bar=True)
savefig_cfg = {"transparent":True, "dpi": 400}
# Out:
# 0.103.0
# CPU times: user 5.65 s, sys: 50.7 ms, total: 5.7 s
# Wall time: 565 ms

# %% [markdown]
# ## Functions

# %%
def standardize_site_location_property(Recording, zero_coord=0):
    """
    zero_coord: coordinate with zero values
    """
    site_pos = Recording.get_channel_locations()
    site_pos = np.insert(site_pos, zero_coord, 0, axis=1)
    Recording.set_property("location3D", site_pos)
    return Recording


def set_metadata_to_mearec_simulations(recording_generator, Recording, Sorting):

    # set cell features
    features = [
        "cell_type",
        "snr",
        "mtype",
        "soma_position",
        "bursting",
        "exp_decay",
        "max_spikes_per_burst",
        "max_burst_duration",
    ]
    n_cells = len(recording_generator.spiketrains)

    # set cell properties in sorting extractor
    for feature in features:
        feature_data = []
        for cell_ix in range(n_cells):
            feature_data.append(
                recording_generator.spiketrains[cell_ix].annotations[feature]
            )
        Sorting.set_property(feature, np.array(feature_data))

    # set electrode properties in recording extractor
    # by default, channel_locations are attached to Recording extractor
    Recording.set_property("layer", np.array(["L5"] * 384))  # layer
    return Recording, Sorting


def simulate_synthetic_recording_with_mearec(
    rec_prms: dict, layer: str, templates_path: str, recording_clone_h5_path: str
):

    # generate simulated recording (takes 22 min)
    rec_gen = mr.gen_recordings(params=rec_prms, templates=templates_path)

    # from ipdb import set_trace; set_trace()

    # save simulated recording
    mr.save_recording_generator(rec_gen, recording_clone_h5_path)

    # load recording h5 file
    RecordingClone = se.MEArecRecordingExtractor(recording_clone_h5_path)
    RecordingClone.set_property("layers", np.array([layer] * 384))  # add layer metadata

    # load ground truth
    SortingClone = se.MEArecSortingExtractor(recording_clone_h5_path)

    # delete intermediate h5 file
    os.remove(recording_clone_h5_path)
    return RecordingClone, SortingClone, rec_gen


def save_simulation_parameters_to_assets(
    rec_prms: dict, rec_gen, input_params_path: str, output_params_path: str
):

    folder_path = os.path.dirname(input_params_path)
    os.makedirs(folder_path, exist_ok=True)

    # save input simulation parameters to MEAREC
    with open(input_params_path, "w") as f:
        json.dump(rec_prms, f, indent=4)

    folder_path = os.path.dirname(output_params_path)
    os.makedirs(folder_path, exist_ok=True)

    # save parameters recorded in recording generator
    with open(output_params_path, "w") as f:
        json.dump(rec_gen.params, f, indent=4)

# %% [markdown]
# ## Parametrize cell templates

# %%
# setup common cell templates, probe, and seed parameters (takes 4,531 secs)
tpl_prms = mr.get_default_templates_params()
tpl_prms["probe"] = "Neuropixels-384"  # probe
tpl_prms["n"] = (
    1500  # (default = 50) number of templates per cell model (minimum that worked to match npx_spont cell counts), I use 1500.
)
tpl_prms["seed"] = 0  # setup reproducibility
tpl_prms["overhang"] = (
    50  # (default = 30) extension in um beyond MEA boundaries for neuron locations
)
tpl_prms["ncontacts"] = (
    1  # (default = 10) number of contacts per recording site, spatial extent of the electrode over which to average potential
)
tpl_prms["offset"] = (
    0  # (default = 0) x offset; MEA is in the yz plane with x 0 by default. One can center the MEA in cell population by setting x offset.
)
tpl_prms["xlim"] = [
    -50,
    50,
]  # (default = [10,80]) limits ( low high ) for neuron locations in the x-axis (depth)
tpl_prms["ylim"] = (
    None  # (default = None) limits ( low high ) for neuron locations in the y-axis
)
tpl_prms["zlim"] = [
    -1001,
    1001,
]  # (default = None) limits ( low high ) for neuron locations in the z-axis

# create and save waveform templates (10 min for 200 templates per cell, 15 MB) - uncomment to run (1h20min)
if CREATE_TEMPLATE:
    tpl_gen = mr.gen_templates(
        cell_models_folder=CELLS_PATH, params=tpl_prms, recompile=True
    )
    mr.save_template_generator(tpl_gen, TEMPLATES_PATH)

tpl_prms
# Out:
# Compiling NEURON models
# /home/steeve/steeve/epfl/code/spikebias/envs/mearec_si_0_103_0/bin/nrnivmodl:10: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import working_set
# /home/steeve/.config/mearec/1.9.0/cell_models/bbp/mods
# Mod files: "./CaDynamics_E2.mod" "./Ca_HVA.mod" "./Ca_LVAst.mod" "./Ca.mod" "./Ih.mod" "./Im.mod" "./K_Pst.mod" "./K_Tst.mod" "./Nap_Et2.mod" "./NaTa_t.mod" "./NaTs2_t.mod" "./ProbAMPANMDA_EMS.mod" "./ProbGABAAB_EMS.mod" "./SK_E2.mod" "./SKv3_1.mod"
#
#  -> Compiling mod_func.cpp
#  => LINKING shared library ./libnrnmech.so
# Successfully created x86_64/special
# Setting n_jobs to 32 CPUs
# Running with 32 jobs
# Starting simulation 8/13 - cell: L5_NGC_bNAC219_1
#
# Starting simulation 10/13 - cell: L5_STPC_cADpyr232_1
# Starting simulation 6/13 - cell: L5_MC_bAC217_1
#
#
# Starting simulation 13/13 - cell: L5_UTPC_cADpyr232_1
#
# Starting simulation 11/13 - cell: L5_TTPC1_cADpyr232_1
#
# Starting simulation 5/13 - cell: L5_LBC_bAC217_1
#
# Starting simulation 12/13 - cell: L5_TTPC2_cADpyr232_1
#
# Starting simulation 1/13 - cell: L5_BP_bAC217_1
#
# Starting simulation 4/13 - cell: L5_DBC_bAC217_1
#
# Starting simulation 2/13 - cell: L5_BTC_bAC217_1
#
# Starting simulation 3/13 - cell: L5_ChC_cACint209_1
#
# Starting simulation 9/13 - cell: L5_SBC_bNAC219_1
#
# Starting simulation 7/13 - cell: L5_NBC_bAC217_1
#
# Intracellular simulation: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/L5_NGC_bNAC219_1
# Intracellular simulation: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/L5_MC_bAC217_1
# Intracellular simulation: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/L5_UTPC_cADpyr232_1
# Intracellular simulation: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/L5_STPC_cADpyr232_1
# Intracellular simulation: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/L5_TTPC1_cADpyr232_1
# Intracellular simulation: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/L5_BP_bAC217_1
# Intracellular simulation: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/L5_DBC_bAC217_1
# Setting temperature to 34.000000 C
# Setting simulation time step to 0.025000 ms
# 	1
# 	1
# 	1
# template bNAC219_L5_NGC_6186b7e85e exist already
# Setting temperature to 34.000000 C
# Setting simulation time step to 0.025000 ms
# 	1
# 	1
# 	1
# template cADpyr232_L5_UTPC_5e3840b51e exist already
# Setting temperature to 34.000000 C
# Setting simulation time step to 0.025000 ms
# 	1
# 	1
# 	1
# template bAC217_L5_MC_cc2a170ef6 exist already
# Intracellular simulation: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/L5_BTC_bAC217_1
# Setting temperature to 34.000000 C
# Setting simulation time step to 0.025000 ms
# 	1
# 	1
# 	1
# template cADpyr232_L5_STPC_d16b0be14e exist already
# Setting temperature to 34.000000 C
# Setting simulation time step to 0.025000 ms
# Setting temperature to 34.000000 C
# Setting simulation time step to 0.025000 ms
# 	1
# 	1
# 	1
# 	1
# 	1
# 	1
# template cADpyr232_L5_TTPC1_0fb1ca4724 exist already
# template bAC217_L5_BP_d0cc8d7615 exist already
# Intracellular simulation: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/L5_TTPC2_cADpyr232_1
# Intracellular simulation: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/L5_ChC_cACint209_1
# Intracellular simulation: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/L5_LBC_bAC217_1
# Setting temperature to 34.000000 C
# Setting simulation time step to 0.025000 ms
# Setting temperature to 34.000000 C
# Setting simulation time step to 0.025000 ms
# 	1
# 	1
# 	1
# 	1
# 	1
# 	1
# template bAC217_L5_DBC_4765d943f4 exist already
# template cADpyr232_L5_TTPC2_8052133265 exist already
# Setting temperature to 34.000000 C
# Setting simulation time step to 0.025000 ms
# 	1
# 	1
# 	1
# Setting temperature to 34.000000 C
# Setting simulation time step to 0.025000 ms
# template cACint209_L5_ChC_e98f63217d exist already
# 	1
# 	1
# 	1
# template bAC217_L5_BTC_160272643a exist already
# Intracellular simulation: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/L5_NBC_bAC217_1
# Intracellular simulation: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/L5_SBC_bNAC219_1
# Setting temperature to 34.000000 C
# Setting simulation time step to 0.025000 ms
# 	1
# 	1
# 	1
# template bAC217_L5_LBC_c2cff91741 exist already
# Setting temperature to 34.000000 C
# Setting simulation time step to 0.025000 ms
# Setting temperature to 34.000000 C
# Setting simulation time step to 0.025000 ms
# 	1
# 	1
# 	1
# 	1
# 	1
# 	1
# template bNAC219_L5_SBC_77ab259b7f exist already
# template bAC217_L5_NBC_2db880c523 exist already
# Input weight: 0.25 - Num Spikes: 14
# Extracellular simulation: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/L5_MC_bAC217_1
# Seed = 5
# Mechanisms already loaded from path: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/mods.  Aborting.
# template bAC217_L5_MC_cc2a170ef6 exist already
# Input weight: 0.25 - Num Spikes: 104
# Input weight: 0.25 - Num Spikes: 22
# Extracellular simulation: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/L5_BP_bAC217_1
# Seed = 0
# Mechanisms already loaded from path: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/mods.  Aborting.
# template bAC217_L5_BP_d0cc8d7615 exist already
# Cell L5_MC_bAC217_1 extracellular spikes to be simulated
# Pre-generating 150000000 random positions
# Cell L5_BP_bAC217_1 extracellular spikes to be simulated
# Pre-generating 150000000 random positions
# Input weight: 0.25 - Num Spikes: 12
# Extracellular simulation: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/L5_UTPC_cADpyr232_1
# Seed = 12
# Mechanisms already loaded from path: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/mods.  Aborting.
# template cADpyr232_L5_UTPC_5e3840b51e exist already
# Input weight: 0.25 - Num Spikes: 60
# Input weight: 0.25 - Num Spikes: 15
# Extracellular simulation: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/L5_BTC_bAC217_1
# Seed = 1
# Mechanisms already loaded from path: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/mods.  Aborting.
# template bAC217_L5_BTC_160272643a exist already
# Cell L5_BTC_bAC217_1 extracellular spikes to be simulated
# Pre-generating 150000000 random positions
# Cell L5_UTPC_cADpyr232_1 extracellular spikes to be simulated
# Pre-generating 150000000 random positions
# Input weight: 0.25 - Num Spikes: 103
# Input weight: 0.0625 - Num Spikes: 26
# Extracellular simulation: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/L5_NGC_bNAC219_1
# Seed = 7
# Mechanisms already loaded from path: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/mods.  Aborting.
# template bNAC219_L5_NGC_6186b7e85e exist already
# Cell: L5_BP_bAC217_1 Progress: [1/1500]
# Cell: L5_MC_bAC217_1 Progress: [1/1500]
# Cell L5_NGC_bNAC219_1 extracellular spikes to be simulated
# Pre-generating 150000000 random positions
# Cell: L5_BP_bAC217_1 Progress: [2/1500]
# Cell: L5_BP_bAC217_1 Progress: [3/1500]
# Cell: L5_MC_bAC217_1 Progress: [2/1500]
# Cell: L5_BP_bAC217_1 Progress: [4/1500]
# Cell: L5_MC_bAC217_1 Progress: [3/1500]
# Cell: L5_MC_bAC217_1 Progress: [4/1500]
# Cell: L5_MC_bAC217_1 Progress: [5/1500]
# Cell: L5_MC_bAC217_1 Progress: [6/1500]
# Cell: L5_MC_bAC217_1 Progress: [7/1500]
# Cell: L5_BP_bAC217_1 Progress: [5/1500]
# Cell: L5_MC_bAC217_1 Progress: [8/1500]
# Input weight: 0.25 - Num Spikes: 11
# Extracellular simulation: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/L5_DBC_bAC217_1
# Seed = 3
# Mechanisms already loaded from path: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/mods.  Aborting.
# template bAC217_L5_DBC_4765d943f4 exist already
# Cell: L5_MC_bAC217_1 Progress: [9/1500]
# Cell: L5_MC_bAC217_1 Progress: [10/1500]
# Cell: L5_MC_bAC217_1 Progress: [11/1500]
# Cell: L5_MC_bAC217_1 Progress: [12/1500]
# Cell: L5_BP_bAC217_1 Progress: [6/1500]
# Input weight: 0.25 - Num Spikes: 11
# Extracellular simulation: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/L5_LBC_bAC217_1
# Seed = 4
# Mechanisms already loaded from path: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/mods.  Aborting.
# template bAC217_L5_LBC_c2cff91741 exist already
# Input weight: 0.25 - Num Spikes: 15
# Extracellular simulation: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/L5_NBC_bAC217_1
# Seed = 6
# Mechanisms already loaded from path: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/mods.  Aborting.
# template bAC217_L5_NBC_2db880c523 exist already
# Cell: L5_MC_bAC217_1 Progress: [13/1500]
# Cell: L5_BP_bAC217_1 Progress: [7/1500]
# Cell: L5_MC_bAC217_1 Progress: [14/1500]
# Cell: L5_MC_bAC217_1 Progress: [15/1500]
# Cell L5_NBC_bAC217_1 extracellular spikes to be simulated
# Pre-generating 150000000 random positions
# Cell: L5_BP_bAC217_1 Progress: [8/1500]
# Cell L5_DBC_bAC217_1 extracellular spikes to be simulated
# Cell: L5_MC_bAC217_1 Progress: [16/1500]
# Pre-generating 150000000 random positions
# Cell: L5_UTPC_cADpyr232_1 Progress: [1/1500]
# Cell: L5_BP_bAC217_1 Progress: [9/1500]
# Input weight: 0.25 - Num Spikes: 4
# Extracellular simulation: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/L5_TTPC1_cADpyr232_1
# Seed = 10
# Mechanisms already loaded from path: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/mods.  Aborting.
# template cADpyr232_L5_TTPC1_0fb1ca4724 exist already
# Cell L5_LBC_bAC217_1 extracellular spikes to be simulated
# Pre-generating 150000000 random positions
# Cell: L5_MC_bAC217_1 Progress: [17/1500]
# Input weight: 0.0625 - Num Spikes: 26
# Extracellular simulation: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/L5_ChC_cACint209_1
# Seed = 2
# Mechanisms already loaded from path: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/mods.  Aborting.
# template cACint209_L5_ChC_e98f63217d exist already
# Cell: L5_UTPC_cADpyr232_1 Progress: [2/1500]
# Cell: L5_MC_bAC217_1 Progress: [18/1500]
# Input weight: 0.25 - Num Spikes: 5
# Extracellular simulation: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/L5_TTPC2_cADpyr232_1
# Seed = 11
# Mechanisms already loaded from path: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/mods.  Aborting.
# template cADpyr232_L5_TTPC2_8052133265 exist already
# Cell L5_ChC_cACint209_1 extracellular spikes to be simulated
# Cell: L5_BP_bAC217_1 Progress: [10/1500]
# Pre-generating 150000000 random positions
# Input weight: 0.0625 - Num Spikes: 17
# Extracellular simulation: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/L5_SBC_bNAC219_1
# Seed = 8
# Mechanisms already loaded from path: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/mods.  Aborting.
# template bNAC219_L5_SBC_77ab259b7f exist already
# Cell: L5_BP_bAC217_1 Progress: [11/1500]
# Cell L5_TTPC1_cADpyr232_1 extracellular spikes to be simulated
# Pre-generating 150000000 random positions
# Cell L5_SBC_bNAC219_1 extracellular spikes to be simulated
# Cell: L5_MC_bAC217_1 Progress: [19/1500]
# Pre-generating 150000000 random positions
# Cell: L5_BP_bAC217_1 Progress: [12/1500]
# Cell: L5_BTC_bAC217_1 Progress: [1/1500]
# Cell L5_TTPC2_cADpyr232_1 extracellular spikes to be simulated
# Pre-generating 150000000 random positions
# Cell: L5_BTC_bAC217_1 Progress: [2/1500]
# Cell: L5_BP_bAC217_1 Progress: [13/1500]
# Cell: L5_MC_bAC217_1 Progress: [20/1500]
# Cell: L5_BP_bAC217_1 Progress: [14/1500]
# Cell: L5_BTC_bAC217_1 Progress: [3/1500]
# Cell: L5_BP_bAC217_1 Progress: [15/1500]
# Cell: L5_BTC_bAC217_1 Progress: [4/1500]
# Cell: L5_BTC_bAC217_1 Progress: [5/1500]
# Cell: L5_BTC_bAC217_1 Progress: [6/1500]
# Cell: L5_MC_bAC217_1 Progress: [21/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [3/1500]
# Cell: L5_BTC_bAC217_1 Progress: [7/1500]
# Cell: L5_BP_bAC217_1 Progress: [16/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [1/1500]
# Cell: L5_BTC_bAC217_1 Progress: [8/1500]
# Cell: L5_BTC_bAC217_1 Progress: [9/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [2/1500]
# Cell: L5_MC_bAC217_1 Progress: [22/1500]
# Cell: L5_MC_bAC217_1 Progress: [23/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [4/1500]
# Cell: L5_BP_bAC217_1 Progress: [17/1500]
# Cell: L5_BTC_bAC217_1 Progress: [10/1500]
# Cell: L5_LBC_bAC217_1 Progress: [1/1500]
# Cell: L5_BTC_bAC217_1 Progress: [11/1500]
# Cell: L5_LBC_bAC217_1 Progress: [2/1500]
# Cell: L5_BTC_bAC217_1 Progress: [12/1500]
# Cell: L5_ChC_cACint209_1 Progress: [1/1500]
# Cell: L5_MC_bAC217_1 Progress: [24/1500]
# Cell: L5_NBC_bAC217_1 Progress: [1/1500]
# Cell: L5_BTC_bAC217_1 Progress: [13/1500]
# Cell: L5_LBC_bAC217_1 Progress: [3/1500]
# Cell: L5_BP_bAC217_1 Progress: [18/1500]
# Cell: L5_ChC_cACint209_1 Progress: [2/1500]
# Cell: L5_BTC_bAC217_1 Progress: [14/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [5/1500]
# Cell: L5_ChC_cACint209_1 Progress: [3/1500]
# Cell: L5_LBC_bAC217_1 Progress: [4/1500]
# Cell: L5_BP_bAC217_1 Progress: [19/1500]
# Cell: L5_BTC_bAC217_1 Progress: [15/1500]
# Cell: L5_ChC_cACint209_1 Progress: [4/1500]
# Cell: L5_LBC_bAC217_1 Progress: [5/1500]
# Cell: L5_ChC_cACint209_1 Progress: [5/1500]
# Cell: L5_NBC_bAC217_1 Progress: [2/1500]
# Cell: L5_ChC_cACint209_1 Progress: [6/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [1/1500]
# Cell: L5_BTC_bAC217_1 Progress: [16/1500]
# Cell: L5_LBC_bAC217_1 Progress: [6/1500]
# Input weight: 0.25 - Num Spikes: 6
# Cell: L5_ChC_cACint209_1 Progress: [7/1500]
# Cell: L5_NBC_bAC217_1 Progress: [3/1500]
# Extracellular simulation: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/L5_STPC_cADpyr232_1
# Seed = 9
# Mechanisms already loaded from path: /home/steeve/.config/mearec/1.9.0/cell_models/bbp/mods.  Aborting.
# template cADpyr232_L5_STPC_d16b0be14e exist already
# Cell: L5_BTC_bAC217_1 Progress: [17/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [1/1500]
# Cell: L5_ChC_cACint209_1 Progress: [8/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [1/1500]
# Cell: L5_NBC_bAC217_1 Progress: [4/1500]
# Cell: L5_ChC_cACint209_1 Progress: [9/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [3/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [6/1500]
# Cell: L5_BP_bAC217_1 Progress: [20/1500]
# Cell: L5_NBC_bAC217_1 Progress: [5/1500]
# Cell: L5_ChC_cACint209_1 Progress: [10/1500]
# Cell: L5_LBC_bAC217_1 Progress: [7/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [2/1500]
# Cell: L5_NBC_bAC217_1 Progress: [6/1500]
# Cell: L5_ChC_cACint209_1 Progress: [11/1500]
# Cell: L5_BP_bAC217_1 Progress: [21/1500]
# Cell: L5_MC_bAC217_1 Progress: [25/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [2/1500]
# Cell: L5_BP_bAC217_1 Progress: [22/1500]
# Cell: L5_LBC_bAC217_1 Progress: [8/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [7/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [2/1500]
# Cell: L5_ChC_cACint209_1 Progress: [12/1500]
# Cell: L5_BTC_bAC217_1 Progress: [18/1500]
# Cell L5_STPC_cADpyr232_1 extracellular spikes to be simulated
# Pre-generating 150000000 random positions
# Cell: L5_NBC_bAC217_1 Progress: [7/1500]
# Cell: L5_DBC_bAC217_1 Progress: [1/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [3/1500]
# Cell: L5_ChC_cACint209_1 Progress: [13/1500]
# Cell: L5_NBC_bAC217_1 Progress: [8/1500]
# Cell: L5_ChC_cACint209_1 Progress: [14/1500]
# Cell: L5_BP_bAC217_1 Progress: [23/1500]
# Cell: L5_BTC_bAC217_1 Progress: [19/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [3/1500]
# Cell: L5_LBC_bAC217_1 Progress: [9/1500]
# Cell: L5_MC_bAC217_1 Progress: [26/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [8/1500]
# Cell: L5_ChC_cACint209_1 Progress: [15/1500]
# Cell: L5_DBC_bAC217_1 Progress: [2/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [4/1500]
# Cell: L5_ChC_cACint209_1 Progress: [16/1500]
# Cell: L5_BTC_bAC217_1 Progress: [20/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [5/1500]
# Cell: L5_LBC_bAC217_1 Progress: [10/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [3/1500]
# Cell: L5_ChC_cACint209_1 Progress: [17/1500]
# Cell: L5_MC_bAC217_1 Progress: [27/1500]
# Cell: L5_BTC_bAC217_1 Progress: [21/1500]
# Cell: L5_NBC_bAC217_1 Progress: [9/1500]
# Cell: L5_DBC_bAC217_1 Progress: [3/1500]
# Cell: L5_ChC_cACint209_1 Progress: [18/1500]
# Cell: L5_BP_bAC217_1 Progress: [24/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [4/1500]
# Cell: L5_NBC_bAC217_1 Progress: [10/1500]
# Cell: L5_ChC_cACint209_1 Progress: [19/1500]
# Cell: L5_MC_bAC217_1 Progress: [28/1500]
# Cell: L5_NBC_bAC217_1 Progress: [11/1500]
# Cell: L5_DBC_bAC217_1 Progress: [4/1500]
# Cell: L5_ChC_cACint209_1 Progress: [20/1500]
# Cell: L5_BTC_bAC217_1 Progress: [22/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [9/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [4/1500]
# Cell: L5_LBC_bAC217_1 Progress: [11/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [5/1500]
# Cell: L5_BTC_bAC217_1 Progress: [23/1500]
# Cell: L5_ChC_cACint209_1 Progress: [21/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [6/1500]
# Cell: L5_DBC_bAC217_1 Progress: [5/1500]
# Cell: L5_MC_bAC217_1 Progress: [29/1500]
# Cell: L5_NBC_bAC217_1 Progress: [12/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [10/1500]
# Cell: L5_NBC_bAC217_1 Progress: [13/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [7/1500]
# Cell: L5_DBC_bAC217_1 Progress: [6/1500]
# Cell: L5_LBC_bAC217_1 Progress: [12/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [8/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [6/1500]
# Cell: L5_NBC_bAC217_1 Progress: [14/1500]
# Cell: L5_ChC_cACint209_1 Progress: [22/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [5/1500]
# Cell: L5_ChC_cACint209_1 Progress: [23/1500]
# Cell: L5_BTC_bAC217_1 Progress: [24/1500]
# Cell: L5_BP_bAC217_1 Progress: [25/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [9/1500]
# Cell: L5_ChC_cACint209_1 Progress: [24/1500]
# Cell: L5_LBC_bAC217_1 Progress: [13/1500]
# Cell: L5_ChC_cACint209_1 Progress: [25/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [7/1500]
# Cell: L5_NBC_bAC217_1 Progress: [15/1500]
# Cell: L5_BTC_bAC217_1 Progress: [25/1500]
# Cell: L5_ChC_cACint209_1 Progress: [26/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [10/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [11/1500]
# Cell: L5_NBC_bAC217_1 Progress: [16/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [4/1500]
# Cell: L5_ChC_cACint209_1 Progress: [27/1500]
# Cell: L5_BTC_bAC217_1 Progress: [26/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [6/1500]
# Cell: L5_MC_bAC217_1 Progress: [30/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [11/1500]
# Cell: L5_NBC_bAC217_1 Progress: [17/1500]
# Cell: L5_ChC_cACint209_1 Progress: [28/1500]
# Cell: L5_LBC_bAC217_1 Progress: [14/1500]
# Cell: L5_BTC_bAC217_1 Progress: [27/1500]
# Cell: L5_DBC_bAC217_1 Progress: [7/1500]
# Cell: L5_ChC_cACint209_1 Progress: [29/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [8/1500]
# Cell: L5_BP_bAC217_1 Progress: [26/1500]
# Cell: L5_LBC_bAC217_1 Progress: [15/1500]
# Cell: L5_ChC_cACint209_1 Progress: [30/1500]
# Cell: L5_NBC_bAC217_1 Progress: [18/1500]
# Cell: L5_DBC_bAC217_1 Progress: [8/1500]Cell: L5_BTC_bAC217_1 Progress: [28/1500]
#
# Cell: L5_NBC_bAC217_1 Progress: [19/1500]
# Cell: L5_MC_bAC217_1 Progress: [31/1500]
# Cell: L5_LBC_bAC217_1 Progress: [16/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [12/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [7/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [12/1500]
# Cell: L5_BP_bAC217_1 Progress: [27/1500]
# Cell: L5_NBC_bAC217_1 Progress: [20/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [9/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [13/1500]
# Cell: L5_LBC_bAC217_1 Progress: [17/1500]
# Cell: L5_BTC_bAC217_1 Progress: [29/1500]
# Cell: L5_MC_bAC217_1 Progress: [32/1500]
# Cell: L5_ChC_cACint209_1 Progress: [31/1500]
# Cell: L5_BTC_bAC217_1 Progress: [30/1500]
# Cell: L5_LBC_bAC217_1 Progress: [18/1500]
# Cell: L5_BP_bAC217_1 Progress: [28/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [13/1500]
# Cell: L5_ChC_cACint209_1 Progress: [32/1500]
# Cell: L5_MC_bAC217_1 Progress: [33/1500]
# Cell: L5_DBC_bAC217_1 Progress: [9/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [10/1500]
# Cell: L5_ChC_cACint209_1 Progress: [33/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [5/1500]
# Cell: L5_LBC_bAC217_1 Progress: [19/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [8/1500]
# Cell: L5_BP_bAC217_1 Progress: [29/1500]
# Cell: L5_ChC_cACint209_1 Progress: [34/1500]
# Cell: L5_MC_bAC217_1 Progress: [34/1500]
# Cell: L5_BP_bAC217_1 Progress: [30/1500]
# Cell: L5_DBC_bAC217_1 Progress: [10/1500]
# Cell: L5_LBC_bAC217_1 Progress: [20/1500]
# Cell: L5_ChC_cACint209_1 Progress: [35/1500]
# Cell: L5_BTC_bAC217_1 Progress: [31/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [6/1500]
# Cell: L5_ChC_cACint209_1 Progress: [36/1500]
# Cell: L5_BTC_bAC217_1 Progress: [32/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [14/1500]
# Cell: L5_NBC_bAC217_1 Progress: [21/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [11/1500]
# Cell: L5_MC_bAC217_1 Progress: [35/1500]
# Cell: L5_LBC_bAC217_1 Progress: [21/1500]
# Cell: L5_ChC_cACint209_1 Progress: [37/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [15/1500]
# Cell: L5_BP_bAC217_1 Progress: [31/1500]
# Cell: L5_DBC_bAC217_1 Progress: [11/1500]
# Cell: L5_NBC_bAC217_1 Progress: [22/1500]
# Cell: L5_ChC_cACint209_1 Progress: [38/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [9/1500]
# Cell: L5_BP_bAC217_1 Progress: [32/1500]
# Cell: L5_LBC_bAC217_1 Progress: [22/1500]
# Cell: L5_ChC_cACint209_1 Progress: [39/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [16/1500]
# Cell: L5_ChC_cACint209_1 Progress: [40/1500]
# Cell: L5_DBC_bAC217_1 Progress: [12/1500]
# Cell: L5_LBC_bAC217_1 Progress: [23/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [12/1500]
# Cell: L5_ChC_cACint209_1 Progress: [41/1500]
# Cell: L5_LBC_bAC217_1 Progress: [24/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [17/1500]
# Cell: L5_DBC_bAC217_1 Progress: [13/1500]
# Cell: L5_NBC_bAC217_1 Progress: [23/1500]
# Cell: L5_BP_bAC217_1 Progress: [33/1500]
# Cell: L5_MC_bAC217_1 Progress: [36/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [10/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [7/1500]
# Cell: L5_ChC_cACint209_1 Progress: [42/1500]
# Cell: L5_BP_bAC217_1 Progress: [34/1500]
# Cell: L5_LBC_bAC217_1 Progress: [25/1500]
# Cell: L5_NBC_bAC217_1 Progress: [24/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [13/1500]
# Cell: L5_BTC_bAC217_1 Progress: [33/1500]
# Cell: L5_BP_bAC217_1 Progress: [35/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [14/1500]
# Cell: L5_DBC_bAC217_1 Progress: [14/1500]
# Cell: L5_BP_bAC217_1 Progress: [36/1500]
# Cell: L5_BTC_bAC217_1 Progress: [34/1500]
# Cell: L5_LBC_bAC217_1 Progress: [26/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [18/1500]
# Cell: L5_ChC_cACint209_1 Progress: [43/1500]
# Cell: L5_BP_bAC217_1 Progress: [37/1500]
# Cell: L5_NBC_bAC217_1 Progress: [25/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [19/1500]
# Cell: L5_MC_bAC217_1 Progress: [37/1500]
# Cell: L5_LBC_bAC217_1 Progress: [27/1500]
# Cell: L5_NBC_bAC217_1 Progress: [26/1500]
# Cell: L5_DBC_bAC217_1 Progress: [15/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [20/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [15/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [14/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [11/1500]
# Cell: L5_BTC_bAC217_1 Progress: [35/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [8/1500]
# Cell: L5_BP_bAC217_1 Progress: [38/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [21/1500]
# Cell: L5_LBC_bAC217_1 Progress: [28/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [22/1500]
# Cell: L5_BTC_bAC217_1 Progress: [36/1500]
# Cell: L5_NBC_bAC217_1 Progress: [27/1500]
# Cell: L5_DBC_bAC217_1 Progress: [16/1500]
# Cell: L5_ChC_cACint209_1 Progress: [44/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [9/1500]
# Cell: L5_LBC_bAC217_1 Progress: [29/1500]
# Cell: L5_MC_bAC217_1 Progress: [38/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [1/1500]
# Cell: L5_ChC_cACint209_1 Progress: [45/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [15/1500]
# Cell: L5_ChC_cACint209_1 Progress: [46/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [23/1500]
# Cell: L5_LBC_bAC217_1 Progress: [30/1500]
# Cell: L5_DBC_bAC217_1 Progress: [17/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [12/1500]
# Cell: L5_BP_bAC217_1 Progress: [39/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [10/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [24/1500]
# Cell: L5_MC_bAC217_1 Progress: [39/1500]
# Cell: L5_ChC_cACint209_1 Progress: [47/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [25/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [16/1500]
# Cell: L5_ChC_cACint209_1 Progress: [48/1500]
# Cell: L5_LBC_bAC217_1 Progress: [31/1500]
# Cell: L5_BTC_bAC217_1 Progress: [37/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [26/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [16/1500]
# Cell: L5_DBC_bAC217_1 Progress: [18/1500]
# Cell: L5_ChC_cACint209_1 Progress: [49/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [11/1500]
# Cell: L5_BTC_bAC217_1 Progress: [38/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [2/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [27/1500]
# Cell: L5_LBC_bAC217_1 Progress: [32/1500]
# Cell: L5_BP_bAC217_1 Progress: [40/1500]
# Cell: L5_ChC_cACint209_1 Progress: [50/1500]
# Cell: L5_NBC_bAC217_1 Progress: [28/1500]
# Cell: L5_MC_bAC217_1 Progress: [40/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [28/1500]
# Cell: L5_DBC_bAC217_1 Progress: [19/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [13/1500]
# Cell: L5_LBC_bAC217_1 Progress: [33/1500]
# Cell: L5_BTC_bAC217_1 Progress: [39/1500]
# Cell: L5_ChC_cACint209_1 Progress: [51/1500]
# Cell: L5_NBC_bAC217_1 Progress: [29/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [17/1500]
# Cell: L5_ChC_cACint209_1 Progress: [52/1500]
# Cell: L5_MC_bAC217_1 Progress: [41/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [29/1500]
# Cell: L5_LBC_bAC217_1 Progress: [34/1500]
# Cell: L5_NBC_bAC217_1 Progress: [30/1500]
# Cell: L5_BP_bAC217_1 Progress: [41/1500]
# Cell: L5_ChC_cACint209_1 Progress: [53/1500]
# Cell: L5_DBC_bAC217_1 Progress: [20/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [3/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [30/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [12/1500]
# Cell: L5_NBC_bAC217_1 Progress: [31/1500]
# Cell: L5_ChC_cACint209_1 Progress: [54/1500]
# Cell: L5_MC_bAC217_1 Progress: [42/1500]
# Cell: L5_LBC_bAC217_1 Progress: [35/1500]
# Cell: L5_ChC_cACint209_1 Progress: [55/1500]
# Cell: L5_NBC_bAC217_1 Progress: [32/1500]
# Cell: L5_DBC_bAC217_1 Progress: [21/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [14/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [18/1500]
# Cell: L5_ChC_cACint209_1 Progress: [56/1500]
# Cell: L5_LBC_bAC217_1 Progress: [36/1500]
# Cell: L5_BP_bAC217_1 Progress: [42/1500]
# Cell: L5_ChC_cACint209_1 Progress: [57/1500]
# Cell: L5_BTC_bAC217_1 Progress: [40/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [4/1500]
# Cell: L5_ChC_cACint209_1 Progress: [58/1500]
# Cell: L5_DBC_bAC217_1 Progress: [22/1500]
# Cell: L5_LBC_bAC217_1 Progress: [37/1500]
# Cell: L5_MC_bAC217_1 Progress: [43/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [31/1500]
# Cell: L5_NBC_bAC217_1 Progress: [33/1500]
# Cell: L5_ChC_cACint209_1 Progress: [59/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [19/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [17/1500]
# Cell: L5_LBC_bAC217_1 Progress: [38/1500]
# Cell: L5_NBC_bAC217_1 Progress: [34/1500]
# Cell: L5_MC_bAC217_1 Progress: [44/1500]
# Cell: L5_DBC_bAC217_1 Progress: [23/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [15/1500]
# Cell: L5_ChC_cACint209_1 Progress: [60/1500]
# Cell: L5_BTC_bAC217_1 Progress: [41/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [13/1500]
# Cell: L5_ChC_cACint209_1 Progress: [61/1500]
# Cell: L5_MC_bAC217_1 Progress: [45/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [5/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [18/1500]
# Cell: L5_DBC_bAC217_1 Progress: [24/1500]
# Cell: L5_NBC_bAC217_1 Progress: [35/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [20/1500]
# Cell: L5_ChC_cACint209_1 Progress: [62/1500]
# Cell: L5_MC_bAC217_1 Progress: [46/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [32/1500]
# Cell: L5_LBC_bAC217_1 Progress: [39/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [16/1500]
# Cell: L5_DBC_bAC217_1 Progress: [25/1500]
# Cell: L5_ChC_cACint209_1 Progress: [63/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [19/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [14/1500]
# Cell: L5_ChC_cACint209_1 Progress: [64/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [33/1500]
# Cell: L5_LBC_bAC217_1 Progress: [40/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [15/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [21/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [6/1500]
# Cell: L5_ChC_cACint209_1 Progress: [65/1500]
# Cell: L5_BP_bAC217_1 Progress: [43/1500]
# Cell: L5_DBC_bAC217_1 Progress: [26/1500]
# Cell: L5_NBC_bAC217_1 Progress: [36/1500]
# Cell: L5_ChC_cACint209_1 Progress: [66/1500]
# Cell: L5_LBC_bAC217_1 Progress: [41/1500]
# Cell: L5_BTC_bAC217_1 Progress: [42/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [20/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [16/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [34/1500]
# Cell: L5_ChC_cACint209_1 Progress: [67/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [17/1500]
# Cell: L5_LBC_bAC217_1 Progress: [42/1500]
# Cell: L5_ChC_cACint209_1 Progress: [68/1500]
# Cell: L5_DBC_bAC217_1 Progress: [27/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [22/1500]
# Cell: L5_NBC_bAC217_1 Progress: [37/1500]
# Cell: L5_ChC_cACint209_1 Progress: [69/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [7/1500]
# Cell: L5_BP_bAC217_1 Progress: [44/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [21/1500]
# Cell: L5_LBC_bAC217_1 Progress: [43/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [35/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [17/1500]
# Cell: L5_BTC_bAC217_1 Progress: [43/1500]
# Cell: L5_MC_bAC217_1 Progress: [47/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [36/1500]
# Cell: L5_DBC_bAC217_1 Progress: [28/1500]
# Cell: L5_ChC_cACint209_1 Progress: [70/1500]
# Cell: L5_BTC_bAC217_1 Progress: [44/1500]
# Cell: L5_LBC_bAC217_1 Progress: [44/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [23/1500]
# Cell: L5_ChC_cACint209_1 Progress: [71/1500]
# Cell: L5_MC_bAC217_1 Progress: [48/1500]
# Cell: L5_BP_bAC217_1 Progress: [45/1500]
# Cell: L5_BTC_bAC217_1 Progress: [45/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [18/1500]
# Cell: L5_ChC_cACint209_1 Progress: [72/1500]
# Cell: L5_LBC_bAC217_1 Progress: [45/1500]
# Cell: L5_DBC_bAC217_1 Progress: [29/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [37/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [18/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [8/1500]
# Cell: L5_ChC_cACint209_1 Progress: [73/1500]
# Cell: L5_BTC_bAC217_1 Progress: [46/1500]
# Cell: L5_BP_bAC217_1 Progress: [46/1500]
# Cell: L5_NBC_bAC217_1 Progress: [38/1500]
# Cell: L5_MC_bAC217_1 Progress: [49/1500]
# Cell: L5_ChC_cACint209_1 Progress: [74/1500]
# Cell: L5_LBC_bAC217_1 Progress: [46/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [38/1500]
# Cell: L5_BP_bAC217_1 Progress: [47/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [24/1500]
# Cell: L5_ChC_cACint209_1 Progress: [75/1500]
# Cell: L5_DBC_bAC217_1 Progress: [30/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [22/1500]
# Cell: L5_MC_bAC217_1 Progress: [50/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [19/1500]
# Cell: L5_LBC_bAC217_1 Progress: [47/1500]
# Cell: L5_ChC_cACint209_1 Progress: [76/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [19/1500]
# Cell: L5_ChC_cACint209_1 Progress: [77/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [9/1500]
# Cell: L5_LBC_bAC217_1 Progress: [48/1500]
# Cell: L5_MC_bAC217_1 Progress: [51/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [39/1500]
# Cell: L5_BTC_bAC217_1 Progress: [47/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [25/1500]
# Cell: L5_ChC_cACint209_1 Progress: [78/1500]
# Cell: L5_LBC_bAC217_1 Progress: [49/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [40/1500]
# Cell: L5_BTC_bAC217_1 Progress: [48/1500]
# Cell: L5_ChC_cACint209_1 Progress: [79/1500]
# Cell: L5_DBC_bAC217_1 Progress: [31/1500]
# Cell: L5_BTC_bAC217_1 Progress: [49/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [23/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [20/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [20/1500]
# Cell: L5_ChC_cACint209_1 Progress: [80/1500]
# Cell: L5_MC_bAC217_1 Progress: [52/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [10/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [26/1500]
# Cell: L5_BP_bAC217_1 Progress: [48/1500]
# Cell: L5_DBC_bAC217_1 Progress: [32/1500]
# Cell: L5_ChC_cACint209_1 Progress: [81/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [41/1500]
# Cell: L5_LBC_bAC217_1 Progress: [50/1500]
# Cell: L5_BTC_bAC217_1 Progress: [50/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [42/1500]
# Cell: L5_ChC_cACint209_1 Progress: [82/1500]
# Cell: L5_NBC_bAC217_1 Progress: [39/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [24/1500]
# Cell: L5_LBC_bAC217_1 Progress: [51/1500]
# Cell: L5_BP_bAC217_1 Progress: [49/1500]
# Cell: L5_DBC_bAC217_1 Progress: [33/1500]
# Cell: L5_ChC_cACint209_1 Progress: [83/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [27/1500]
# Cell: L5_BTC_bAC217_1 Progress: [51/1500]
# Cell: L5_MC_bAC217_1 Progress: [53/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [21/1500]
# Cell: L5_LBC_bAC217_1 Progress: [52/1500]
# Cell: L5_ChC_cACint209_1 Progress: [84/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [11/1500]
# Cell: L5_NBC_bAC217_1 Progress: [40/1500]
# Cell: L5_BTC_bAC217_1 Progress: [52/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [25/1500]
# Cell: L5_DBC_bAC217_1 Progress: [34/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [21/1500]
# Cell: L5_BP_bAC217_1 Progress: [50/1500]
# Cell: L5_LBC_bAC217_1 Progress: [53/1500]
# Cell: L5_ChC_cACint209_1 Progress: [85/1500]
# Cell: L5_BTC_bAC217_1 Progress: [53/1500]
# Cell: L5_BP_bAC217_1 Progress: [51/1500]
# Cell: L5_ChC_cACint209_1 Progress: [86/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [28/1500]
# Cell: L5_BP_bAC217_1 Progress: [52/1500]
# Cell: L5_NBC_bAC217_1 Progress: [41/1500]
# Cell: L5_LBC_bAC217_1 Progress: [54/1500]
# Cell: L5_MC_bAC217_1 Progress: [54/1500]
# Cell: L5_DBC_bAC217_1 Progress: [35/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [26/1500]
# Cell: L5_BTC_bAC217_1 Progress: [54/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [22/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [12/1500]
# Cell: L5_ChC_cACint209_1 Progress: [87/1500]
# Cell: L5_MC_bAC217_1 Progress: [55/1500]
# Cell: L5_ChC_cACint209_1 Progress: [88/1500]
# Cell: L5_NBC_bAC217_1 Progress: [42/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [43/1500]
# Cell: L5_DBC_bAC217_1 Progress: [36/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [29/1500]
# Cell: L5_ChC_cACint209_1 Progress: [89/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [44/1500]
# Cell: L5_LBC_bAC217_1 Progress: [55/1500]
# Cell: L5_BTC_bAC217_1 Progress: [55/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [27/1500]
# Cell: L5_ChC_cACint209_1 Progress: [90/1500]
# Cell: L5_MC_bAC217_1 Progress: [56/1500]
# Cell: L5_ChC_cACint209_1 Progress: [91/1500]
# Cell: L5_DBC_bAC217_1 Progress: [37/1500]
# Cell: L5_NBC_bAC217_1 Progress: [43/1500]
# Cell: L5_BP_bAC217_1 Progress: [53/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [13/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [23/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [45/1500]
# Cell: L5_ChC_cACint209_1 Progress: [92/1500]
# Cell: L5_MC_bAC217_1 Progress: [57/1500]
# Cell: L5_BP_bAC217_1 Progress: [54/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [30/1500]
# Cell: L5_LBC_bAC217_1 Progress: [56/1500]
# Cell: L5_BP_bAC217_1 Progress: [55/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [46/1500]
# Cell: L5_DBC_bAC217_1 Progress: [38/1500]
# Cell: L5_NBC_bAC217_1 Progress: [44/1500]
# Cell: L5_ChC_cACint209_1 Progress: [93/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [47/1500]
# Cell: L5_MC_bAC217_1 Progress: [58/1500]
# Cell: L5_LBC_bAC217_1 Progress: [57/1500]
# Cell: L5_BP_bAC217_1 Progress: [56/1500]
# Cell: L5_ChC_cACint209_1 Progress: [94/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [22/1500]
# Cell: L5_BTC_bAC217_1 Progress: [56/1500]
# Cell: L5_ChC_cACint209_1 Progress: [95/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [14/1500]
# Cell: L5_DBC_bAC217_1 Progress: [39/1500]
# Cell: L5_LBC_bAC217_1 Progress: [58/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [31/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [24/1500]
# Cell: L5_ChC_cACint209_1 Progress: [96/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [48/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [49/1500]
# Cell: L5_ChC_cACint209_1 Progress: [97/1500]
# Cell: L5_LBC_bAC217_1 Progress: [59/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [50/1500]
# Cell: L5_BTC_bAC217_1 Progress: [57/1500]
# Cell: L5_MC_bAC217_1 Progress: [59/1500]
# Cell: L5_DBC_bAC217_1 Progress: [40/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [28/1500]
# Cell: L5_NBC_bAC217_1 Progress: [45/1500]
# Cell: L5_ChC_cACint209_1 Progress: [98/1500]
# Cell: L5_BTC_bAC217_1 Progress: [58/1500]
# Cell: L5_LBC_bAC217_1 Progress: [60/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [32/1500]
# Cell: L5_ChC_cACint209_1 Progress: [99/1500]
# Cell: L5_MC_bAC217_1 Progress: [60/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [15/1500]
# Cell: L5_DBC_bAC217_1 Progress: [41/1500]
# Cell: L5_ChC_cACint209_1 Progress: [100/1500]Cell: L5_TTPC1_cADpyr232_1 Progress: [25/1500]
#
# Cell: L5_LBC_bAC217_1 Progress: [61/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [51/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [29/1500]
# Cell: L5_ChC_cACint209_1 Progress: [101/1500]
# Cell: L5_LBC_bAC217_1 Progress: [62/1500]
# Cell: L5_BTC_bAC217_1 Progress: [59/1500]
# Cell: L5_ChC_cACint209_1 Progress: [102/1500]
# Cell: L5_DBC_bAC217_1 Progress: [42/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [33/1500]
# Cell: L5_MC_bAC217_1 Progress: [61/1500]
# Cell: L5_LBC_bAC217_1 Progress: [63/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [16/1500]
# Cell: L5_ChC_cACint209_1 Progress: [103/1500]
# Cell: L5_NBC_bAC217_1 Progress: [46/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [23/1500]
# Cell: L5_BTC_bAC217_1 Progress: [60/1500]
# Cell: L5_DBC_bAC217_1 Progress: [43/1500]
# Cell: L5_ChC_cACint209_1 Progress: [104/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [26/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [52/1500]
# Cell: L5_NBC_bAC217_1 Progress: [47/1500]
# Cell: L5_LBC_bAC217_1 Progress: [64/1500]
# Cell: L5_BP_bAC217_1 Progress: [57/1500]
# Cell: L5_ChC_cACint209_1 Progress: [105/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [34/1500]
# Cell: L5_NBC_bAC217_1 Progress: [48/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [30/1500]
# Cell: L5_ChC_cACint209_1 Progress: [106/1500]
# Cell: L5_LBC_bAC217_1 Progress: [65/1500]
# Cell: L5_MC_bAC217_1 Progress: [62/1500]
# Cell: L5_NBC_bAC217_1 Progress: [49/1500]
# Cell: L5_BP_bAC217_1 Progress: [58/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [53/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [17/1500]
# Cell: L5_NBC_bAC217_1 Progress: [50/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [54/1500]
# Cell: L5_ChC_cACint209_1 Progress: [107/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [27/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [35/1500]
# Cell: L5_DBC_bAC217_1 Progress: [44/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [55/1500]
# Cell: L5_LBC_bAC217_1 Progress: [66/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [56/1500]
# Cell: L5_ChC_cACint209_1 Progress: [108/1500]
# Cell: L5_NBC_bAC217_1 Progress: [51/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [57/1500]
# Cell: L5_BP_bAC217_1 Progress: [59/1500]
# Cell: L5_ChC_cACint209_1 Progress: [109/1500]
# Cell: L5_BP_bAC217_1 Progress: [60/1500]
# Cell: L5_DBC_bAC217_1 Progress: [45/1500]
# Cell: L5_NBC_bAC217_1 Progress: [52/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [18/1500]
# Cell: L5_BP_bAC217_1 Progress: [61/1500]
# Cell: L5_BTC_bAC217_1 Progress: [61/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [36/1500]
# Cell: L5_MC_bAC217_1 Progress: [63/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [24/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [28/1500]
# Cell: L5_DBC_bAC217_1 Progress: [46/1500]
# Cell: L5_ChC_cACint209_1 Progress: [110/1500]
# Cell: L5_BP_bAC217_1 Progress: [62/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [58/1500]
# Cell: L5_MC_bAC217_1 Progress: [64/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [31/1500]
# Cell: L5_NBC_bAC217_1 Progress: [53/1500]
# Cell: L5_ChC_cACint209_1 Progress: [111/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [37/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [19/1500]
# Cell: L5_DBC_bAC217_1 Progress: [47/1500]
# Cell: L5_ChC_cACint209_1 Progress: [112/1500]
# Cell: L5_LBC_bAC217_1 Progress: [67/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [59/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [32/1500]
# Cell: L5_ChC_cACint209_1 Progress: [113/1500]
# Cell: L5_LBC_bAC217_1 Progress: [68/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [29/1500]
# Cell: L5_BTC_bAC217_1 Progress: [62/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [60/1500]
# Cell: L5_DBC_bAC217_1 Progress: [48/1500]
# Cell: L5_NBC_bAC217_1 Progress: [54/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [61/1500]
# Cell: L5_NBC_bAC217_1 Progress: [55/1500]
# Cell: L5_LBC_bAC217_1 Progress: [69/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [38/1500]
# Cell: L5_ChC_cACint209_1 Progress: [114/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [20/1500]
# Cell: L5_MC_bAC217_1 Progress: [65/1500]
# Cell: L5_DBC_bAC217_1 Progress: [49/1500]
# Cell: L5_ChC_cACint209_1 Progress: [115/1500]
# Cell: L5_LBC_bAC217_1 Progress: [70/1500]
# Cell: L5_ChC_cACint209_1 Progress: [116/1500]
# Cell: L5_ChC_cACint209_1 Progress: [117/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [30/1500]
# Cell: L5_BTC_bAC217_1 Progress: [63/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [62/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [39/1500]
# Cell: L5_ChC_cACint209_1 Progress: [118/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [33/1500]
# Cell: L5_BTC_bAC217_1 Progress: [64/1500]
# Cell: L5_MC_bAC217_1 Progress: [66/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [21/1500]
# Cell: L5_NBC_bAC217_1 Progress: [56/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [63/1500]
# Cell: L5_LBC_bAC217_1 Progress: [71/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [64/1500]
# Cell: L5_DBC_bAC217_1 Progress: [50/1500]
# Cell: L5_ChC_cACint209_1 Progress: [119/1500]
# Cell: L5_NBC_bAC217_1 Progress: [57/1500]
# Cell: L5_ChC_cACint209_1 Progress: [120/1500]
# Cell: L5_BTC_bAC217_1 Progress: [65/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [40/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [31/1500]
# Cell: L5_BP_bAC217_1 Progress: [63/1500]
# Cell: L5_DBC_bAC217_1 Progress: [51/1500]
# Cell: L5_NBC_bAC217_1 Progress: [58/1500]
# Cell: L5_LBC_bAC217_1 Progress: [72/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [22/1500]
# Cell: L5_BTC_bAC217_1 Progress: [66/1500]
# Cell: L5_NBC_bAC217_1 Progress: [59/1500]
# Cell: L5_ChC_cACint209_1 Progress: [121/1500]
# Cell: L5_BP_bAC217_1 Progress: [64/1500]
# Cell: L5_LBC_bAC217_1 Progress: [73/1500]
# Cell: L5_ChC_cACint209_1 Progress: [122/1500]
# Cell: L5_MC_bAC217_1 Progress: [67/1500]
# Cell: L5_DBC_bAC217_1 Progress: [52/1500]
# Cell: L5_BTC_bAC217_1 Progress: [67/1500]
# Cell: L5_NBC_bAC217_1 Progress: [60/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [41/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [65/1500]
# Cell: L5_ChC_cACint209_1 Progress: [123/1500]
# Cell: L5_LBC_bAC217_1 Progress: [74/1500]
# Cell: L5_ChC_cACint209_1 Progress: [124/1500]
# Cell: L5_MC_bAC217_1 Progress: [68/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [32/1500]
# Cell: L5_DBC_bAC217_1 Progress: [53/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [34/1500]
# Cell: L5_ChC_cACint209_1 Progress: [125/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [23/1500]
# Cell: L5_ChC_cACint209_1 Progress: [126/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [42/1500]
# Cell: L5_ChC_cACint209_1 Progress: [127/1500]
# Cell: L5_NBC_bAC217_1 Progress: [61/1500]
# Cell: L5_LBC_bAC217_1 Progress: [75/1500]
# Cell: L5_DBC_bAC217_1 Progress: [54/1500]
# Cell: L5_ChC_cACint209_1 Progress: [128/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [35/1500]
# Cell: L5_BTC_bAC217_1 Progress: [68/1500]
# Cell: L5_ChC_cACint209_1 Progress: [129/1500]
# Cell: L5_LBC_bAC217_1 Progress: [76/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [33/1500]
# Cell: L5_NBC_bAC217_1 Progress: [62/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [66/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [24/1500]
# Cell: L5_ChC_cACint209_1 Progress: [130/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [43/1500]
# Cell: L5_DBC_bAC217_1 Progress: [55/1500]
# Cell: L5_BTC_bAC217_1 Progress: [69/1500]
# Cell: L5_MC_bAC217_1 Progress: [69/1500]
# Cell: L5_LBC_bAC217_1 Progress: [77/1500]
# Cell: L5_NBC_bAC217_1 Progress: [63/1500]
# Cell: L5_ChC_cACint209_1 Progress: [131/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [36/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [67/1500]
# Cell: L5_ChC_cACint209_1 Progress: [132/1500]
# Cell: L5_NBC_bAC217_1 Progress: [64/1500]
# Cell: L5_LBC_bAC217_1 Progress: [78/1500]
# Cell: L5_DBC_bAC217_1 Progress: [56/1500]
# Cell: L5_MC_bAC217_1 Progress: [70/1500]
# Cell: L5_BP_bAC217_1 Progress: [65/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [44/1500]
# Cell: L5_ChC_cACint209_1 Progress: [133/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [34/1500]
# Cell: L5_LBC_bAC217_1 Progress: [79/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [37/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [25/1500]
# Cell: L5_NBC_bAC217_1 Progress: [65/1500]
# Cell: L5_MC_bAC217_1 Progress: [71/1500]
# Cell: L5_ChC_cACint209_1 Progress: [134/1500]
# Cell: L5_DBC_bAC217_1 Progress: [57/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [68/1500]
# Cell: L5_BP_bAC217_1 Progress: [66/1500]
# Cell: L5_ChC_cACint209_1 Progress: [135/1500]
# Cell: L5_BP_bAC217_1 Progress: [67/1500]
# Cell: L5_LBC_bAC217_1 Progress: [80/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [69/1500]
# Cell: L5_ChC_cACint209_1 Progress: [136/1500]
# Cell: L5_MC_bAC217_1 Progress: [72/1500]
# Cell: L5_BP_bAC217_1 Progress: [68/1500]
# Cell: L5_NBC_bAC217_1 Progress: [66/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [45/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [38/1500]
# Cell: L5_BP_bAC217_1 Progress: [69/1500]
# Cell: L5_DBC_bAC217_1 Progress: [58/1500]
# Cell: L5_BTC_bAC217_1 Progress: [70/1500]
# Cell: L5_LBC_bAC217_1 Progress: [81/1500]
# Cell: L5_NBC_bAC217_1 Progress: [67/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [70/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [35/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [26/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [25/1500]
# Cell: L5_LBC_bAC217_1 Progress: [82/1500]
# Cell: L5_ChC_cACint209_1 Progress: [137/1500]
# Cell: L5_DBC_bAC217_1 Progress: [59/1500]
# Cell: L5_ChC_cACint209_1 Progress: [138/1500]
# Cell: L5_NBC_bAC217_1 Progress: [68/1500]
# Cell: L5_BP_bAC217_1 Progress: [70/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [71/1500]
# Cell: L5_MC_bAC217_1 Progress: [73/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [46/1500]
# Cell: L5_LBC_bAC217_1 Progress: [83/1500]
# Cell: L5_ChC_cACint209_1 Progress: [139/1500]
# Cell: L5_BTC_bAC217_1 Progress: [71/1500]
# Cell: L5_ChC_cACint209_1 Progress: [140/1500]
# Cell: L5_DBC_bAC217_1 Progress: [60/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [26/1500]
# Cell: L5_LBC_bAC217_1 Progress: [84/1500]
# Cell: L5_ChC_cACint209_1 Progress: [141/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [27/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [39/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [36/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [27/1500]
# Cell: L5_ChC_cACint209_1 Progress: [142/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [47/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [72/1500]
# Cell: L5_MC_bAC217_1 Progress: [74/1500]
# Cell: L5_DBC_bAC217_1 Progress: [61/1500]
# Cell: L5_ChC_cACint209_1 Progress: [143/1500]
# Cell: L5_ChC_cACint209_1 Progress: [144/1500]
# Cell: L5_LBC_bAC217_1 Progress: [85/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [40/1500]
# Cell: L5_BP_bAC217_1 Progress: [71/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [73/1500]
# Cell: L5_NBC_bAC217_1 Progress: [69/1500]
# Cell: L5_DBC_bAC217_1 Progress: [62/1500]
# Cell: L5_BTC_bAC217_1 Progress: [72/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [28/1500]
# Cell: L5_BP_bAC217_1 Progress: [72/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [48/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [37/1500]
# Cell: L5_ChC_cACint209_1 Progress: [145/1500]
# Cell: L5_BTC_bAC217_1 Progress: [73/1500]
# Cell: L5_MC_bAC217_1 Progress: [75/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [28/1500]
# Cell: L5_NBC_bAC217_1 Progress: [70/1500]
# Cell: L5_LBC_bAC217_1 Progress: [86/1500]
# Cell: L5_ChC_cACint209_1 Progress: [146/1500]
# Cell: L5_BTC_bAC217_1 Progress: [74/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [29/1500]
# Cell: L5_ChC_cACint209_1 Progress: [147/1500]
# Cell: L5_MC_bAC217_1 Progress: [76/1500]
# Cell: L5_LBC_bAC217_1 Progress: [87/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [49/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [29/1500]
# Cell: L5_NBC_bAC217_1 Progress: [71/1500]
# Cell: L5_DBC_bAC217_1 Progress: [63/1500]
# Cell: L5_NGC_bNAC219_1 Progress: [30/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [41/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [38/1500]
# Cell: L5_ChC_cACint209_1 Progress: [148/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [74/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [75/1500]
# Cell: L5_ChC_cACint209_1 Progress: [149/1500]
# Cell: L5_DBC_bAC217_1 Progress: [64/1500]
# Cell: L5_LBC_bAC217_1 Progress: [88/1500]
# Cell: L5_MC_bAC217_1 Progress: [77/1500]
# Cell: L5_ChC_cACint209_1 Progress: [150/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [50/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [76/1500]
# Cell: L5_BTC_bAC217_1 Progress: [75/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [30/1500]
# Cell: L5_DBC_bAC217_1 Progress: [65/1500]
# Cell: L5_MC_bAC217_1 Progress: [78/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [39/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [77/1500]
# Cell: L5_BP_bAC217_1 Progress: [73/1500]
# Cell: L5_ChC_cACint209_1 Progress: [151/1500]
# Cell: L5_LBC_bAC217_1 Progress: [89/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [78/1500]
# Cell: L5_TTPC2_cADpyr232_1 Progress: [51/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [79/1500]
# Cell: L5_ChC_cACint209_1 Progress: [152/1500]
# Cell: L5_MC_bAC217_1 Progress: [79/1500]
# Cell: L5_DBC_bAC217_1 Progress: [66/1500]
# Cell: L5_LBC_bAC217_1 Progress: [90/1500]
# Cell: L5_ChC_cACint209_1 Progress: [153/1500]
# Cell: L5_STPC_cADpyr232_1 Progress: [31/1500]
# Cell: L5_LBC_bAC217_1 Progress: [91/1500]
# Cell: L5_SBC_bNAC219_1 Progress: [80/1500]
# Cell: L5_DBC_bAC217_1 Progress: [67/1500]
# Cell: L5_ChC_cACint209_1 Progress: [154/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [40/1500]
# ...
# Cell: L5_UTPC_cADpyr232_1 Progress: [1207/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [1481/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1208/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [1482/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [1483/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1209/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [1484/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [1485/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1210/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [1486/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1211/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1212/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [1487/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [1488/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1213/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1214/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [1489/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1215/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [1490/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [1491/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1216/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [1492/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1217/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1218/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [1493/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [1494/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1219/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [1495/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1220/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1221/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [1496/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [1497/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1222/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [1498/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1223/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [1499/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1224/1500]
# Cell: L5_TTPC1_cADpyr232_1 Progress: [1500/1500]
# Done generating EAPs for L5_TTPC1_cADpyr232_1
# Cell: L5_UTPC_cADpyr232_1 Progress: [1225/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1226/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1227/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1228/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1229/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1230/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1231/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1232/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1233/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1234/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1235/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1236/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1237/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1238/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1239/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1240/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1241/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1242/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1243/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1244/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1245/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1246/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1247/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1248/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1249/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1250/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1251/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1252/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1253/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1254/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1255/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1256/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1257/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1258/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1259/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1260/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1261/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1262/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1263/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1264/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1265/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1266/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1267/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1268/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1269/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1270/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1271/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1272/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1273/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1274/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1275/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1276/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1277/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1278/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1279/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1280/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1281/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1282/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1283/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1284/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1285/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1286/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1287/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1288/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1289/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1290/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1291/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1292/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1293/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1294/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1295/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1296/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1297/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1298/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1299/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1300/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1301/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1302/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1303/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1304/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1305/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1306/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1307/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1308/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1309/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1310/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1311/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1312/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1313/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1314/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1315/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1316/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1317/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1318/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1319/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1320/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1321/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1322/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1323/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1324/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1325/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1326/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1327/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1328/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1329/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1330/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1331/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1332/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1333/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1334/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1335/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1336/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1337/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1338/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1339/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1340/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1341/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1342/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1343/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1344/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1345/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1346/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1347/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1348/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1349/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1350/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1351/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1352/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1353/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1354/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1355/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1356/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1357/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1358/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1359/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1360/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1361/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1362/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1363/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1364/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1365/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1366/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1367/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1368/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1369/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1370/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1371/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1372/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1373/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1374/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1375/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1376/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1377/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1378/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1379/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1380/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1381/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1382/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1383/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1384/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1385/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1386/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1387/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1388/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1389/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1390/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1391/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1392/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1393/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1394/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1395/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1396/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1397/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1398/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1399/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1400/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1401/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1402/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1403/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1404/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1405/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1406/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1407/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1408/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1409/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1410/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1411/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1412/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1413/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1414/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1415/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1416/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1417/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1418/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1419/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1420/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1421/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1422/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1423/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1424/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1425/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1426/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1427/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1428/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1429/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1430/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1431/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1432/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1433/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1434/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1435/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1436/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1437/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1438/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1439/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1440/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1441/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1442/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1443/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1444/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1445/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1446/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1447/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1448/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1449/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1450/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1451/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1452/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1453/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1454/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1455/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1456/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1457/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1458/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1459/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1460/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1461/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1462/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1463/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1464/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1465/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1466/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1467/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1468/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1469/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1470/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1471/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1472/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1473/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1474/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1475/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1476/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1477/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1478/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1479/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1480/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1481/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1482/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1483/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1484/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1485/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1486/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1487/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1488/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1489/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1490/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1491/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1492/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1493/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1494/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1495/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1496/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1497/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1498/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1499/1500]
# Cell: L5_UTPC_cADpyr232_1 Progress: [1500/1500]
# Done generating EAPs for L5_UTPC_cADpyr232_1
# Aggregating templates
#
#
#
# Simulation time: 584.9658041000366
#
#
#
#
# Saved  templates in temp/pros_of_details/templates.h5
# {'sim_time': 1,
#  'target_spikes': [3, 50],
#  'cut_out': [2, 5],
#  'dt': 0.03125,
#  'delay': 10,
#  'weights': [0.25, 1.75],
#  'rot': 'physrot',
#  'probe': 'Neuropixels-384',
#  'ncontacts': 1,
#  'overhang': 50,
#  'offset': 0,
#  'xlim': [-50, 50],
#  'ylim': None,
#  'zlim': [-1001, 1001],
#  'x_distr': 'uniform',
#  'beta_distr_params': [1.5, 5],
#  'min_amp': 30,
#  'check_eap_shape': True,
#  'n': 1500,
#  'seed': 0,
#  'drifting': False,
#  'max_drift': 100,
#  'min_drift': 30,
#  'drift_steps': 31,
#  'drift_xlim': [-10, 10],
#  'drift_ylim': [-10, 10],
#  'drift_zlim': [30, 80],
#  'check_for_drift_amp': False,
#  'drift_within_bounds': False,
#  'timeout': None,
#  'max_iterations': 1000}

# %% [markdown]
# ## Parametrize recording

# %%
# %%time

# setup common recording parameters
rec_prms = mr.get_default_recordings_params()

rec_prms['recordings']['filter'] = False                         # no filtering

rec_prms['spiketrains']['duration'] = 600          # (default=600) recording duration
rec_prms['spiketrains']['min_rate'] = 0.5          # default value

rec_prms['seeds']['spiketrains'] = 0               # seeds for reproducibility 
rec_prms['seeds']['templates'] = 1
rec_prms['seeds']['noise'] = 2
rec_prms['seeds']['convolution'] = 3

# save common template parameters
with open(TEMPLATE_PARAMS_PATH, 'w') as f:
    json.dump(tpl_prms, f, indent=4)
# Out:
# CPU times: user 0 ns, sys: 5.88 ms, total: 5.88 ms
# Wall time: 5.69 ms

# %% [markdown]
# - This replicates Buccino et al., simulation with MEAREC as described in the Spikeinterface paper.
# - Execution time: 23 min

# %% [markdown]
# ## Simulate
#
# - execution time: 23 min

# %%
# %%time

# setup parameters
rec_prms['spiketrains']['n_exc'] = 200
rec_prms['spiketrains']['n_inh'] = 50

# simulate recording (23 min)
RecordingRep, GtRep, RecGen = simulate_synthetic_recording_with_mearec(rec_prms, 'L5', TEMPLATES_PATH, RECORDING_REP_H5_PATH)

# setup metadata
RecordingRep, GtRep = set_metadata_to_mearec_simulations(RecGen, RecordingRep, GtRep)
RecordingRep = standardize_site_location_property(RecordingRep)

# save extractors
RecordingRep.save(folder=RECORDING_REP_PATH, **save_recording_params)

# save parameters
save_simulation_parameters_to_assets(rec_prms, RecGen, INPUT_PARAMS_REP_PATH, OUTPUT_PARAMS_REP_PATH)

# report parameters
# report_simulation_parameters(RecGen)
print('Recording metadata:', si.load_extractor(RECORDING_REP_PATH).get_property_keys())
# Out:
# Loading templates...
# Done loading templates...
# Spiketrains seed:  0
# dtype float32
# Noise Level  10
# Templates selection seed:  1
# Selecting cells
# Padding template edges
# Elapsed pad time: 2.60158634185791
# Creating time jittering
# Elapsed jitter time: 1.810586929321289
# Smoothing templates
# Computing spike train SNR
# Adding spiketrain annotations
# Convolution seed:  3
# Electrode modulaton
# Adding noise
# Noise seed:  2
# Elapsed time:  1036.9336937698536
# write_binary_recording
# engine=process - n_jobs=20 - samples_per_chunk=50,000 - chunk_memory=73.24 MiB - total_memory=1.43 GiB - chunk_duration=1.56s
# write_binary_recording (workers: 20 processes):   0%|          | 0/384 [00:00<?, ?it/s]
# Recording metadata: ['gain_to_uV', 'offset_to_uV', 'contact_vector', 'location', 'group', 'gain_to_physical_unit', 'location3D', 'layer', 'offset_to_physical_unit', 'channel_name', 'physical_unit', 'layers']
# CPU times: user 15min 37s, sys: 1min 55s, total: 17min 32s
# Wall time: 17min 51s
