# %% [markdown]
# # Fig3a

# %% [markdown]
# a) Five types of spike temporal profiles sorted with Kilosort3 from Neuropixels 1.0 single-electrodes in the Human neocortex (panel adapted from \cite{paulk_large-scale_2021_biorxiv}),
#
# b) Five similar types found in the cat visual cortex (panel adapted from \cite{sun_analysis_2021}) and sorted with Kilosort3
#
# https://www.wiley.com/en-us/solutions-partnerships/permissions/general-queries/
