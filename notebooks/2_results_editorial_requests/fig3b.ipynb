# %% [markdown]
# # Fig3b

# %% [markdown]
# b) Five similar types found in the cat visual cortex (panel adapted from \cite{sun_analysis_2021}) and sorted with Kilosort3
#
# 1. Submit request to use content (RightsLink): https://www.wiley.com/en-us/solutions-partnerships/permissions/general-queries/
# 2. Write title of paper
# 3.
