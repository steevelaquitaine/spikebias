# %%
import numpy as np
spike_times = np.load("/gpfs/bbp.cscs.ch/project/proj68/scratch/laquitai/2_bernstein_2023/sorting/0_silico/test_neuropixels_lfp_10m_384ch_hex_O1_40Khz_2023_08_17/421db120-c09a-4b21-9b5d-f63e2c0d15b4/KS3_output/spike_times.npy")
spike_templates = np.load("/gpfs/bbp.cscs.ch/project/proj68/scratch/laquitai/2_bernstein_2023/sorting/0_silico/test_neuropixels_lfp_10m_384ch_hex_O1_40Khz_2023_08_17/421db120-c09a-4b21-9b5d-f63e2c0d15b4/KS3_output/spike_templates.npy")
templates = np.load("/gpfs/bbp.cscs.ch/project/proj68/scratch/laquitai/2_bernstein_2023/sorting/0_silico/test_neuropixels_lfp_10m_384ch_hex_O1_40Khz_2023_08_17/421db120-c09a-4b21-9b5d-f63e2c0d15b4/KS3_output/templates.npy")
clusters = np.load("/gpfs/bbp.cscs.ch/project/proj68/scratch/laquitai/2_bernstein_2023/sorting/0_silico/test_neuropixels_lfp_10m_384ch_hex_O1_40Khz_2023_08_17/421db120-c09a-4b21-9b5d-f63e2c0d15b4/KS3_output/spike_clusters.npy")

# %%
print(spike_templates.shape)
print(spike_times.shape)

# these are the set of learnt 3D templates 
# used to extract spikes
print(templates.shape)
print(len(np.unique(clusters)))
# Out:
# (312478, 1)
# (312478, 1)
# (793, 82, 384)
# 782

# %%
from matplotlib import pyplot as plt
#plt.imshow(np.log10(templates[0,:,192:199]));
plt.imshow(templates[0,:,192:199]);

# %%
plt.plot(templates[0,:,:]);

# %%
# plt.imshow(templates[100,:,192:199]);
plt.imshow(templates[100,:,:]);

# %%
plt.plot(templates[100,:,:]);
