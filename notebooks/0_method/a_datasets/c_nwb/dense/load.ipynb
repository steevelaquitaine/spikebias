# %% [markdown]
# ## Load
#
# * Load from neurodata without border (NWB).
#
# setup spikeinterf0_100_5

# %%
# SETUP PACKAGES 
# %load_ext autoreload
# %autoreload 2
import os
import spikeinterface as si

# SET PROJECT PATH
PROJ_PATH = "/gpfs/bbp.cscs.ch/project/proj85/home/laquitai/preprint_2023"
os.chdir(PROJ_PATH)
from src.nodes.utils import get_config

# SETUP CONFIG
data_conf, param_conf = get_config("dense_spont", "probe_3").values()
NWB_PATH = data_conf["nwb"]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2024-11-07 14:38:26,876 - root - utils.py - get_config - INFO - Reading experiment config.
# 2024-11-07 14:38:26,926 - root - utils.py - get_config - INFO - Reading experiment config. - done

# %% [markdown]
# ### Load wired recording from NWB

# %%
# NWB way
RecNWB = si.load_extractor(data_conf["probe_wiring"]["full"]["output"])

# old way
RecOld = si.load_extractor(
    "/gpfs/bbp.cscs.ch/project/proj85/scratch/laquitai/4_preprint_2023/0_silico/horvath/concatenated_campaigns/probe3_hex0_rou04_pfr03_20Khz/dataeng/recording/traces_wired"
)

# %%
# unit-test
tracenwb = RecNWB.get_traces()
traceold = RecOld.get_traces()
(tracenwb == traceold).all()
# Out:
# True

# %% [markdown]
# ### visua

# %%
from matplotlib import pyplot as plt

plt.plot(tracenwb[:100000, 50])

# %%
plt.plot(traceold[:100000, 50])
