# %% [markdown]
# # Check NWB recordings are wired
#
# 1. Download from DANDI archive (see pipeline in src/)
# 2. activate spikeinterf.. env

# %%
import spikeinterface.extractors as se

# %% [markdown]
# ### npx_spont

# %%
rec = se.NwbRecordingExtractor(
    "/gpfs/bbp.cscs.ch/project/proj85/scratch/laquitai/4_preprint_2023/0_silico/neuropixels/concatenated_campaigns/nwb/sub-001/sub-001_ecephys.nwb"
)
probe = rec.get_probe()
print("coordinates:", probe.contact_positions)
# Out:
# coordinates: [[ 2744.8337607   -881.07702126     0.        ]
#  [ 2770.135404    -889.29972517     0.        ]
#  [ 2795.4370473   -897.52242907     0.        ]
#  ...
#  [ 5125.37300183 -1604.2500257      0.        ]
#  [ 5150.67464513 -1612.4727296      0.        ]
#  [ 5175.97628843 -1620.69543351     0.        ]]
# /gpfs/bbp.cscs.ch/project/proj85/scratch/laquitai/4_preprint_2023/envs/spikinterf0_100_5/lib/python3.9/site-packages/spikeinterface/core/baserecordingsnippets.py:244: UserWarning: There is no Probe attached to this recording. Creating a dummy one with contact positions
#   warn("There is no Probe attached to this recording. Creating a dummy one with contact positions")

# %% [markdown]
# ### npx_evoked

# %%
rec = se.NwbRecordingExtractor(
    "/gpfs/bbp.cscs.ch/project/proj85/scratch/laquitai/4_preprint_2023/dataeng/0_silico/4_spikesorting_stimulus_test_neuropixels_8-1-24__8slc_80f_360r_50t_200ms_1_smallest_fiber_gids/0fcb7709-b1e9-4d84-b056-5801f20d55af/campaign/nwb/sub-002/sub-002_ecephys.nwb"
)
probe = rec.get_probe()
print("coordinates:", probe.contact_positions)
# Out:
# coordinates: [[ 2744.8337607   -881.07702126     0.        ]
#  [ 2770.135404    -889.29972517     0.        ]
#  [ 2795.4370473   -897.52242907     0.        ]
#  ...
#  [ 5125.37300183 -1604.2500257      0.        ]
#  [ 5150.67464513 -1612.4727296      0.        ]
#  [ 5175.97628843 -1620.69543351     0.        ]]

# %% [markdown]
# ### Dense probe

# %%
rec = se.NwbRecordingExtractor(
    "/gpfs/bbp.cscs.ch/project/proj85/scratch/laquitai/4_preprint_2023/0_silico/horvath/concatenated_campaigns/probe1_hex0_rou04_pfr03_20Khz/nwb/sub-003/sub-003_ecephys.nwb"
)
probe = rec.get_probe()
print("coordinates:", probe.contact_positions)
# Out:
# coordinates: [[ 4161.87293284 -1364.79067876     0.        ]
#  [ 4182.8860406  -1370.74738756     0.        ]
#  [ 4203.89914835 -1376.70409635     0.        ]
#  [ 4224.91225611 -1382.66080515     0.        ]
#  [ 4245.92536386 -1388.61751395     0.        ]
#  [ 4266.93847162 -1394.57422275     0.        ]
#  [ 4287.95157937 -1400.53093155     0.        ]
#  [ 4308.96468713 -1406.48764034     0.        ]
#  [ 4329.97779488 -1412.44434914     0.        ]
#  [ 4350.99090264 -1418.40105794     0.        ]
#  [ 4372.00401039 -1424.35776674     0.        ]
#  [ 4393.01711815 -1430.31447553     0.        ]
#  [ 4414.0302259  -1436.27118433     0.        ]
#  [ 4435.04333366 -1442.22789313     0.        ]
#  [ 4456.05644141 -1448.18460193     0.        ]
#  [ 4477.06954917 -1454.14131073     0.        ]
#  [ 4498.08265692 -1460.09801952     0.        ]
#  [ 4519.09576468 -1466.05472832     0.        ]
#  [ 4540.10887243 -1472.01143712     0.        ]
# ...

# %%
rec = se.NwbRecordingExtractor(
    "/gpfs/bbp.cscs.ch/project/proj85/scratch/laquitai/4_preprint_2023/0_silico/horvath/concatenated_campaigns/probe2_hex0_rou04_pfr03_20Khz/nwb/dense_biophy_spont2.nwb"
)
probe = rec.get_probe()
print("coordinates:", probe.contact_positions)
# Out:
# coordinates: [[ 3761.00210007 -1221.57043056     0.        ]
#  [ 3775.23427443 -1226.1957015      0.        ]
#  [ 3789.46644878 -1230.82097245     0.        ]
#  [ 3803.69862314 -1235.44624339     0.        ]
#  [ 3817.93079749 -1240.07151433     0.        ]
#  [ 3832.16297185 -1244.69678528     0.        ]
#  [ 3846.39514621 -1249.32205622     0.        ]
#  [ 3860.62732056 -1253.94732717     0.        ]
#  [ 3874.85949492 -1258.57259811     0.        ]
#  [ 3889.09166927 -1263.19786906     0.        ]
#  [ 3903.32384363 -1267.82314        0.        ]
#  [ 3917.55601798 -1272.44841095     0.        ]
#  [ 3931.78819234 -1277.07368189     0.        ]
#  [ 3946.0203667  -1281.69895284     0.        ]
#  [ 3960.25254105 -1286.32422378     0.        ]
#  [ 3974.48471541 -1290.94949473     0.        ]
#  [ 3988.71688976 -1295.57476567     0.        ]
#  [ 4002.94906412 -1300.20003662     0.        ]
#  [ 4017.18123847 -1304.82530756     0.        ]
# ...

# %%
rec = se.NwbRecordingExtractor(
    "/gpfs/bbp.cscs.ch/project/proj85/scratch/laquitai/4_preprint_2023/0_silico/horvath/concatenated_campaigns/probe3_hex0_rou04_pfr03_20Khz/nwb/dense_biophy_spont3.nwb"
)
probe = rec.get_probe()
print("coordinates:", probe.contact_positions)
# Out:
# coordinates: [[ 3128.4610176  -1016.002833       0.        ]
#  [ 3142.69319196 -1020.62810395     0.        ]
#  [ 3156.92536631 -1025.25337489     0.        ]
#  [ 3171.15754067 -1029.87864584     0.        ]
#  [ 3185.38971502 -1034.50391678     0.        ]
#  [ 3199.62188938 -1039.12918773     0.        ]
#  [ 3213.85406373 -1043.75445867     0.        ]
#  [ 3228.08623809 -1048.37972962     0.        ]
#  [ 3242.31841245 -1053.00500056     0.        ]
#  [ 3256.5505868  -1057.63027151     0.        ]
#  [ 3270.78276116 -1062.25554245     0.        ]
#  [ 3285.01493551 -1066.8808134      0.        ]
#  [ 3299.24710987 -1071.50608434     0.        ]
#  [ 3313.47928422 -1076.13135529     0.        ]
#  [ 3327.71145858 -1080.75662623     0.        ]
#  [ 3341.94363293 -1085.38189718     0.        ]
#  [ 3356.17580729 -1090.00716812     0.        ]
#  [ 3370.40798165 -1094.63243907     0.        ]
#  [ 3384.640156   -1099.25771001     0.        ]
# ...
